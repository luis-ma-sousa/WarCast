# %% [markdown]
# # Wikipedia scrapping

# %% [markdown]
# ## List of battles

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from urllib.parse import urljoin
import time
import random

BASE_URL = "https://en.wikipedia.org"
MAIN_PAGE = urljoin(BASE_URL, "/wiki/List_of_battles_(alphabetical)")
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    )
}

def extract_year(text):
    """Extract a year from text with improved matching for various formats."""
    if not isinstance(text, str):
        return None
        
    # Standard year pattern (1000-2029)
    match = re.search(r'\b(\d{3,4})\b(?!\s*BCE|\s*BC)', text)
    if match:
        return int(match.group(1))
    
    # Check for year ranges like "1495–96" or "1914-18"
    range_match = re.search(r'\b(\d{3,4})[–\-](\d{2,4})\b', text)
    if range_match:
        return int(range_match.group(1))
    
    # Last resort: any 3-4 digit number that might be a year
    digits_match = re.search(r'\b(\d{3,4})\b', text)
    if digits_match:
        year = int(digits_match.group(1))
        # Basic validation (between 500 and 2030)
        if 500 <= year <= 2030:
            return year
            
    return None

def clean_description(text):
    """Clean up description text by removing weird characters and formatting."""
    if not isinstance(text, str):
        return ""
    
    # Replace various dashes with standard hyphen
    cleaned = text.replace('–', '-').replace('\u2013', '-').replace('\u2014', '-')
    
    # Remove any HTML entities
    cleaned = re.sub(r'&[a-zA-Z]+;', ' ', cleaned)
    
    # Remove escape sequences
    cleaned = re.sub(r'\\[a-z]', '', cleaned)
    
    # Normalize whitespace
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    
    return cleaned

def standardize_conflict_name(conflict_text, year=None):
    """
    Standardize various ways of writing World War I and World War II in the conflict column.
    Also correct World War I references for battles within WWII period to World War II.
    
    Args:
        conflict_text (str): The original conflict text
        year (int, optional): The year of the battle, used for correction
        
    Returns:
        str: Standardized conflict text
    """
    if not isinstance(conflict_text, str) or not conflict_text.strip():
        return conflict_text
    
    # First, fix any World War III+ issues
    if "World War III" in conflict_text or "World War IIII" in conflict_text or "World War IIIII" in conflict_text:
        conflict_text = "World War II"
        return conflict_text
    
    # Determine if this is WWI or WWII
    is_ww2 = False
    is_ww1 = False
    
    # Check if year is within WWII period (1939-1945)
    if year is not None and 1939 <= year <= 1945:
        is_ww2 = True
    # Check if year is within WWI period (1914-1918)
    elif year is not None and 1914 <= year <= 1918:
        is_ww1 = True
    
    # Look for WWII indicators
    ww2_indicators = ["world war 2", "ww2", "wwii", "second world war", 
                     "2nd world war", "world war two", "world war ii"]
    
    for indicator in ww2_indicators:
        if indicator in conflict_text.lower():
            is_ww2 = True
            break
    
    # Look for WWI indicators
    ww1_indicators = ["world war 1", "ww1", "wwi", "first world war", 
                     "1st world war", "world war one", "great war", "world war i"]
    
    for indicator in ww1_indicators:
        if indicator in conflict_text.lower():
            is_ww1 = True
            break
    
    # Apply rule: if any WWII indicator or year is in WWII period, it's WWII
    if is_ww2:
        return "World War II"
    
    # If it has a WWI indicator and isn't WWII, it's WWI
    if is_ww1:
        return "World War I"
    
    # No world war references found
    return conflict_text

def extract_conflict(desc, year):
    """Extract the conflict/war information from the description."""
    if not year or not isinstance(desc, str):
        return None
    
    # Look for text that appears after the year
    year_str = str(int(year))  # Convert to string without decimal
    if year_str in desc:
        parts = desc.split(year_str, 1)
        if len(parts) > 1:
            after_year = parts[1].strip()
            # Remove any leading dashes or hyphens
            after_year = re.sub(r'^[-–—\s]+', '', after_year)
            
            # Standardize World War references with year correction
            after_year = standardize_conflict_name(after_year, year)
            
            return after_year if after_year else None
    
    # Alternative approach: look for common conflict prefixes
    prefixes = [
        "part of", "during", "in the", "related to", "world war", 
        "civil war", "napoleonic", "crusade", "invasion of"
    ]
    
    for prefix in prefixes:
        if prefix in desc.lower():
            index = desc.lower().find(prefix)
            if index > 0:
                conflict = desc[index:].strip()
                
                # Standardize World War references with year correction
                conflict = standardize_conflict_name(conflict, year)
                
                return conflict
    
    return None

def get_alternate_battle_pages():
    """Find other pages that list battles."""
    print(f"Checking for battle list pages from: {MAIN_PAGE}")
    response = requests.get(MAIN_PAGE, headers=HEADERS)
    
    if response.status_code != 200:
        print(f"Failed to fetch main page: {MAIN_PAGE}")
        return []
    
    soup = BeautifulSoup(response.content, "html.parser")
    pages = []
    
    # Only include pages that are likely to contain actual battle lists
    # Exclude navigation and edit pages
    excluded_terms = ["action=edit", "action=history", "Special:", "Talk:", 
                      "oldid=", "printable=", "toggle_view_mobile", "action=info"]
    
    # Method 1: Look for links to categorized battle lists
    for a in soup.find_all("a"):
        href = a.get("href", "")
        text = a.text.strip()
        
        # Only include links that look like battle list pages
        # and exclude navigation/action links
        if (href and "List_of_battles" in href and 
            href != "/wiki/List_of_battles_(alphabetical)" and
            ("by_location" in href or "chronological" in href) and
            not any(term in href for term in excluded_terms)):
            
            url = urljoin(BASE_URL, href)
            pages.append((url, text))
            print(f"Found battle list page: {text} -> {url}")
    
    # Method 2: Check for links in the See Also section
    see_also = None
    for h2 in soup.find_all("h2"):
        span = h2.find("span", class_="mw-headline")
        if span and "See also" in span.text:
            see_also = h2
            break
    
    if see_also:
        next_elem = see_also.next_sibling
        while next_elem and next_elem.name != "h2":
            if next_elem.name == "ul":
                for li in next_elem.find_all("li"):
                    a = li.find("a")
                    if a and "List_of_battles" in a.get("href", ""):
                        href = a.get("href", "")
                        # Skip navigation/edit links
                        if any(term in href for term in excluded_terms):
                            continue
                            
                        url = urljoin(BASE_URL, href)
                        text = a.text.strip()
                        if (url, text) not in pages:
                            pages.append((url, text))
                            print(f"Found battle list page in 'See also': {text} -> {url}")
            next_elem = next_elem.next_sibling
    
    # Method 3: Check for letter-specific pages like "List_of_battles_(A)"
    # This rarely exists anymore, but check a few common ones
    letter_ranges = ["A", "B", "C", "S", "A-F", "G-M", "N-Z"]
    for letter in letter_ranges:
        letter_url = urljoin(BASE_URL, f"/wiki/List_of_battles_({letter})")
        try:
            r = requests.head(letter_url, headers=HEADERS)
            if r.status_code == 200:
                pages.append((letter_url, f"Battles {letter}"))
                print(f"Found letter-specific page: Battles {letter} -> {letter_url}")
                time.sleep(random.uniform(0.5, 1.0))  # Random delay to avoid rate limiting
        except Exception as e:
            print(f"Error checking for letter page {letter}: {e}")
    
    # Always include the main alphabetical page
    pages.append((MAIN_PAGE, "Main"))
    
    # Remove duplicates
    unique_pages = []
    seen_urls = set()
    for url, label in pages:
        if url not in seen_urls and not any(term in url for term in excluded_terms):
            seen_urls.add(url)
            unique_pages.append((url, label))
    
    print(f"Found {len(unique_pages)} unique battle list pages")
    return unique_pages

def process_list(ul, battles, section):
    """Process a list element and extract battles."""
    battle_count = 0
    
    # Skip very small lists that are likely navigation
    if len(ul.find_all("li")) < 2:
        return 0
        
    # Process all list items
    for li in ul.find_all("li", recursive=False):  # Only direct children
        a_tag = li.find("a")
        if not a_tag:
            continue
        
        battle_name = a_tag.text.strip()
        href = a_tag.get("href", "")
        
        # Skip non-wiki links, categories, lists, etc.
        if not href.startswith("/wiki/") or ":" in href or "List_of" in href:
            continue
            
        wiki_link = urljoin(BASE_URL, href)
        full_text = li.get_text(strip=True)
        
        # Skip very short texts that are likely not battles
        if len(full_text) < 10:
            continue
            
        # Clean the description text
        clean_text = clean_description(full_text)
        
        # Check if this looks like a battle
        is_battle = False
        
        # Check for battle-related terms in the text or link
        battle_terms = ["battle of", "siege of", "campaign", "offensive", "assault", 
                       "war of", "invasion of", "operation ", "attack on"]
        if any(term in battle_name.lower() for term in battle_terms) or \
           any(term in clean_text.lower() for term in battle_terms):
            is_battle = True
        
        # Extract year
        year = extract_year(clean_text)
        if year:
            is_battle = True
        
        # Extract conflict information
        conflict = extract_conflict(clean_text, year)
        
        if is_battle and "/wiki/" in wiki_link:
            # Check if this battle is already in our list
            is_duplicate = False
            for battle in battles:
                # Only consider it a duplicate if name AND year match
                # (or if the links are identical)
                same_name = battle["battle_name"] == battle_name
                same_link = battle["wiki_link"] == wiki_link
                same_year = battle["year"] == year
                
                if same_link or (same_name and same_year):
                    is_duplicate = True
                    break
            
            if not is_duplicate:
                battles.append({
                    "battle_name": battle_name,
                    "year": year,
                    "description": clean_text,
                    "conflict": conflict,
                    "wiki_link": wiki_link
                })
                battle_count += 1
    
    return battle_count

def scrape_battles_from_page(url, label):
    """Extract battles from a Wikipedia page."""
    print(f"Scraping battles from: {url}")
    response = requests.get(url, headers=HEADERS)
    
    if response.status_code != 200:
        print(f"Failed to fetch page: {url}")
        return []
    
    soup = BeautifulSoup(response.content, "html.parser")
    content_div = soup.find("div", {"class": "mw-parser-output"})
    
    if not content_div:
        print(f"Could not find content on page: {url}")
        return []
    
    battles = []
    current_section = None
    
    # Keep track of section counts for debugging
    section_counts = {}
    
    # STRATEGY 1: Find all section headings (most likely the letter headings A, B, C, etc.)
    for element in content_div.find_all(['h2', 'h3', 'div']):
        span = None
        
        # Handle different heading elements
        if element.name in ['h2', 'h3']:
            span = element.find("span", {"class": "mw-headline"})
        elif element.name == 'div' and element.get('class') and 'mw-heading' in element.get('class'):
            span = element.find("span", {"class": "mw-headline"})
            
        if span:
            section_id = span.get("id", "")
            section_text = span.text.strip()
            
            # Check if it looks like a letter or letter range section
            if len(section_text) == 1 and section_text.isalpha():
                current_section = section_text
                print(f"Found section: {current_section}")
                section_counts[current_section] = 0
            elif re.match(r'^[A-Z][^a-z]*$', section_text) and len(section_text) < 10:
                # Matches letter ranges like "A-F" or similar
                current_section = section_text
                print(f"Found section: {current_section}")
                section_counts[current_section] = 0
            
            # Process lists that follow this heading
            if current_section:
                # Find all lists that follow this header until the next header
                next_elem = element.next_sibling
                
                # Skip text nodes and comments
                while next_elem and (not hasattr(next_elem, 'name') or not next_elem.name):
                    next_elem = next_elem.next_sibling
                
                # Look for all lists before the next heading
                while next_elem and not (hasattr(next_elem, 'name') and next_elem.name in ['h1', 'h2', 'h3']):
                    if hasattr(next_elem, 'name'):
                        # Direct UL element
                        if next_elem.name == 'ul':
                            battle_count = process_list(next_elem, battles, current_section)
                            section_counts[current_section] = section_counts.get(current_section, 0) + battle_count
                        
                        # List might be inside another container (div, p, etc.)
                        else:
                            for ul in next_elem.find_all('ul', recursive=True):
                                battle_count = process_list(ul, battles, current_section)
                                section_counts[current_section] = section_counts.get(current_section, 0) + battle_count
                    
                    next_elem = next_elem.next_sibling
    
    # STRATEGY 2: Look for battles in tables
    tables = content_div.find_all("table", {"class": "wikitable"})
    for table in tables:
        # Skip tables that are clearly navigation or metadata
        if any(cls in table.get("class", []) for cls in ["infobox", "navbox", "vertical-navbox"]):
            continue
            
        # Check column structure to determine if it's a battle table
        headers = []
        header_row = table.find("tr")
        if header_row:
            headers = [th.get_text(strip=True).lower() for th in header_row.find_all(["th"])]
        
        is_battle_table = False
        if headers and any(keyword in " ".join(headers) for keyword in ["battle", "year", "date", "war", "conflict"]):
            is_battle_table = True
        
        if is_battle_table:
            print(f"Found battle table with columns: {headers}")
            
            # Process table rows
            for row in table.find_all("tr")[1:]:  # Skip header row
                cells = row.find_all(["td"])
                if len(cells) < 2:
                    continue
                
                # Try to determine which columns contain what information
                battle_name = None
                year_text = None
                conflict_text = None
                
                # First cell usually has the battle name
                first_cell = cells[0]
                a_tag = first_cell.find("a")
                if a_tag:
                    battle_name = a_tag.text.strip()
                    wiki_link = urljoin(BASE_URL, a_tag.get("href", ""))
                else:
                    continue  # Skip if no link found
                
                # Look for year in date column or second column
                if len(cells) > 1:
                    year_text = cells[1].get_text(strip=True)
                
                # Look for conflict in additional columns
                if len(cells) > 2:
                    conflict_text = cells[2].get_text(strip=True)
                
                # Combine all cells for description
                full_text = " ".join(cell.get_text(strip=True) for cell in cells)
                clean_text = clean_description(full_text)
                
                # Extract year if not found in specific column
                year = extract_year(year_text) if year_text else extract_year(clean_text)
                
                # Extract conflict if not found in specific column
                conflict = None
                if conflict_text:
                    # Clean and standardize the conflict text
                    conflict = clean_description(conflict_text)
                    conflict = standardize_conflict_name(conflict, year)
                else:
                    conflict = extract_conflict(clean_text, year)
                
                # Add to battles list
                if "/wiki/" in wiki_link and "List_of" not in wiki_link:
                    # Check if this is a duplicate battle
                    is_duplicate = False
                    for battle in battles:
                        # Only consider it a duplicate if name AND year match
                        # (or if the links are identical)
                        same_name = battle["battle_name"] == battle_name
                        same_link = battle["wiki_link"] == wiki_link
                        same_year = battle["year"] == year
                        
                        if same_link or (same_name and same_year):
                            is_duplicate = True
                            break
                    
                    if not is_duplicate:
                        battles.append({
                            "battle_name": battle_name,
                            "year": year,
                            "description": clean_text,
                            "conflict": conflict,
                            "wiki_link": wiki_link
                        })
    
    # Print section counts (for debugging)
    if section_counts:
        print("Battles found by section:")
        total_section_battles = 0
        for section, count in sorted(section_counts.items()):
            print(f"  {section}: {count} battles")
            total_section_battles += count
        print(f"  Total from sections: {total_section_battles}")
    
    # STRATEGY 3: Fallback - look for any lists with battle-like entries
    # Only run this if we found very few battles with normal methods
    # or if we're missing battles from some sections
    if len(battles) < 200 or len(section_counts) < 20:
        print("Using fallback approach to find additional battles...")
        
        # Process all UL elements anywhere in the page
        battle_count_before = len(battles)
        for ul in content_div.find_all("ul"):
            battle_count = process_list(ul, battles, "fallback")
        
        print(f"Fallback method found {len(battles) - battle_count_before} additional battles")
    
    print(f"Total battles found on this page: {len(battles)}")
    return battles

def main():
    try:
        all_battles = []
        
        # We'll just focus on the main page since that contains everything
        print(f"Scraping battles from main page: {MAIN_PAGE}")
        main_battles = scrape_battles_from_page(MAIN_PAGE, "Main")
        all_battles.extend(main_battles)
        
        # Check some alternative pages only if we found few battles
        if len(all_battles) < 500:
            print("Found relatively few battles on main page, checking alternate pages...")
            alt_pages = get_alternate_battle_pages()
            
            # If we found alternate pages, scrape them
            if alt_pages:
                for url, label in alt_pages:
                    battles = scrape_battles_from_page(url, label)
                    all_battles.extend(battles)
                    # Random delay to avoid rate limiting
                    time.sleep(random.uniform(1, 2))
        
        # If we still found nothing, print a debug message
        if not all_battles:
            print("\n⚠️ No battles found! The page structure might have changed.")
            print("Here's some information about the main page structure:")
            
            response = requests.get(MAIN_PAGE, headers=HEADERS)
            soup = BeautifulSoup(response.content, "html.parser")
            
            print(f"Page title: {soup.title.text if soup.title else 'No title'}")
            print("Headings found:")
            for i, h in enumerate(soup.find_all(['h1', 'h2', 'h3'])[:10]):
                print(f"{i+1}. {h.name}: {h.get_text(strip=True)}")
            
            return
        
        print(f"\nTotal battles found across all pages: {len(all_battles)}")
        
        # Create a DataFrame and handle duplicates
        df = pd.DataFrame(all_battles)
        print(f"Initial data: {len(df)} battles")
        
        # Count before deduplication
        battle_counts = df.groupby(['battle_name', 'year']).size().reset_index(name='count')
        duplicate_battles = battle_counts[battle_counts['count'] > 1]
        
        if len(duplicate_battles) > 0:
            print(f"{len(duplicate_battles)} battle name+year combinations appear multiple times")
            print("Examples: ")
            for i, row in duplicate_battles.head(5).iterrows():
                print(f"  - {row['battle_name']} ({row['year']}): {row['count']} occurrences")
        
        # Remove duplicates by battle name AND year (to keep battles with same name but different years)
        df_cleaned = df.drop_duplicates(subset=["battle_name", "year", "wiki_link"]).copy()
        print(f"After deduplication: {len(df_cleaned)} unique battles")
        
        # Post-processing: Standardize World War references in all conflicts
        print("Standardizing World War references in conflicts...")
        
        # Test case for "World War IIIII" issue
        print("Checking for problematic World War references...")
        problematic_refs = df_cleaned['conflict'].str.contains('World War III|World War IIII|World War IIIII', 
                                                              regex=True, 
                                                              case=True, 
                                                              na=False)
        if problematic_refs.sum() > 0:
            print(f"Found {problematic_refs.sum()} problematic 'World War III+' references that need fixing")
        
        # Apply year-based correction to ensure battles are properly classified
        def apply_standardization(row):
            if pd.isna(row['conflict']):
                return ''
            return standardize_conflict_name(row['conflict'], row['year'])
        
        df_cleaned['conflict'] = df_cleaned.apply(apply_standardization, axis=1)
        
        # Count standardized World War references 
        ww1_count = df_cleaned['conflict'].str.contains('^World War I$', regex=True, case=True, na=False).sum()
        ww2_count = df_cleaned['conflict'].str.contains('^World War II$', regex=True, case=True, na=False).sum()
        print(f"Found {ww1_count} battles from World War I and {ww2_count} battles from World War II")
        
        # Final check for any remaining issues
        remaining_issues = df_cleaned['conflict'].str.contains('World War III|World War IIII|World War IIIII', 
                                                              regex=True, 
                                                              case=True, 
                                                              na=False)
        if remaining_issues.sum() > 0:
            print(f"Warning: Still found {remaining_issues.sum()} problematic World War references")
            print("Applying final correction...")
            
            # Manual fix for any remaining issues
            df_cleaned['conflict'] = df_cleaned['conflict'].str.replace('World War IIIII', 'World War II')
            df_cleaned['conflict'] = df_cleaned['conflict'].str.replace('World War IIII', 'World War II')
            df_cleaned['conflict'] = df_cleaned['conflict'].str.replace('World War III', 'World War II')
        
        # Check for any potential misclassifications between WWI and WWII
        potential_errors = df_cleaned[(df_cleaned['year'] >= 1939) & (df_cleaned['year'] <= 1945) & 
                                      (df_cleaned['conflict'] == 'World War I')]
        
        if len(potential_errors) > 0:
            print(f"Warning: Found {len(potential_errors)} battles during WWII period (1939-1945) still labeled as World War I")
            print("These will be corrected...")
            
            # Force correct WWII period battles
            df_cleaned.loc[(df_cleaned['year'] >= 1939) & (df_cleaned['year'] <= 1945), 'conflict'] = df_cleaned.loc[
                (df_cleaned['year'] >= 1939) & (df_cleaned['year'] <= 1945), 'conflict'].apply(
                    lambda x: 'World War II' if x == 'World War I' else x
                )
        
        # Check and fix year data
        year_count = df_cleaned['year'].notna().sum()
        print(f"Battles with year information: {year_count} ({year_count/len(df_cleaned)*100:.1f}%)")
        
        # Reorder columns to a logical order and add battle_id as primary key
        df_cleaned.reset_index(drop=True, inplace=True)
        df_cleaned['battle_id'] = df_cleaned.index + 1  # Start IDs from 1
        column_order = ["battle_id", "battle_name", "year", "description", "conflict", "wiki_link"]
        df_cleaned = df_cleaned[column_order]
        
        # Save to CSV
        df_cleaned.to_csv("battles_list.csv", index=False)
        
        print(f"\n✅ Scraped {len(df_cleaned)} unique battles. Saved to 'battles_list.csv'.")
        
        # Show some sample data
        print("\nSample of scraped battles:")
        for i, row in df_cleaned.head(5).iterrows():
            print(f"{i+1}. {row['battle_name']} ({row['year'] if pd.notna(row['year']) else 'Year unknown'})")
            if row['conflict'] and pd.notna(row['conflict']):
                print(f"   Conflict: {row['conflict']}")
            print(f"   Link: {row['wiki_link']}")
    
    except Exception as e:
        print(f"\n❌ Error: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# Scraping battles from main page: https://en.wikipedia.org/wiki/List_of_battles_(alphabetical)
# Scraping battles from: https://en.wikipedia.org/wiki/List_of_battles_(alphabetical)
# Using fallback approach to find additional battles...
# Fallback method found 962 additional battles
# Total battles found on this page: 962
#
# Total battles found across all pages: 962
# Initial data: 962 battles
# After deduplication: 962 unique battles
# Standardizing World War references in conflicts...
# Checking for problematic World War references...
# Found 58 battles from World War I and 87 battles from World War II
# Battles with year information: 883 (91.8%)
#
# ✅ Scraped 962 unique battles. Saved to 'battles_list.csv'.
#
# Sample of scraped battles:
# 1. Battle of Aachen (1944.0)
#    Conflict: World War II
#    Link: https://en.wikipedia.org/wiki/Battle_of_Aachen
# 2. Battle of Abensberg (1809.0)
#    Conflict: Napoleonic Wars
#    Link: https://en.wikipedia.org/wiki/Battle_of_Abensberg
# 3. Battle of Abbeville (1940.0)
#    Conflict: World War II
#    Link: https://en.wikipedia.org/wiki/Battle_of_Abbeville
# 4. Battle of Abukir (1799.0)
#    Conflict: French Revolution
#    Link: https://en.wikipedia.org/wiki/Battle_of_Abukir_(1799)
# 5. Battle of Abu Klea (1885.0)
#    Conflict: Mahdist War
#    Link: https://en.wikipedia.org/wiki/Battle_of_Abu_Klea

# %% [markdown]
# ## Battle info

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import random
import os.path
from urllib.parse import urljoin

# Constants
BASE_URL = "https://en.wikipedia.org"
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    )
}

def load_battles_csv(filename="battles_list.csv"):
    """Load the battles CSV file and return as DataFrame."""
    if not os.path.isfile(filename):
        raise FileNotFoundError(f"Battles CSV file not found: {filename}")
    
    battles_df = pd.read_csv(filename)
    print(f"Loaded {len(battles_df)} battles from {filename}")
    return battles_df

def extract_number(text, keywords=None):
    """
    Extract number from text, with optional keyword context.
    If keywords provided, looks for numbers near the keywords.
    """
    if not isinstance(text, str):
        return None
    
    text = text.replace('\xa0', ' ')  # Handle non-breaking spaces
    
    # Default keywords if none provided
    if keywords is None:
        keywords = ['men', 'troops', 'soldiers', 'personnel']
    elif isinstance(keywords, str):
        keywords = [keywords]
    
    # Try each keyword
    for keyword in keywords:
        if keyword in text.lower():
            # Find position of keyword
            pos = text.lower().find(keyword)
            
            # Look for numbers before the keyword (within 50 characters)
            before_text = text[max(0, pos-50):pos]
            number_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+(?:\.\d+)?|\d+)', before_text)
            
            # If found numbers before keyword, use the closest one (last one)
            if number_matches:
                num_str = number_matches[-1].replace(',', '')
                try:
                    return int(float(num_str))
                except ValueError:
                    pass
            
            # Look for numbers after keyword (within 20 characters)
            after_text = text[pos + len(keyword):min(len(text), pos + len(keyword) + 20)]
            number_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+(?:\.\d+)?|\d+)', after_text)
            
            # If found numbers after keyword, use the closest one (first one)
            if number_matches:
                num_str = number_matches[0].replace(',', '')
                try:
                    return int(float(num_str))
                except ValueError:
                    pass
    
    # If no numbers found near keywords, look for number ranges (e.g., "10,000-15,000")
    range_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+)(?:\s*[-–]\s*)(\d{1,3}(?:,\d{3})+|\d+)', text)
    if range_matches:
        try:
            # Use average of the range
            first_num = int(range_matches[0][0].replace(',', ''))
            second_num = int(range_matches[0][1].replace(',', ''))
            return (first_num + second_num) // 2
        except ValueError:
            pass
    
    # Look for any number with specific formats (prioritize larger numbers which are more likely troop counts)
    # Focus on numbers that appear to be formatted as thousands (e.g., "10,000")
    formatted_thousands = re.findall(r'(\d{1,3},\d{3})', text)
    if formatted_thousands:
        try:
            return int(formatted_thousands[0].replace(',', ''))
        except ValueError:
            pass
    
    # Look for any large numbers (3+ digits)
    large_numbers = re.findall(r'(\d{3,})', text)
    if large_numbers:
        try:
            return int(large_numbers[0])
        except ValueError:
            pass
    
    # Last resort: any number
    number_matches = re.findall(r'(\d+)', text)
    if number_matches:
        for match in number_matches:
            try:
                num = int(match)
                # Only consider if it's a reasonably sized number for troop counts
                if num > 50:  # Avoid small numbers that might be dates or footnotes
                    return num
            except ValueError:
                continue
    
    return None

def clean_country_name(text):
    """Clean country name text."""
    if not isinstance(text, str):
        return None
    
    # Remove text in brackets, parentheses
    cleaned = re.sub(r'\([^)]*\)', '', text)
    cleaned = re.sub(r'\[[^\]]*\]', '', cleaned)
    
    # Remove footnote references and citation needed
    cleaned = re.sub(r'\[\d+\]', '', cleaned)
    cleaned = re.sub(r'\[citation needed\]', '', cleaned)
    
    # Remove excess whitespace
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    
    # Skip phrases that are clearly results, not countries
    result_phrases = [
        'victory', 'defeat', 'decisive', 'inconclusive', 'stalemate', 
        'draw', 'tactical', 'strategic', 'pyrrhic', 'truce', 'ceasefire'
    ]
    if any(phrase in cleaned.lower() for phrase in result_phrases) and len(cleaned.split()) <= 3:
        return None
    
    # Remove very short strings or just numbers or dates
    if len(cleaned) < 3 or cleaned.isdigit() or re.match(r'^\d+\s+\w+$', cleaned):
        return None
    
    # Replace some common abbreviations
    replacements = {
        'US': 'United States',
        'U.S.': 'United States',
        'U.S.A.': 'United States',
        'USA': 'United States',
        'UK': 'United Kingdom',
        'U.K.': 'United Kingdom',
        'Soviet Union': 'Russia',
        'USSR': 'Russia',
        'U.S.S.R.': 'Russia'
    }
    
    for abbr, full in replacements.items():
        if cleaned == abbr:
            cleaned = full
    
    return cleaned

def extract_html_content(element):
    """Extract a clean text representation of HTML content including flags and formatting."""
    if element is None:
        return ""
    
    # For simple text elements, just return the text
    if isinstance(element, str):
        return element.strip()
    
    # Create a list to store the content parts
    content_parts = []
    
    # Process all child elements
    for child in element.children:
        if child.name is None:  # Text node
            text = child.strip()
            if text:
                content_parts.append(text)
        elif child.name == 'br':
            content_parts.append('\n')
        elif child.name == 'li':
            content_parts.append('\n• ' + extract_html_content(child))
        elif child.name in ['b', 'strong', 'i', 'em', 'span', 'div', 'p']:
            content_parts.append(extract_html_content(child))
        elif child.name == 'a':
            content_parts.append(child.get_text().strip())
        elif child.name == 'ul' or child.name == 'ol':
            for li in child.find_all('li', recursive=False):
                content_parts.append('\n• ' + extract_html_content(li))
    
    # Join all the parts together
    return ' '.join(content_parts).strip()

def extract_countries_from_text(content):
    """Extract country names from text content with better handling of separators."""
    countries = []
    
    # Split by common separators
    parts = re.split(r'[,\n•]|\band\b', content)
    
    for part in parts:
        country = clean_country_name(part)
        if country and country not in countries and len(country) > 3:
            countries.append(country)
    
    return countries

def split_content_by_flags(content):
    """
    Split HTML content that may contain flags and country references.
    This improves extraction when countries are arranged with flag icons.
    """
    if not content:
        return []
    
    # Check for list items
    if '•' in content:
        parts = [p.strip() for p in content.split('•') if p.strip()]
        return parts
    
    # Split by commas and newlines
    parts = re.split(r'[,\n]+', content)
    return [p.strip() for p in parts if p.strip()]

def determine_battle_result(result_text, side1_countries, side2_countries):
    """Determine the battle result with improved pattern matching."""
    if not result_text:
        return "unknown", "unknown"
    
    result_lower = result_text.lower()
    
    # Check for ties
    if any(term in result_lower for term in ["stalemate", "draw", "inconclusive", "indecisive", "truce", "ceasefire"]):
        return "tied", "tied"
    
    # Check for side 1 victory
    side1_victory = any(term in result_lower for term in ["allied victory", "american victory", "british victory", "french victory"])
    for country in side1_countries:
        if country.lower() in result_lower and "victory" in result_lower:
            side1_victory = True
            break
    
    # Check for side 2 victory
    side2_victory = any(term in result_lower for term in ["german victory", "axis victory", "japanese victory", "confederate victory"])
    for country in side2_countries:
        if country.lower() in result_lower and "victory" in result_lower:
            side2_victory = True
            break
    
    # Determine results based on the checks
    if side1_victory and not side2_victory:
        return "winner", "loser"
    elif side2_victory and not side1_victory:
        return "loser", "winner"
    
    # Check for specific defeat mentions
    if "defeat" in result_lower:
        for country in side1_countries:
            if country.lower() in result_lower and "defeat" in result_lower:
                return "loser", "winner"
        for country in side2_countries:
            if country.lower() in result_lower and "defeat" in result_lower:
                return "winner", "loser"
    
    # Default to unknown if we can't determine
    return "unknown", "unknown"

def extract_infobox_data(infobox, key):
    """
    Extract data from infobox based on a key (header text)
    with improved handling of infobox structures.
    """
    if not infobox:
        return []
    
    data = []
    found_header = False
    
    # First try to find a row with the key in the header
    for row in infobox.find_all("tr"):
        if not found_header:
            # Check if this is a header row with our key
            th = row.find("th")
            if th and key.lower() in th.get_text().strip().lower():
                found_header = True
                # Some infoboxes include data in the same row as the header
                td = row.find("td")
                if td:
                    data.append(td)
        else:
            # After finding the header, collect subsequent data rows until we hit another header
            th = row.find("th")
            if th:
                # If the new header doesn't contain our key, we've moved to a new section
                if key.lower() not in th.get_text().strip().lower():
                    break
            
            # Add any data cells
            for td in row.find_all("td"):
                data.append(td)
    
    # If standard approach failed, try to find rows with specific structure
    if not data:
        # Look for row format: belligerent1, belligerent2
        for row in infobox.find_all("tr"):
            ths = row.find_all("th")
            tds = row.find_all("td")
            
            # Check if this is a row with key in any header and multiple data cells
            if any(key.lower() in th.get_text().strip().lower() for th in ths) and len(tds) >= 2:
                data = tds
                break
    
    return data

def scrape_battle_page(battle_id, battle_name, wiki_link):
    """Scrape an individual battle page for country participant information."""
    print(f"Scraping battle page: {battle_name} (ID: {battle_id})")
    
    # Check if the wiki_link is already a full URL
    if not wiki_link.startswith("http"):
        url = urljoin(BASE_URL, wiki_link)
    else:
        url = wiki_link
    
    participants = []
    
    try:
        # Fetch the page
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Failed to fetch page: {url} (Status: {response.status_code})")
            return participants
        
        # Parse the HTML
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Find the infobox (try multiple classes)
        infobox = soup.find("table", {"class": ["infobox", "vevent", "vcard"]})
        if not infobox:
            print(f"No infobox found for {battle_name} at {url}")
            return participants
        
        # Extract result first to determine overall battle outcome
        result_text = ""
        result_data = extract_infobox_data(infobox, "result")
        if result_data:
            result_text = extract_html_content(result_data[0])
            print(f"Result: {result_text[:100]}...")
        
        # Extract belligerents
        belligerent_data = extract_infobox_data(infobox, "belligerent") or extract_infobox_data(infobox, "combatant")
        
        side1_countries = []
        side2_countries = []
        
        if len(belligerent_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(belligerent_data[0])
            print(f"Side 1 raw content: {side1_content[:100]}...")
            
            # Extract countries with improved extraction
            if side1_content:
                # First try to extract from list items if present
                parts = split_content_by_flags(side1_content)
                if parts:
                    for part in parts:
                        country = clean_country_name(part)
                        if country and country not in side1_countries:
                            side1_countries.append(country)
                else:
                    # Try extracting from the full content
                    extracted = extract_countries_from_text(side1_content)
                    side1_countries.extend([c for c in extracted if c not in side1_countries])
            
            # Process Side 2
            side2_content = extract_html_content(belligerent_data[1])
            print(f"Side 2 raw content: {side2_content[:100]}...")
            
            # Extract countries with improved extraction
            if side2_content:
                # First try to extract from list items if present
                parts = split_content_by_flags(side2_content)
                if parts:
                    for part in parts:
                        country = clean_country_name(part)
                        if country and country not in side2_countries:
                            side2_countries.append(country)
                else:
                    # Try extracting from the full content
                    extracted = extract_countries_from_text(side2_content)
                    side2_countries.extend([c for c in extracted if c not in side2_countries])
        
        # If no countries found, try harder with alternative approaches
        if not side1_countries and not side2_countries:
            # Get all text from the infobox
            infobox_text = infobox.get_text()
            
            # Try to identify common country names in the text
            common_countries = [
                "United States", "Germany", "France", "United Kingdom", "Great Britain",
                "Soviet Union", "Russia", "Japan", "Italy", "China", "Spain", "Austria",
                "Confederate States", "Union", "Prussia", "Ottoman Empire", "Turkey"
            ]
            
            found_countries = []
            for country in common_countries:
                if country in infobox_text:
                    found_countries.append(country)
            
            # If we found some countries, try to split them into sides
            if len(found_countries) >= 2:
                # Common historical pairings to guess sides
                opposing_pairs = [
                    (["United States", "United Kingdom", "France", "Russia", "Soviet Union"], 
                     ["Germany", "Japan", "Italy"]),
                    (["Union"], ["Confederate States"]),
                    (["United Kingdom", "Prussia", "Russia"], ["France"]),
                    (["United Kingdom", "France"], ["Spain"]),
                    (["Austria", "Prussia", "Russia"], ["Ottoman Empire", "Turkey"])
                ]
                
                for side1_candidates, side2_candidates in opposing_pairs:
                    side1_matches = [c for c in found_countries if c in side1_candidates]
                    side2_matches = [c for c in found_countries if c in side2_candidates]
                    
                    if side1_matches and side2_matches:
                        side1_countries = side1_matches
                        side2_countries = side2_matches
                        break
                
                # If we couldn't assign sides with pairs, just split the found countries
                if not side1_countries and not side2_countries and len(found_countries) >= 2:
                    middle = len(found_countries) // 2
                    side1_countries = found_countries[:middle]
                    side2_countries = found_countries[middle:]
        
        print(f"Side 1 countries: {side1_countries}")
        print(f"Side 2 countries: {side2_countries}")
        
        # Extract strength information
        strength_data = extract_infobox_data(infobox, "strength")
        
        side1_troops = None
        side2_troops = None
        
        if len(strength_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(strength_data[0])
            print(f"Side 1 strength raw: {side1_content[:100]}...")
            
            # Extract troop numbers with improved extraction
            if side1_content:
                # Try multiple keywords for troop counts
                keywords = ['men', 'troops', 'soldiers', 'personnel', 'combatants', 'infantry', 'army']
                side1_troops = extract_number(side1_content, keywords)
            
            # Process Side 2
            side2_content = extract_html_content(strength_data[1])
            print(f"Side 2 strength raw: {side2_content[:100]}...")
            
            # Extract troop numbers with improved extraction
            if side2_content:
                # Try multiple keywords for troop counts
                keywords = ['men', 'troops', 'soldiers', 'personnel', 'combatants', 'infantry', 'army']
                side2_troops = extract_number(side2_content, keywords)
        
        print(f"Side 1 troops: {side1_troops}")
        print(f"Side 2 troops: {side2_troops}")
        
        # Extract casualty information
        casualty_data = extract_infobox_data(infobox, "casualt") or extract_infobox_data(infobox, "loss")
        
        side1_deaths = None
        side2_deaths = None
        
        if len(casualty_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(casualty_data[0])
            print(f"Side 1 casualties raw: {side1_content[:100]}...")
            
            # Extract death numbers with improved extraction
            if side1_content:
                # Try multiple keywords for death counts
                keywords = ['killed', 'dead', 'deaths', 'fatalities', 'kia', 'killed in action']
                side1_deaths = extract_number(side1_content, keywords)
                
                # If no deaths found with keywords, try extracting other casualty numbers
                if side1_deaths is None:
                    side1_deaths = extract_number(side1_content, ['casualties', 'wounded', 'injured'])
            
            # Process Side 2
            side2_content = extract_html_content(casualty_data[1])
            print(f"Side 2 casualties raw: {side2_content[:100]}...")
            
            # Extract death numbers with improved extraction
            if side2_content:
                # Try multiple keywords for death counts
                keywords = ['killed', 'dead', 'deaths', 'fatalities', 'kia', 'killed in action']
                side2_deaths = extract_number(side2_content, keywords)
                
                # If no deaths found with keywords, try extracting other casualty numbers
                if side2_deaths is None:
                    side2_deaths = extract_number(side2_content, ['casualties', 'wounded', 'injured'])
        
        print(f"Side 1 deaths: {side1_deaths}")
        print(f"Side 2 deaths: {side2_deaths}")
        
        # Determine the result for each side based on the overall result
        side1_result, side2_result = determine_battle_result(result_text, side1_countries, side2_countries)
        
        print(f"Side 1 result: {side1_result}")
        print(f"Side 2 result: {side2_result}")
        
        # Add the participants
        for country in side1_countries:
            participants.append({
                "battle_id": battle_id,
                "country": country,
                "troops": side1_troops,
                "deaths": side1_deaths,
                "result": side1_result
            })
        
        for country in side2_countries:
            participants.append({
                "battle_id": battle_id,
                "country": country,
                "troops": side2_troops,
                "deaths": side2_deaths,
                "result": side2_result
            })
        
        print(f"Found {len(participants)} participants for {battle_name}")
        
        return participants
    
    except Exception as e:
        print(f"Error scraping {battle_name}: {e}")
        import traceback
        traceback.print_exc()
        return participants

def main():
    try:
        # Load the battles from the CSV file
        battles_df = load_battles_csv()
        
        # Create a list to store all participants
        all_participants = []
        
        # Process all battles or limit for testing
        max_battles = len(battles_df)  # Change this to limit the number of battles processed
        num_battles = min(len(battles_df), max_battles)
        
        print(f"Processing {num_battles} battles...")
        
        # Process each battle
        for index, battle in battles_df.head(num_battles).iterrows():
            battle_id = battle["battle_id"]
            battle_name = battle["battle_name"]
            wiki_link = battle["wiki_link"]
            
            # Skip if missing wiki link
            if pd.isna(wiki_link) or not wiki_link:
                print(f"Skipping battle {battle_name} (ID: {battle_id}) - Missing wiki link")
                continue
            
            # Scrape the battle page for country information
            participants = scrape_battle_page(battle_id, battle_name, wiki_link)
            
            # Add participants to the overall list
            all_participants.extend(participants)
            
            # Add a random delay to avoid rate limiting
            time.sleep(random.uniform(1.0, 3.0))
            
            # Print progress every 10 battles
            if (index + 1) % 10 == 0 or (index + 1) == num_battles:
                print(f"Progress: {index + 1}/{num_battles} battles processed ({((index + 1)/num_battles)*100:.1f}%)")
        
        # Create a DataFrame from the participants data
        if not all_participants:
            print("No participants found. Check the scraping logic.")
            return
        
        participants_df = pd.DataFrame(all_participants)
        
        # Add a unique participant_id as the primary key
        participants_df.reset_index(drop=True, inplace=True)
        participants_df['participant_id'] = participants_df.index + 1  # Start IDs from 1
        
        # Reorder columns to put participant_id first
        cols = ['participant_id', 'battle_id', 'country', 'troops', 'deaths', 'result']
        participants_df = participants_df[cols]
        
        # Save to CSV
        participants_df.to_csv("battle_info.csv", index=False)
        
        print(f"\n✅ Scraped {len(participants_df)} participant entries for {num_battles} battles.")
        print("Saved to 'battle_participants.csv'")
        
        # Print stats about data extraction
        troops_count = participants_df['troops'].notna().sum()
        deaths_count = participants_df['deaths'].notna().sum()
        result_count = participants_df[participants_df['result'] != "unknown"].shape[0]
        
        print(f"\nExtraction statistics:")
        print(f"- Participants with troop numbers: {troops_count} ({troops_count/len(participants_df)*100:.1f}%)")
        print(f"- Participants with death counts: {deaths_count} ({deaths_count/len(participants_df)*100:.1f}%)")
        print(f"- Participants with known results: {result_count} ({result_count/len(participants_df)*100:.1f}%)")
        
        # Show some sample data
        print("\nSample of participant data:")
        for i, row in participants_df.head(5).iterrows():
            print(f"{i+1}. Participant ID: {row['participant_id']}, Battle ID: {row['battle_id']}, Country: {row['country']}")
            print(f"   Troops: {row['troops'] if pd.notna(row['troops']) else 'Unknown'}")
            print(f"   Deaths: {row['deaths'] if pd.notna(row['deaths']) else 'Unknown'}")
            print(f"   Result: {row['result'] if pd.notna(row['result']) else 'Unknown'}")
    
    except Exception as e:
        print(f"\n❌ Error: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# Loaded 962 battles from battles_list.csv
# Processing 962 battles...
# Scraping battle page: Battle of Aachen (ID: 1)
# Result: American victory...
# Side 1 raw content: United States...
# Side 2 raw content: Germany...
# Side 1 countries: ['United States']
# Side 2 countries: ['Germany']
# Side 1 strength raw: 100,000 soldiers...
# Side 2 strength raw: 13,000 soldiers
#  5,000 Volkssturm...
# Side 1 troops: 100000
# Side 2 troops: 13000
# Side 1 casualties raw: 7,000+ casualties
#  including 2,000 killed...
# Side 2 casualties raw: 5,000 killed (estimate),
#  5,600 captured...
# Side 1 deaths: 2000
# Side 2 deaths: 5000
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Aachen
# Scraping battle page: Battle of Abensberg (ID: 2)
# Result: French victory...
# Side 1 raw content: First French Empire
#   Kingdom of Bavaria
#   Württemberg...
# Side 2 raw content: Austrian Empire...
# Side 1 countries: ['First French Empire', 'Kingdom of Bavaria', 'Württemberg']
# Side 2 countries: ['Austrian Empire']
# Side 1 strength raw: 55,000...
# Side 2 strength raw: 42,000...
# Side 1 troops: 55000
# Side 2 troops: 42000
# Side 1 casualties raw: 1,000...
# Side 2 casualties raw: 7,200, 12 guns...
# Side 1 deaths: 1000
# Side 2 deaths: 7200
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of Abensberg
# Scraping battle page: Battle of Abbeville (ID: 3)
# Result: German victory...
# Side 1 raw content: France
#   United Kingdom...
# Side 2 raw content: Germany...
# Side 1 countries: ['France', 'United Kingdom']
# Side 2 countries: ['Germany']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: 2,000 killed or captured
#  210 AFVs destroyed or captured...
# Side 2 casualties raw: 57th Infantry Division: 1,000 casualties including about 300 POW...
# Side 1 deaths: 2000
# Side 2 deaths: 1000
# Side 1 result: loser
# Side 2 result: winner
# Found 3 participants for Battle of Abbeville
# Scraping battle page: Battle of Abukir (ID: 4)
# Result: French victory...
# Side 1 raw content: France...
# Side 2 raw content: Ottoman Empire
#  Great Britain...
# Side 1 countries: ['France']
# Side 2 countries: ['Ottoman Empire', 'Great Britain']
# Side 1 strength raw: 9,000 infantry
#  1,000 cavalry
#  17 guns...
# Side 2 strength raw: 5,000 under Mustapha Pasha, 2,000 under Hassan Bey
#  7,000 in a state fit to fight according to the ...
# Side 1 troops: 9000
# Side 2 troops: 20000
# Side 1 casualties raw: 220 killed in action
#  600 wounded...
# Side 2 casualties raw: 2,000 killed in action
#  11,000 drowned
#  5,000 captured
#  2,000 missing and unaccounted for...
# Side 1 deaths: 220
# Side 2 deaths: 2000
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Battle of Abukir
# Scraping battle page: Battle of Abu Klea (ID: 5)
# Result: British victory...
# Side 1 raw content: United Kingdom
# • India...
# Side 2 raw content: Mahdist State...
# Side 1 countries: ['United Kingdom', 'India']
# Side 2 countries: ['Mahdist State']
# Side 1 strength raw: 1,400...
# Side 2 strength raw: 14,000 (3,000 engaged in the battle)...
# Side 1 troops: 1400
# Side 2 troops: 14000
# Side 1 casualties raw: 76 killed
#  82 wounded...
# Side 2 casualties raw: 1,100 killed, unknown wounded (British claim)...
# Side 1 deaths: 76
# Side 2 deaths: 1100
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Battle of Abu Klea
# Scraping battle page: Battle of Aclea (ID: 6)
# Result: West Saxon victory...
# Side 1 raw content: Kingdom of Wessex...
# Side 2 raw content: Kingdom of Denmark...
# Side 1 countries: ['Kingdom of Wessex']
# Side 2 countries: ['Kingdom of Denmark']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Aclea
# Scraping battle page: Battle of Acragas (ID: 7)
# Result: Carthaginian victory...
# Side 1 raw content: Carthage...
# Side 2 raw content: Akragas
#  Syracuse...
# Side 1 countries: ['Carthage']
# Side 2 countries: ['Akragas', 'Syracuse']
# Side 1 strength raw: 60,000
#  120 triremes
#  1,000 transport ships...
# Side 2 strength raw: 35,000
#  40 triremes
#  Supply convoy...
# Side 1 troops: 60000
# Side 2 troops: 35000
# Side 1 casualties raw: 6,000 killed
#  15 triremes lost...
# Side 2 casualties raw: 8 triremes sunk
#  Supply convoy captured
#  Population massacred...
# Side 1 deaths: 6000
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Acragas
# Scraping battle page: Siege of Acre (1189–1191) (ID: 8)
# Result: Crusader victory...
# Side 1 raw content: • Kingdom of England
# • Kingdom of France
# • Kingdom of Jerusalem • Knights Templar
# • Order Of St L...
# Side 2 raw content: Ayyubids...
# Side 1 countries: ['Kingdom of England', 'Kingdom of France', 'Kingdom of Jerusalem', 'Knights Templar', 'Order Of St Lazarus', 'Knights Hospitaller', 'Republic of Pisa', 'Kingdom of Sicily', 'Papal States', 'Holy Roman Empire', 'Duchy of Bohemia', 'Armenian Kingdom of Cilicia', 'Kingdom of Denmark', 'Republic of Genoa']
# Side 2 countries: ['Ayyubids']
# Side 1 strength raw: ...
# Side 2 strength raw: 45,000–50,000 men
# • Garrison: 5,000–10,000 men
# • Relief force:
# • 40,000 men
# • 50 galleys...
# Side 1 troops: None
# Side 2 troops: 50000
# Side 1 casualties raw: 19,000 dead...
# Side 2 casualties raw: ...
# Side 1 deaths: 19000
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 15 participants for Siege of Acre (1189–1191)
# Scraping battle page: Siege of Acre (1291) (ID: 9)
# Result: Mamluk victory • Collapse of the Crusader states...
# Side 1 raw content: Mamluk Sultanate
# • Ayyubid remnant emirate of Hama...
# Side 2 raw content: • Kingdom of Jerusalem (in union with Cyprus )
# • Knights Templar
# • Knights Hospitaller
# • Teutonic...
# Side 1 countries: ['Mamluk Sultanate', 'Ayyubid remnant emirate of Hama']
# Side 2 countries: ['Kingdom of Jerusalem', 'Knights Templar', 'Knights Hospitaller', 'Teutonic Order', 'Order of St. Thomas', 'Order of St. Lazarus']
# Side 1 strength raw: Unknown...
# Side 2 strength raw: Acre: 15,000 Cyprus: 700...
# Side 1 troops: None
# Side 2 troops: 15000
# Side 1 casualties raw: Unknown...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 8 participants for Siege of Acre (1291)
# Scraping battle page: Siege of Acre (1799) (ID: 10)
# Result: Anglo–Ottoman victory...
# Side 1 raw content: Ottoman Empire
#   Great Britain...
# Side 2 raw content: French Republic...
# Side 1 countries: ['Ottoman Empire', 'Great Britain']
# Side 2 countries: ['French Republic']
# Side 1 strength raw: Garrison : 5,000 men
#  Relief army ( Mt. Tabor ): 35,000 –40,000
#  Support : 2 British ships of the ...
# Side 2 strength raw: 12,000 –13,000...
# Side 1 troops: 5000
# Side 2 troops: 12500
# Side 1 casualties raw: 2,000 (for the siege)...
# Side 2 casualties raw: 4,000
#  or 4,500
# • 2,300 killed
# • 2,200 wounded or ill...
# Side 1 deaths: 2000
# Side 2 deaths: 2300
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Siege of Acre (1799)
# Progress: 10/962 battles processed (1.0%)
# Scraping battle page: Battle of the Admin Box (ID: 11)
# Result: Allied victory...
# Side 1 raw content: United Kingdom
# • British Raj...
# Side 2 raw content: Japan
# • Azad Hind...
# Side 1 countries: ['United Kingdom', 'British Raj']
# Side 2 countries: ['Japan', 'Azad Hind']
# Side 1 strength raw: At start:
#  2 infantry divisions
#  1 armoured regiment
#  Reinforcements:
#  2 infantry divisions...
# Side 2 strength raw: 1 infantry division...
# Side 1 troops: 1
# Side 2 troops: 1
# Side 1 casualties raw: 3,506 total
#  Several fighter aircraft...
# Side 2 casualties raw: 3,106 killed
#  2,229 wounded
#  Several fighter aircraft...
# Side 1 deaths: 3506
# Side 2 deaths: 3106
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of the Admin Box
# Scraping battle page: Battle of Akroinon (ID: 12)
# Result: Byzantine victory...
# Side 1 raw content: Umayyad Caliphate...
# Side 2 raw content: Byzantine Empire...
# Side 1 countries: ['Umayyad Caliphate']
# Side 2 countries: ['Byzantine Empire']
# Side 1 strength raw: 20,000...
# Side 2 strength raw: Unknown...
# Side 1 troops: 20000
# Side 2 troops: None
# Side 1 casualties raw: 13,200...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: 13200
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Akroinon
# Scraping battle page: Battle of Actium (ID: 13)
# Result: Octavian victory...
# Side 1 raw content: Octavian 's forces...
# Side 2 raw content: Antony 's forces
#  Ptolemaic Egypt...
# Side 1 countries: ["Octavian 's forces"]
# Side 2 countries: ["Antony 's forces", 'Ptolemaic Egypt']
# Side 1 strength raw: 250–400 galleys
#  3,000 archers
#  16,000 infantry on ships...
# Side 2 strength raw: 250–500 larger galleys
#  30–50 transports
#  20,000–70,000 infantry on ships
#  2,000 archers...
# Side 1 troops: 16000
# Side 2 troops: 70000
# Side 1 casualties raw: About 2,500 killed...
# Side 2 casualties raw: Over 5,000 killed
#  250 ships sunk or captured...
# Side 1 deaths: 2500
# Side 2 deaths: 5000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Actium
# Scraping battle page: Battle of Ad Decimum (ID: 14)
# Result: Byzantine victory...
# Side 1 raw content: Byzantine Empire...
# Side 2 raw content: Vandal Kingdom...
# Side 1 countries: ['Byzantine Empire']
# Side 2 countries: ['Vandal Kingdom']
# Side 1 strength raw: 18,000 men or 15,000 men...
# Side 2 strength raw: Greater than the Romans, 20,000 men at maximum. Most likely 10,000–12,000 men or 11,000 men....
# Side 1 troops: 18000
# Side 2 troops: 20000
# Side 1 casualties raw: 1,000? Still unknown modern estimate...
# Side 2 casualties raw: 3,000–4,000? Still unknown modern estimate...
# Side 1 deaths: 1000
# Side 2 deaths: 3500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Ad Decimum
# Scraping battle page: Battle of Adwa (ID: 15)
# Result: Ethiopian victory...
# Side 1 raw content: Ethiopia...
# Side 2 raw content: Italy...
# Side 1 countries: ['Ethiopia']
# Side 2 countries: ['Italy']
# Side 1 strength raw: 73,000–100,000...
# Side 2 strength raw: 14,519–17,770...
# Side 1 troops: 86500
# Side 2 troops: 16144
# Side 1 casualties raw: 3,886–7,000 killed...
# Side 2 casualties raw: ~6,000 killed
#  3,865 captured...
# Side 1 deaths: 7000
# Side 2 deaths: 6000
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Adwa
# Scraping battle page: Battle of Adwalton Moor (ID: 16)
# Result: Royalist Victory...
# Side 1 raw content: Royalists...
# Side 2 raw content: Parliamentarians...
# Side 1 countries: ['Royalists']
# Side 2 countries: ['Parliamentarians']
# Side 1 strength raw: 4,000 foot soldiers
#  3,000 horse...
# Side 2 strength raw: 6,000 foot soldiers
#  1,500 horse
#  Local countrymen...
# Side 1 troops: 4000
# Side 2 troops: 1500
# Side 1 casualties raw: 200 killed
#  300 wounded...
# Side 2 casualties raw: 500 killed
#  1,500 captured...
# Side 1 deaths: 200
# Side 2 deaths: 500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Adwalton Moor
# Scraping battle page: Battle of Aegina (ID: 17)
# Result: Arrangement between Sparta and Athens ratified by the " Thirty Years' Peace "...
# Side 1 raw content: Delian League led by Athens ,
#  Argos...
# Side 2 raw content: Peloponnesian League led by Sparta ,
#  Thebes...
# Side 1 countries: ['Delian League led by Athens', 'Argos']
# Side 2 countries: ['Peloponnesian League led by Sparta', 'Thebes']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Aegina
# Scraping battle page: Battle of Aegospotami (ID: 18)
# Result: • Decisive Spartan victory • Athens is besieged and surrenders
# • End of the Peloponnesian War...
# Side 1 raw content: ...
# Side 2 raw content: ...
# Side 1 countries: []
# Side 2 countries: []
# Side 1 strength raw: 170 ships...
# Side 2 strength raw: 180 ships 36,000 men...
# Side 1 troops: 170
# Side 2 troops: 36000
# Side 1 casualties raw: Minimal...
# Side 2 casualties raw: 160 ships,
#  3,000 sailors executed...
# Side 1 deaths: None
# Side 2 deaths: 3000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 0 participants for Battle of Aegospotami
# Scraping battle page: Battle of Agincourt (ID: 19)
# Result: English victory...
# Side 1 raw content: Kingdom of England...
# Side 2 raw content: Kingdom of France...
# Side 1 countries: ['Kingdom of England']
# Side 2 countries: ['Kingdom of France']
# Side 1 strength raw: 6,000 –8,100 men
#  (modern estimates; see Numbers at Agincourt )
#  • About 5 ⁄ 6 archers
#  •...
# Side 2 strength raw: 14,000–15,000 men or up to 25,000 if counting armed servants
#  • 10,000 men-at-arms
#  • 4,000–5,000 ...
# Side 1 troops: 8100
# Side 2 troops: 15000
# Side 1 casualties raw: Up to 600 killed (112 identified)...
# Side 2 casualties raw: • 6,000 killed (most of whom were of the French nobility)
#  • 700–2,200 captured...
# Side 1 deaths: 600
# Side 2 deaths: 6000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Agincourt
# Scraping battle page: Battle of Agnadello (ID: 20)
# Result: French victory...
# Side 1 raw content: Kingdom of France...
# Side 2 raw content: Republic of Venice...
# Side 1 countries: ['Kingdom of France']
# Side 2 countries: ['Republic of Venice']
# Side 1 strength raw: 30,000...
# Side 2 strength raw: 15,000...
# Side 1 troops: 30000
# Side 2 troops: 15000
# Side 1 casualties raw: 500...
# Side 2 casualties raw: 10,000+...
# Side 1 deaths: 500
# Side 2 deaths: 10000
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Agnadello
# Progress: 20/962 battles processed (2.1%)
# Scraping battle page: Battle of Agusan Hill (ID: 21)
# Result: American victory...
# Side 1 raw content: First Philippine Republic...
# Side 2 raw content: United States...
# Side 1 countries: ['First Philippine Republic']
# Side 2 countries: ['United States']
# Side 1 strength raw: 500...
# Side 2 strength raw: 80...
# Side 1 troops: 500
# Side 2 troops: 80
# Side 1 casualties raw: 38 killed...
# Side 2 casualties raw: 2 killed; 3 wounded...
# Side 1 deaths: 38
# Side 2 deaths: 2
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Agusan Hill
# Scraping battle page: Battle of Ahvenanmaa (ID: 22)
# Result: Russian victory...
# Side 1 raw content: Swedish Empire...
# Side 2 raw content: • Tsardom of Russia
# • Navy...
# Side 1 countries: ['Swedish Empire']
# Side 2 countries: ['Tsardom of Russia', 'Navy']
# Side 1 strength raw: 1 pram
#  6 galleys
#  2 skerry boats
#  941–2,400 men...
# Side 2 strength raw: 98 galleys , of which 23 engaged, with about 3,900 men aboard...
# Side 1 troops: 2400
# Side 2 troops: 3900
# Side 1 casualties raw: All ships captured or sunk
#  361 killed
#  580 captured –2,400 killed or captured...
# Side 2 casualties raw: Russian accounts :
#  125 killed, 341 wounded
#  Swedish accounts :
#  3,000 men, 50+ galleys...
# Side 1 deaths: 361
# Side 2 deaths: 125
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Ahvenanmaa
# Scraping battle page: Battle of Ain Jalut (ID: 23)
# Result: Mamluk victory...
# Side 1 raw content: • Mamluk Sultanate
# • Ayyubid emirs of Kerak and Hamah...
# Side 2 raw content: • Ilkhanate
# • Cilician Armenia
# • Kingdom of Georgia...
# Side 1 countries: ['Mamluk Sultanate', 'Ayyubid emirs of Kerak and Hamah']
# Side 2 countries: ['Ilkhanate', 'Cilician Armenia', 'Kingdom of Georgia']
# Side 1 strength raw: 15,000–20,000...
# Side 2 strength raw: 10,000–20,000...
# Side 1 troops: 17500
# Side 2 troops: 15000
# Side 1 casualties raw: Unknown...
# Side 2 casualties raw: High...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 5 participants for Battle of Ain Jalut
# Scraping battle page: First Battle of the Aisne (ID: 24)
# Result: Indecisive...
# Side 1 raw content: France
#   United Kingdom...
# Side 2 raw content: German Empire...
# Side 1 countries: ['France', 'United Kingdom']
# Side 2 countries: ['German Empire']
# Side 1 strength raw: Fifth Army
#   Sixth Army
#   BEF...
# Side 2 strength raw: First Army
#   Second Army
#   Seventh Army...
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: Unknown
#   13,541 killed or wounded...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: 13541
# Side 2 deaths: None
# Side 1 result: tied
# Side 2 result: tied
# Found 3 participants for First Battle of the Aisne
# Scraping battle page: Second Battle of the Aisne (ID: 25)
# Result: Inconclusive...
# Side 1 raw content: France
#  Russia...
# Side 2 raw content: Germany...
# Side 1 countries: ['France', 'Russia']
# Side 2 countries: ['Germany']
# Side 1 strength raw: 53 French divisions
#  4 Russian divisions...
# Side 2 strength raw: 38 divisions...
# Side 1 troops: 53
# Side 2 troops: None
# Side 1 casualties raw: 187,000...
# Side 2 casualties raw: 163,000...
# Side 1 deaths: 187000
# Side 2 deaths: 163000
# Side 1 result: tied
# Side 2 result: tied
# Found 3 participants for Second Battle of the Aisne
# Scraping battle page: Third Battle of the Aisne (ID: 26)
# Result: See Aftermath section...
# Side 1 raw content: France
#  United Kingdom
#  United States
#   Italy...
# Side 2 raw content: German Empire...
# Side 1 countries: ['France', 'United Kingdom', 'United States', 'Italy']
# Side 2 countries: ['German Empire']
# Side 1 strength raw: ...
# Side 2 strength raw: (over 20 divisions and 4,000 artillery guns)...
# Side 1 troops: None
# Side 2 troops: 4000
# Side 1 casualties raw: 127,000...
# Side 2 casualties raw: 130,000...
# Side 1 deaths: 127000
# Side 2 deaths: 130000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 5 participants for Third Battle of the Aisne
# Scraping battle page: Battle of Ajnadayn (ID: 27)
# Result: Muslim victory...
# Side 1 raw content: Byzantine Empire...
# Side 2 raw content: Rashidun Caliphate...
# Side 1 countries: ['Byzantine Empire']
# Side 2 countries: ['Rashidun Caliphate']
# Side 1 strength raw: Max. 40,000 – 100...
# Side 2 strength raw: Max. 500 – 20,000...
# Side 1 troops: 20050
# Side 2 troops: 10250
# Side 1 casualties raw: 50,000 killed
#  ( Al-Waqidi ),
#  Modern estimates unknown....
# Side 2 casualties raw: 5,000 ( Al-Waqidi )
#  Modern estimates unknown....
# Side 1 deaths: 50000
# Side 2 deaths: 5000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Ajnadayn
# Scraping battle page: Battle of Akraba (632) (ID: 28)
# Result: Muslim victory...
# Side 1 raw content: Rashidun Caliphate...
# Side 2 raw content: Banu Hanifa and Musaylima's followers...
# Side 1 countries: ['Rashidun Caliphate']
# Side 2 countries: ["Banu Hanifa and Musaylima's followers"]
# Side 1 strength raw: 10,000-13,000...
# Side 2 strength raw: 50,000-100,000...
# Side 1 troops: 11500
# Side 2 troops: 75000
# Side 1 casualties raw: 1,200...
# Side 2 casualties raw: 10,000-21,000...
# Side 1 deaths: 1200
# Side 2 deaths: 15500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Akraba (632)
# Scraping battle page: Battle of Alalia (ID: 29)
# Result: Greek victory...
# Side 1 raw content: Phocaeans...
# Side 2 raw content: Carthage
#  Etruscans...
# Side 1 countries: ['Phocaeans']
# Side 2 countries: ['Carthage', 'Etruscans']
# Side 1 strength raw: 60 Pentekonters...
# Side 2 strength raw: Around 120 Ships...
# Side 1 troops: 60
# Side 2 troops: 120
# Side 1 casualties raw: Almost 40 Pentekonters...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Alalia
# Scraping battle page: Battle of Alamance (ID: 30)
# Result: Government victory...
# Side 1 raw content: North Carolina...
# Side 2 raw content: Regulators...
# Side 1 countries: ['North Carolina']
# Side 2 countries: ['Regulators']
# Side 1 strength raw: ~1,000...
# Side 2 strength raw: ~2,000...
# Side 1 troops: 1000
# Side 2 troops: 2000
# Side 1 casualties raw: 9-27 killed
#  61 wounded...
# Side 2 casualties raw: 100 killed
#  ~200 wounded...
# Side 1 deaths: 27
# Side 2 deaths: 100
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Alamance
# Progress: 30/962 battles processed (3.1%)
# Scraping battle page: Battle of al-Bab (ID: 31)
# Result: Turkish and SNA victory
# • Turkish Armed Forces and Syrian National Army /allied Syrian rebels captu...
# Side 1 raw content: Turkey
#   Syrian National Army
#  Support:
#   Russia
#   United States (against ISIL only, since 17 Ja...
# Side 2 raw content: Islamic State...
# Side 1 countries: ['Turkey', 'Syrian National Army', 'Support:', 'Russia', 'United States (against ISIL only', 'since 17 Jan. 2017)']
# Side 2 countries: ['Islamic State']
# Side 1 strength raw: 1,300–4,000 soldiers
#  40 tanks originally, 10 reinforcements
#  15+ APCs
#   2,000–3,000 rebel fighte...
# Side 2 strength raw: 3,000–5,000 militants...
# Side 1 troops: 10
# Side 2 troops: 4000
# Side 1 casualties raw: 59 killed
#  8-10 Leopard 2 tanks destroyed, at least 2 captured
#   500+ killed...
# Side 2 casualties raw: 1,348+ killed...
# Side 1 deaths: 59
# Side 2 deaths: 1348
# Side 1 result: winner
# Side 2 result: loser
# Found 7 participants for Battle of al-Bab
# Scraping battle page: Battle of Alam el Halfa (ID: 32)
# Result: British victory...
# Side 1 raw content: United Kingdom
#  New Zealand...
# Side 2 raw content: Germany
#   Italy...
# Side 1 countries: ['United Kingdom', 'New Zealand']
# Side 2 countries: ['Germany', 'Italy']
# Side 1 strength raw: XIII Corps ( Eighth Army ):
#  4 divisions...
# Side 2 strength raw: Panzer Army Africa :
#  6 divisions...
# Side 1 troops: 4
# Side 2 troops: 6
# Side 1 casualties raw: 1,750 killed, wounded or captured
#  68 tanks
#  67 aircraft...
# Side 2 casualties raw: 2,900 killed, wounded or captured
#  49 tanks
#  36 aircraft
#  60 guns
#  400 transport vehicles...
# Side 1 deaths: 1750
# Side 2 deaths: 2900
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of Alam el Halfa
# Scraping battle page: Battle of the Alamo (ID: 33)
# Result: Mexican victory...
# Side 1 raw content: Mexico...
# Side 2 raw content: Republic of Texas...
# Side 1 countries: ['Mexico']
# Side 2 countries: ['Republic of Texas']
# Side 1 strength raw: ~2,000–2,100...
# Side 2 strength raw: 185–260...
# Side 1 troops: 2050
# Side 2 troops: 222
# Side 1 casualties raw: Mexican official version
#  60 killed and 250 wounded
#  Texan estimation
#  400–600 killed and wounded...
# Side 2 casualties raw: 182–257 killed...
# Side 1 deaths: 60
# Side 2 deaths: 257
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of the Alamo
# Scraping battle page: Battle of Aldenhoven (1794) (ID: 34)
# Result: French victory...
# Side 1 raw content: French Republic...
# Side 2 raw content: Habsburg monarchy...
# Side 1 countries: ['French Republic']
# Side 2 countries: ['Habsburg monarchy']
# Side 1 strength raw: 88,000...
# Side 2 strength raw: 77,000...
# Side 1 troops: 88000
# Side 2 troops: 77000
# Side 1 casualties raw: 1,500 killed or wounded...
# Side 2 casualties raw: 3,000 killed or wounded
#  800 captured...
# Side 1 deaths: 1500
# Side 2 deaths: 3000
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Aldenhoven (1794)
# Scraping battle page: El Alamein (ID: 35)
# Side 1 countries: []
# Side 2 countries: []
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 0 participants for El Alamein
# Scraping battle page: Battle of Albarracin (ID: 36)
# Result: Nationalist victory...
# Side 1 raw content: Spanish Republic...
# Side 2 raw content: Nationalist Spain...
# Side 1 countries: ['Spanish Republic']
# Side 2 countries: ['Nationalist Spain']
# Side 1 strength raw: 42nd Division
#  8,000–9,500...
# Side 2 strength raw: ?...
# Side 1 troops: 8750
# Side 2 troops: None
# Side 1 casualties raw: High...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Albarracin
# Scraping battle page: Battle of Alesia (ID: 37)
# Result: • Roman victory
# • Rome completes its conquest of Gaul...
# Side 1 raw content: Roman Republic...
# Side 2 raw content: Gallic confederation...
# Side 1 countries: ['Roman Republic']
# Side 2 countries: ['Gallic confederation']
# Side 1 strength raw: 10–11 legions (30–50,000 legionaries)
#  10,000 auxiliaries 60,000–75,000 approx. total Romans and al...
# Side 2 strength raw: 328,000–470,000 total (ancient sources) • 80,000–170,000 besieged
# • 248,000–300,000 relief forces <...
# Side 1 troops: 10
# Side 2 troops: 399000
# Side 1 casualties raw: 12,800 killed and wounded...
# Side 2 casualties raw: 290,000 (Caesar, exaggerated) • 250,000 killed
# • 40,000 captured...
# Side 1 deaths: 12800
# Side 2 deaths: 250000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Alesia
# Scraping battle page: Battle of Alexandria (ID: 38)
# Result: British victory...
# Side 1 raw content: United Kingdom...
# Side 2 raw content: France...
# Side 1 countries: ['United Kingdom']
# Side 2 countries: ['France']
# Side 1 strength raw: 12,000 –14,200...
# Side 2 strength raw: 10,000 –16,000...
# Side 1 troops: 13100
# Side 2 troops: 13000
# Side 1 casualties raw: 243 killed
#  1,253 wounded
#  32 missing...
# Side 2 casualties raw: 1,700 –5,000...
# Side 1 deaths: 243
# Side 2 deaths: 3350
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Alexandria
# Scraping battle page: First Battle of El Alamein (ID: 39)
# Result: Inconclusive...
# Side 1 raw content: Italy
#   Germany...
# Side 2 raw content: United Kingdom
#   India
#  New Zealand
#   Australia
#   South Africa...
# Side 1 countries: ['Italy', 'Germany']
# Side 2 countries: ['United Kingdom', 'India', 'New Zealand', 'Australia', 'South Africa']
# Side 1 strength raw: 96,000 troops (56,000 Italian, 40,000 German)
#  70 tanks initially (585 tanks later)
#  ~500 planes...
# Side 2 strength raw: 150,000 troops
#  179 tanks initially (1,114 tanks later)
#  1,000+ artillery pieces
#  1,500+ planes...
# Side 1 troops: 96000
# Side 2 troops: 150000
# Side 1 casualties raw: 10,000 killed or wounded
#  7,000 prisoners...
# Side 2 casualties raw: 13,250 killed or wounded...
# Side 1 deaths: 10000
# Side 2 deaths: 13250
# Side 1 result: tied
# Side 2 result: tied
# Found 7 participants for First Battle of El Alamein
# Scraping battle page: Second Battle of El Alamein (ID: 40)
# Result: Allied victory...
# Side 1 raw content: British Empire
# • United Kingdom
# • India
# • Australia
# • New Zealand
# • South Africa
# • Libyan Arab...
# Side 2 raw content: Italy
#  Germany...
# Side 1 countries: ['British Empire', 'United Kingdom', 'India', 'Australia', 'New Zealand', 'South Africa', 'Libyan Arab Force Free France Greece Air support: United States']
# Side 2 countries: ['Italy', 'Germany']
# Side 1 strength raw: 195,000
#  1,029 tanks
#  435 armoured cars
#  730 – 750 aircraft
#  892 – 908 artillery guns
#  1,451 an...
# Side 2 strength raw: 116,000
#  547 tanks
#  192 armoured cars
#  770 – 900 aircraft
#  552 artillery pieces
#  496 – 1,063 an...
# Side 1 troops: 740
# Side 2 troops: 835
# Side 1 casualties raw: 13,560 killed, wounded, captured, and missing
#  332–500 tanks destroyed
#  111 guns destroyed
#  97 ai...
# Side 2 casualties raw: 2,000–9,000 dead or missing, 4,800–15,000 wounded, 35,000–49,000 captured
#  500 tanks destroyed
#  25...
# Side 1 deaths: 13560
# Side 2 deaths: 9000
# Side 1 result: winner
# Side 2 result: loser
# Found 9 participants for Second Battle of El Alamein
# Progress: 40/962 battles processed (4.2%)
# Scraping battle page: Battle of Alessandria (ID: 41)
# Result: Milanese victory...
# Side 1 raw content: Lordship of Milan...
# Side 2 raw content: Republic of Florence...
# Side 1 countries: ['Lordship of Milan']
# Side 2 countries: ['Republic of Florence']
# Side 1 strength raw: 10,000 (incl. 6,000 knights)...
# Side 2 strength raw: 10,500 (incl. 7,500 knights)...
# Side 1 troops: 10000
# Side 2 troops: 10500
# Side 1 casualties raw: Unknown...
# Side 2 casualties raw: Thousands killed 6,000 captured...
# Side 1 deaths: None
# Side 2 deaths: 6000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Alessandria
# Scraping battle page: Battle of Alfambra (ID: 42)
# Result: Nationalist victory...
# Side 1 raw content: Spanish Republic...
# Side 2 raw content: Nationalist Spain
#  Italy
#   Germany...
# Side 1 countries: ['Spanish Republic']
# Side 2 countries: ['Nationalist Spain', 'Italy', 'Germany']
# Side 1 strength raw: Fewer than 50,000
#  120 fighters
#  80 bombers...
# Side 2 strength raw: 100,000
#  500 guns
#  150 fighters
#  100 bombers...
# Side 1 troops: 50000
# Side 2 troops: 100000
# Side 1 casualties raw: 20,000 –22,000...
# Side 2 casualties raw: ?...
# Side 1 deaths: 21000
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Alfambra
# Scraping battle page: Battle of Alfarrobeira (ID: 43)
# Result: Rebellion suppressed;
#  Supremacy of the main line of the House of Aviz preserved...
# Side 1 raw content: Kingdom of Portugal House of Braganza...
# Side 2 raw content: Coimbra Rebels...
# Side 1 countries: ['Kingdom of Portugal House of Braganza']
# Side 2 countries: ['Coimbra Rebels']
# Side 1 strength raw: 30,000 men...
# Side 2 strength raw: 6,000 men:
#  • 5,000 infantry
#  • 1,000 cavalry...
# Side 1 troops: 30000
# Side 2 troops: 6000
# Side 1 casualties raw: 500 dead or wounded...
# Side 2 casualties raw: 4,000 dead, wounded, or captured...
# Side 1 deaths: 500
# Side 2 deaths: 4000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Alfarrobeira
# Scraping battle page: Battle of Algeciras (ID: 44)
# Result: Castillian victory...
# Side 1 raw content: Marinid Dynasty
#   Emirate of Granada...
# Side 2 raw content: Crown of Castile
#   Republic of Genoa
#   Kingdom of Aragon
#   Kingdom of Portugal
#   Kingdom of Nava...
# Side 1 countries: ['Marinid Dynasty', 'Emirate of Granada']
# Side 2 countries: ['Crown of Castile', 'Republic of Genoa', 'Kingdom of Aragon', 'Kingdom of Portugal', 'Kingdom of Navarre', 'European crusaders']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 8 participants for Battle of Algeciras
# Scraping battle page: Battle of Aljubarrota (ID: 45)
# Result: Portuguese victory...
# Side 1 raw content: Kingdom of Portugal
#  Supported by:
#  Kingdom of England...
# Side 2 raw content: Crown of Castile
#  Supported by:
#  Kingdom of France
#  Crown of Aragon
#  Genoese mercenaries...
# Side 1 countries: ['Kingdom of Portugal', 'Supported by:', 'Kingdom of England']
# Side 2 countries: ['Crown of Castile', 'Supported by:', 'Kingdom of France', 'Crown of Aragon', 'Genoese mercenaries']
# Side 1 strength raw: About 6,600 men:
# • 4,000 foot soldiers
# • 1,700 lances
# • 800 crossbowmen
# • 200 English longbowmen...
# Side 2 strength raw: About 31,000 men:
# • 15,000 foot soldiers
# • 6,000 lances
# • 8,000 crossbowmen
# • More than 2,000 Fr...
# Side 1 troops: 6600
# Side 2 troops: 31000
# Side 1 casualties raw: Fewer than 1,000...
# Side 2 casualties raw: 4,000–5,000
#  5,000 in the aftermath...
# Side 1 deaths: 1000
# Side 2 deaths: 4500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 8 participants for Battle of Aljubarrota
# Scraping battle page: Battle of Alma (ID: 46)
# Result: Allied victory...
# Side 1 raw content: Britain
#   France
#   Ottoman Empire...
# Side 2 raw content: Russia...
# Side 1 countries: ['Britain', 'France', 'Ottoman Empire']
# Side 2 countries: ['Russia']
# Side 1 strength raw: 56,500 –58,000...
# Side 2 strength raw: 37,500...
# Side 1 troops: 57250
# Side 2 troops: 37500
# Side 1 casualties raw: 4,103 killed and wounded...
# Side 2 casualties raw: ~5,000 killed and wounded...
# Side 1 deaths: 4103
# Side 2 deaths: 5000
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of Alma
# Scraping battle page: Battle of Almansa (ID: 47)
# Result: Franco-Spanish victory...
# Side 1 raw content: Spain
#   France...
# Side 2 raw content: England
#  Portugal
#  Dutch Republic...
# Side 1 countries: ['Spain', 'France']
# Side 2 countries: ['England', 'Portugal', 'Dutch Republic']
# Side 1 strength raw: 21,000 to 25,000...
# Side 2 strength raw: 16,000 to 16,500...
# Side 1 troops: 21000
# Side 2 troops: 16000
# Side 1 casualties raw: 1,500 to 2,000 killed or wounded...
# Side 2 casualties raw: 7,000 killed, wounded or captured...
# Side 1 deaths: 2000
# Side 2 deaths: 7000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 5 participants for Battle of Almansa
# Scraping battle page: Battle of Almendralejo (ID: 48)
# No infobox found for Battle of Almendralejo at https://en.wikipedia.org/wiki/Battle_of_Almendralejo
# Scraping battle page: Battle of Almonacid (ID: 49)
# Result: French victory...
# Side 1 raw content: France
#   Duchy of Warsaw...
# Side 2 raw content: Spain...
# Side 1 countries: ['France', 'Duchy of Warsaw']
# Side 2 countries: ['Spain']
# Side 1 strength raw: 28,797...
# Side 2 strength raw: 28,107...
# Side 1 troops: 28797
# Side 2 troops: 28107
# Side 1 casualties raw: 2,400...
# Side 2 casualties raw: 3,300–3,500 killed & wounded
#  2,000 captured
#  20–21 guns lost
#  Total :
#  5,500...
# Side 1 deaths: 2400
# Side 2 deaths: 3500
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Battle of Almonacid
# Scraping battle page: Battle of Al-Safra (ID: 50)
# Result: Saudi victory...
# Side 1 raw content: Ottoman Empire...
# Side 2 raw content: Emirate of Diriyah...
# Side 1 countries: ['Ottoman Empire']
# Side 2 countries: ['Emirate of Diriyah']
# Side 1 strength raw: 8,000–14,000 men...
# Side 2 strength raw: 18,000 men
#  800 Cavalry...
# Side 1 troops: 14000
# Side 2 troops: 18000
# Side 1 casualties raw: 4,000–5,000 killed
#  7 Cannons captured...
# Side 2 casualties raw: 600 killed...
# Side 1 deaths: 5000
# Side 2 deaths: 600
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Al-Safra
# Progress: 50/962 battles processed (5.2%)
# Scraping battle page: Battle of Ambarawa (ID: 51)
# Result: • Indonesian victory
# • Withdrawal of all British troops from Magelang , and Ambarawa ....
# Side 1 raw content: Indonesia...
# Side 2 raw content: • United Kingdom
# • British Raj Supported by:
#   Netherlands...
# Side 1 countries: ['Indonesia']
# Side 2 countries: ['United Kingdom', 'British Raj Supported by: Netherlands']
# Side 1 strength raw: 10,000+ (Ambarawa)...
# Side 2 strength raw: Unknown...
# Side 1 troops: 10000
# Side 2 troops: None
# Side 1 casualties raw: 2,000 killed...
# Side 2 casualties raw: 100 killed (Ambarawa)...
# Side 1 deaths: 2000
# Side 2 deaths: 100
# Side 1 result: tied
# Side 2 result: tied
# Found 3 participants for Battle of Ambarawa
# Scraping battle page: Battle of Amberg (ID: 52)
# Result: Austrian victory, turning point in the campaign...
# Side 1 raw content: Republican France...
# Side 2 raw content: Habsburg monarchy...
# Side 1 countries: ['Republican France']
# Side 2 countries: ['Habsburg monarchy']
# Side 1 strength raw: 34,000...
# Side 2 strength raw: 40,000...
# Side 1 troops: 34000
# Side 2 troops: 40000
# Side 1 casualties raw: 2,000...
# Side 2 casualties raw: 400...
# Side 1 deaths: 2000
# Side 2 deaths: 400
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Amberg
# Scraping battle page: Battle of Amiens (ID: 53)
# Result: German victory...
# Side 1 raw content: North German Confederation
# • Prussia...
# Side 2 raw content: French Republic...
# Side 1 countries: ['North German Confederation', 'Prussia']
# Side 2 countries: ['French Republic']
# Side 1 strength raw: 43,000...
# Side 2 strength raw: 25,000...
# Side 1 troops: 43000
# Side 2 troops: 25000
# Side 1 casualties raw: 1,292 killed or wounded
#  300 missing...
# Side 2 casualties raw: 1,383 killed or wounded
#  1,000 soldiers missing...
# Side 1 deaths: 1292
# Side 2 deaths: 1383
# Side 1 result: loser
# Side 2 result: winner
# Found 3 participants for Battle of Amiens
# Scraping battle page: Battle of Amiens (ID: 54)
# Result: Allied victory
# • Start of Hundred Days Offensive...
# Side 1 raw content: British Empire
# • United Kingdom
# • Australia
# • Canada France
#  United States...
# Side 2 raw content: German Empire...
# Side 1 countries: ['British Empire', 'United Kingdom', 'Australia', 'Canada France United States']
# Side 2 countries: ['German Empire']
# Side 1 strength raw: ...
# Side 2 strength raw: ...
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: ...
# Side 2 casualties raw: 45,000 killed or wounded
#  29,873 captured...
# Side 1 deaths: None
# Side 2 deaths: 45000
# Side 1 result: winner
# Side 2 result: loser
# Found 5 participants for Battle of Amiens
# Scraping battle page: Battle of Amphipolis (ID: 55)
# Result: Spartan victory...
# Side 1 raw content: Athens...
# Side 2 raw content: Sparta...
# Side 1 countries: ['Athens']
# Side 2 countries: ['Sparta']
# Side 1 strength raw: About 2,000...
# Side 2 strength raw: About 2,500...
# Side 1 troops: 2000
# Side 2 troops: 2500
# Side 1 casualties raw: About 600...
# Side 2 casualties raw: 7...
# Side 1 deaths: 600
# Side 2 deaths: None
# Side 1 result: loser
# Side 2 result: winner
# Found 2 participants for Battle of Amphipolis
# Scraping battle page: Battle of Amstetten (ID: 56)
# Result: Inconclusive...
# Side 1 raw content: France...
# Side 2 raw content: Habsburg Empire
#   Russia...
# Side 1 countries: ['France']
# Side 2 countries: ['Habsburg Empire', 'Russia']
# Side 1 strength raw: Around 10,000 soldiers...
# Side 2 strength raw: 6,700–7,900 soldiers...
# Side 1 troops: 10000
# Side 2 troops: 7900
# Side 1 casualties raw: 1,000...
# Side 2 casualties raw: Russian Empire:
#  300 killed or wounded
#  <700 prisoners
#  Austrian Empire:
#  1,000 killed, wounded,...
# Side 1 deaths: 1000
# Side 2 deaths: 300
# Side 1 result: tied
# Side 2 result: tied
# Found 3 participants for Battle of Amstetten
# Scraping battle page: Battle of Angaur (ID: 57)
# Result: American victory...
# Side 1 raw content: United States...
# Side 2 raw content: Japan...
# Side 1 countries: ['United States']
# Side 2 countries: ['Japan']
# Side 1 strength raw: 10,000...
# Side 2 strength raw: 1,400...
# Side 1 troops: 10000
# Side 2 troops: 1400
# Side 1 casualties raw: 264 killed
#  1,354 wounded...
# Side 2 casualties raw: 1,350 killed
#  50 captured...
# Side 1 deaths: 264
# Side 2 deaths: 1350
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Angaur
# Scraping battle page: Battle of Ankara (ID: 58)
# Result: Timurid victory...
# Side 1 raw content: Timurid Empire
#  Aq Qoyunlu
#  Germiyanids...
# Side 2 raw content: Ottoman Sultanate
#  Principality of Kastrioti
#  Moravian Serbia
#  District of Branković
#  Anatolian ...
# Side 1 countries: ['Timurid Empire', 'Aq Qoyunlu', 'Germiyanids']
# Side 2 countries: ['Ottoman Sultanate', 'Principality of Kastrioti', 'Moravian Serbia', 'District of Branković', 'Anatolian beyliks and Black Tatars']
# Side 1 strength raw: 140,000...
# Side 2 strength raw: 85,000 –120,000...
# Side 1 troops: 140000
# Side 2 troops: 102500
# Side 1 casualties raw: 15,000–40,000...
# Side 2 casualties raw: 40,000 –50,000...
# Side 1 deaths: 27500
# Side 2 deaths: 45000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 8 participants for Battle of Ankara
# Scraping battle page: Battle of Antietam (ID: 59)
# Result: Union victory (see aftermath )...
# Side 1 raw content: United States ( Union )...
# Side 2 raw content: Confederate States...
# Side 1 countries: ['United States']
# Side 2 countries: ['Confederate States']
# Side 1 strength raw: 53,632 engaged 275 artillery...
# Side 2 strength raw: 30,646 engaged 194 artillery...
# Side 1 troops: 53632
# Side 2 troops: 30646
# Side 1 casualties raw: 12,410
#  2,108 killed
#  9,549 wounded
#  753 captured/missing...
# Side 2 casualties raw: 10,337
#  1,567 killed
#  7,752 wounded
#  1,018 captured/missing...
# Side 1 deaths: 2108
# Side 2 deaths: 1567
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Antietam
# Scraping battle page: Battle of Antioch (218) (ID: 60)
# Result: Victory for Elagabalus...
# Side 1 raw content: Macrinus...
# Side 2 raw content: Elagabalus...
# Side 1 countries: ['Macrinus']
# Side 2 countries: ['Elagabalus']
# Side 1 strength raw: Elements of the
#  Praetorian Guard...
# Side 2 strength raw: Legio III Gallica
#  Legio II Parthica
#  Other rebels...
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: loser
# Side 2 result: winner
# Found 2 participants for Battle of Antioch (218)
# Progress: 60/962 battles processed (6.2%)
# Scraping battle page: Battle of Antioch (1097) (ID: 61)
# Result: Crusader victory...
# Side 1 raw content: Crusaders
#  Byzantine Empire...
# Side 2 raw content: Seljuk Empire
# • Emirate of Antioch
# • Emirate of Damascus
# • Emirate of Homs
# • Sultanate of Aleppo...
# Side 1 countries: ['Crusaders', 'Byzantine Empire']
# Side 2 countries: ['Seljuk Empire', 'Emirate of Antioch', 'Emirate of Damascus', 'Emirate of Homs', 'Sultanate of Aleppo', 'Emirate of Mosul', 'Various other Arab or Turkish Emirates']
# Side 1 strength raw: Crusaders :
#  ~40,000 total at the start of the siege (includes non-combatants)
#  ~20,000 during the...
# Side 2 strength raw: Antiochene garrison :
#  ~5,000
#  Duqaq's relief force : ~10,000
#  Radwan's relief force : ~12,000
#  ...
# Side 1 troops: 0
# Side 2 troops: 37500
# Side 1 casualties raw: Heavy
# • Thousands died of starvation, disease or in battle
# • Nearly all the horses...
# Side 2 casualties raw: Heavy
# • Entire garrison slain
# • Every relief force destroyed and routed...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 9 participants for Battle of Antioch (1097)
# Scraping battle page: Siege of Antioch (1268) (ID: 62)
# Result: Mamluk victory...
# Side 1 raw content: Mamluk Sultanate...
# Side 2 raw content: Principality of Antioch...
# Side 1 countries: ['Mamluk Sultanate']
# Side 2 countries: ['Principality of Antioch']
# Side 1 strength raw: Approx. 15,000...
# Side 2 strength raw: Approx. 7,500...
# Side 1 troops: 15000
# Side 2 troops: 7500
# Side 1 casualties raw: Unknown...
# Side 2 casualties raw: 17,000 slaughtered 100,000 enslaved...
# Side 1 deaths: None
# Side 2 deaths: 17000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Siege of Antioch (1268)
# Scraping battle page: Battle of Antwerp (1584) (ID: 63)
# Result: Spanish victory...
# Side 1 raw content: Estates General...
# Side 2 raw content: Spain...
# Side 1 countries: ['Estates General']
# Side 2 countries: ['Spain']
# Side 1 strength raw: 80,000 men...
# Side 2 strength raw: 40,000 men...
# Side 1 troops: 80000
# Side 2 troops: 40000
# Side 1 casualties raw: 8,000...
# Side 2 casualties raw: ~1,800...
# Side 1 deaths: 8000
# Side 2 deaths: 1800
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Antwerp (1584)
# Scraping battle page: Battle of Antwerp (1832) (ID: 64)
# Result: French victory...
# Side 1 raw content: France
#  Supported by:  Belgium...
# Side 2 raw content: United Netherlands...
# Side 1 countries: ['France', 'Supported by: Belgium']
# Side 2 countries: ['United Netherlands']
# Side 1 strength raw: 50,000–60,000...
# Side 2 strength raw: 4,500...
# Side 1 troops: 55000
# Side 2 troops: 4500
# Side 1 casualties raw: 608 dead
#  1,800 wounded...
# Side 2 casualties raw: 90 dead
#  349 wounded...
# Side 1 deaths: 608
# Side 2 deaths: 90
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Battle of Antwerp (1832)
# Scraping battle page: Battle of Antwerp (1914) (ID: 65)
# Result: German victory...
# Side 1 raw content: German Empire
#   Austria-Hungary...
# Side 2 raw content: Belgium
#  United Kingdom...
# Side 1 countries: ['German Empire', 'Austria-Hungary']
# Side 2 countries: ['Belgium', 'United Kingdom']
# Side 1 strength raw: 66,000...
# Side 2 strength raw: 87,300 field troops
#  63,000 garrison troops...
# Side 1 troops: 66000
# Side 2 troops: 87300
# Side 1 casualties raw: ...
# Side 2 casualties raw: Belgium:
#  33,000 interned in the Netherlands
#  30,000 captured
#  Britain :
#  57 killed
#  1,480 inte...
# Side 1 deaths: None
# Side 2 deaths: 57
# Side 1 result: loser
# Side 2 result: winner
# Found 4 participants for Battle of Antwerp (1914)
# Scraping battle page: Battle of Antwerp (1944) (ID: 66)
# Result: German victory
# • Belgian surrender
# • Establishment of Belgian government and army in exile...
# Side 1 raw content: Belgium
#  France
#   United Kingdom
#   Netherlands
#   Luxembourg...
# Side 2 raw content: Germany...
# Side 1 countries: ['Belgium', 'France', 'United Kingdom', 'Netherlands', 'Luxembourg']
# Side 2 countries: ['Germany']
# Side 1 strength raw: 144 divisions
#  13,974 guns
#  3,384 tanks
#  2,249 aircraft...
# Side 2 strength raw: 141 divisions
#  7,378 guns
#  2,445 tanks
#  5,446 aircraft (4,020 operational)...
# Side 1 troops: 13974
# Side 2 troops: 7378
# Side 1 casualties raw: 222,443+ casualties (200,000 captured )
#  ~900 aircraft...
# Side 2 casualties raw: Uncertain (see German casualties )...
# Side 1 deaths: 222443
# Side 2 deaths: None
# Side 1 result: loser
# Side 2 result: winner
# Found 6 participants for Battle of Antwerp (1944)
# Scraping battle page: Battle of Anzen (ID: 67)
# Result: Abbasid victory...
# Side 1 raw content: Byzantine Empire...
# Side 2 raw content: Abbasid Caliphate...
# Side 1 countries: ['Byzantine Empire']
# Side 2 countries: ['Abbasid Caliphate']
# Side 1 strength raw: 25,000 –40,000...
# Side 2 strength raw: 20,000 –30,000...
# Side 1 troops: 32500
# Side 2 troops: 25000
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Anzen
# Scraping battle page: Battle of Aong (ID: 68)
# Result: Company victory...
# Side 1 raw content: Nana Sahib 's forces,
#  Rebel Company sepoys...
# Side 2 raw content: British East India Company...
# Side 1 countries: ["Nana Sahib 's forces", 'Rebel Company sepoys']
# Side 2 countries: ['British East India Company']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Aong
# Scraping battle page: Siege of Apia (ID: 69)
# Result: Allied victory...
# Side 1 raw content: Allies :
#   Samoa
#  United Kingdom
#   United States...
# Side 2 raw content: Mataafans
#  Supported by:
#  Germany...
# Side 1 countries: ['Allies :', 'Samoa', 'United Kingdom', 'United States']
# Side 2 countries: ['Mataafans', 'Supported by:', 'Germany']
# Side 1 strength raw: Land:
#  2,260
#  Sea:
#  3 cruisers
#  1 corvette...
# Side 2 strength raw: 4,000...
# Side 1 troops: 2260
# Side 2 troops: 4000
# Side 1 casualties raw: 9 killed
#  10–15 wounded...
# Side 2 casualties raw: ~27 killed...
# Side 1 deaths: 9
# Side 2 deaths: 27
# Side 1 result: winner
# Side 2 result: loser
# Found 7 participants for Siege of Apia
# Scraping battle page: Battle of Araure (ID: 70)
# Result: Patriot victory...
# Side 1 raw content: Patriots...
# Side 2 raw content: Royalists...
# Side 1 countries: ['Patriots']
# Side 2 countries: ['Royalists']
# Side 1 strength raw: 3,000 infantry and cavalry...
# Side 2 strength raw: 3,500–5,000 infantry
#  500 cavalry...
# Side 1 troops: 3000
# Side 2 troops: 5000
# Side 1 casualties raw: 800 dead...
# Side 2 casualties raw: 1,000 dead...
# Side 1 deaths: 800
# Side 2 deaths: 1000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Araure
# Progress: 70/962 battles processed (7.3%)
# Scraping battle page: Battle of Arbedo (ID: 71)
# Result: Milanese victory
# • Swiss expansions checked
# • Bellinzona defended and the Leventina returned to Mi...
# Side 1 raw content: Duchy of Milan...
# Side 2 raw content: Swiss Confederates
# • Lucerne
# • Uri
# • Zug
# • Unterwalden...
# Side 1 countries: ['Duchy of Milan']
# Side 2 countries: ['Swiss Confederates', 'Lucerne', 'Uri', 'Zug', 'Unterwalden']
# Side 1 strength raw: 16,000...
# Side 2 strength raw: 8,000...
# Side 1 troops: 16000
# Side 2 troops: 8000
# Side 1 casualties raw: heavy
#  ~900 killed
#  400 horses killed...
# Side 2 casualties raw: heavy
#  ~400 killed
#  all baggage and 1,200 sumpters lost...
# Side 1 deaths: 900
# Side 2 deaths: 400
# Side 1 result: unknown
# Side 2 result: unknown
# Found 6 participants for Battle of Arbedo
# Scraping battle page: Battle of Arcole (1796) (ID: 72)
# Result: French victory...
# Side 1 raw content: French Republic...
# Side 2 raw content: Habsburg monarchy...
# Side 1 countries: ['French Republic']
# Side 2 countries: ['Habsburg monarchy']
# Side 1 strength raw: 20,000...
# Side 2 strength raw: 24,000...
# Side 1 troops: 20000
# Side 2 troops: 24000
# Side 1 casualties raw: 3,500 killed or wounded
#  1,300 captured...
# Side 2 casualties raw: 2,200 killed or wounded
#  4,000 captured...
# Side 1 deaths: 3500
# Side 2 deaths: 2200
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Arcole (1796)
# Scraping battle page: Battle of Arcis-sur-Aube (ID: 73)
# Result: Coalition victory...
# Side 1 raw content: Austria
#   Bavaria
#   Russia
#   Württemberg
#   Prussia...
# Side 2 raw content: France...
# ...
# Side 2 countries: ['Duchy of Brabant', 'City of Cologne', 'County of Berg', 'County of Mark', 'County of Loon', 'County of Jülich', 'County of Tecklenburg', 'County of Waldeck', 'County of Ziegenhain', 'County of Vianden']
# Side 1 strength raw: 4,200
# • 2,800 armored cavalry
# • 1,400 footmen...
# Side 2 strength raw: 4,800
# • 2,300 armored cavalry
# • 2,500 footmen...
# Side 1 troops: 1400
# Side 2 troops: 2500
# Side 1 casualties raw: 1,100...
# Side 2 casualties raw: 40...
# Side 1 deaths: 1100
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 18 participants for Battle of Worringen
# Scraping battle page: Battle of Wounded Knee (ID: 942)
# Result: See Fight and ensuing massacre...
# Side 1 raw content: United States...
# Side 2 raw content: Miniconjou Lakota
#  Hunkpapa Lakota...
# Side 1 countries: ['United States']
# Side 2 countries: ['Miniconjou Lakota', 'Hunkpapa Lakota']
# Side 1 strength raw: 490...
# Side 2 strength raw: 120...
# Side 1 troops: 490
# Side 2 troops: 120
# Side 1 casualties raw: 31 killed
#  33 wounded...
# Side 2 casualties raw: 90 killed
#  4 wounded...
# Side 1 deaths: 31
# Side 2 deaths: 90
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Wounded Knee
# Scraping battle page: Battle of Wuzhang Plains (ID: 943)
# Result: Inconclusive; Shu Han retreat...
# Side 1 raw content: Cao Wei...
# Side 2 raw content: Shu Han...
# Side 1 countries: ['Cao Wei']
# Side 2 countries: ['Shu Han']
# Side 1 strength raw: Unknown...
# Side 2 strength raw: 60,000...
# Side 1 troops: None
# Side 2 troops: 60000
# Side 1 casualties raw: Unknown...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: tied
# Side 2 result: tied
# Found 2 participants for Battle of Wuzhang Plains
# Scraping battle page: Battle of Xiangyang (191 AD) (ID: 944)
# Result: Liu Biao victory...
# Side 1 raw content: Liu Biao...
# Side 2 raw content: Sun Jian...
# Side 1 countries: ['Liu Biao']
# Side 2 countries: ['Sun Jian']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Xiangyang (191 AD)
# Scraping battle page: Battle of Xiangyang (ID: 945)
# Result: Yuan victory...
# Side 1 raw content: Southern Song dynasty...
# Side 2 raw content: Mongol Empire
# • Yuan dynasty...
# Side 1 countries: ['Southern Song dynasty']
# Side 2 countries: ['Mongol Empire', 'Yuan dynasty']
# Side 1 strength raw: 8,000...
# Side 2 strength raw: 100,000
#  5,000 ships
#  100+ trebuchets
#  20+ counterweight trebuchets...
# Side 1 troops: 8000
# Side 2 troops: 100000
# Side 1 casualties raw: Heavy...
# Side 2 casualties raw: Heavy...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Xiangyang
# Scraping battle page: Battle of Xinzheng (ID: 946)
# Result: National Revolutionary Army victory...
# Side 1 raw content: National Revolutionary Army Central Army...
# Side 2 raw content: Feng Yuxiang 's forces...
# Side 1 countries: ['National Revolutionary Army Central Army']
# Side 2 countries: ["Feng Yuxiang 's forces"]
# Side 1 strength raw: 11th, 47th and 48th Divisions (24,000)...
# Side 2 strength raw: 40,000...
# Side 1 troops: 24000
# Side 2 troops: 40000
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Xinzheng
# Scraping battle page: Battle of Yalu River (1894) (ID: 947)
# Result: Japanese victory...
# Side 1 raw content: Japan...
# Side 2 raw content: China...
# Side 1 countries: ['Japan']
# Side 2 countries: ['China']
# Side 1 strength raw: 7 protected cruisers
#  1 belted cruiser
#  2 ironclads
#  1 gunboat
#  1 transport ship...
# Side 2 strength raw: 2 ironclad battleships
#  1 coastal battleship
#  2 armoured cruisers
#  3 protected cruisers
#  1 compo...
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: 380 killed and wounded 5 protected cruisers damaged
#  1 ironclad damaged...
# Side 2 casualties raw: 1,350 killed and wounded
#  1 protected cruiser sunk
#  1 armoured cruiser sunk
#  2 light cruisers sun...
# Side 1 deaths: 380
# Side 2 deaths: 1350
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Yalu River (1894)
# Scraping battle page: Battle of Yalu River (1904) (ID: 948)
# Result: Japanese victory...
# Side 1 raw content: Empire of Japan...
# Side 2 raw content: Russian Empire...
# Side 1 countries: ['Empire of Japan']
# Side 2 countries: ['Russian Empire']
# Side 1 strength raw: 42,000...
# Side 2 strength raw: About 25,000...
# Side 1 troops: 42000
# Side 2 troops: 25000
# Side 1 casualties raw: 1,036 killed, wounded or missing...
# Side 2 casualties raw: 2,172 casualties
# • 593 killed
# • 1,101 wounded
# • 478 missing...
# Side 1 deaths: 1036
# Side 2 deaths: 593
# Side 1 result: loser
# Side 2 result: winner
# Found 2 participants for Battle of Yalu River (1904)
# Scraping battle page: Battle of Yarmuk (ID: 949)
# Result: Rashidun victory...
# Side 1 raw content: Rashidun Caliphate...
# Side 2 raw content: Byzantine Empire
#  Ghassanid Kingdom
#  Tanukhids...
# Side 1 countries: ['Rashidun Caliphate']
# Side 2 countries: ['Byzantine Empire', 'Ghassanid Kingdom', 'Tanukhids']
# Side 1 strength raw: 15,000–40,000
#  (modern estimates)
#  24,000–40,000
#  (primary Arab sources)...
# Side 2 strength raw: 20,000–40,000
#  (modern estimates)
#  100,000–200,000
#  (primary Arab sources)
#  140,000
#  (primary R...
# Side 1 troops: 27500
# Side 2 troops: 30000
# Side 1 casualties raw: 4,000 killed...
# Side 2 casualties raw: 70,000–120,000 killed
#  (primary Arab sources)...
# Side 1 deaths: 4000
# Side 2 deaths: 120000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Yarmuk
# Scraping battle page: Battle of Yarmouk Camp (ID: 950)
# Result: Partial ISIL victory
# • 2,000 people were evacuated from the district
# • Rebels repel ISIL attack on...
# Side 1 raw content: Islamic State of Iraq and the Levant  al-Nusra Front...
# Side 2 raw content: Jaysh al-Islam
#   Free Syrian Army
#   Aknaf Bait al-Maqdis...
# Side 1 countries: ['Islamic State of Iraq and the Levant al-Nusra Front']
# Side 2 countries: ['Jaysh al-Islam', 'Free Syrian Army', 'Aknaf Bait al-Maqdis']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: 80 killed
#
#  36 killed...
# Side 2 casualties raw: 9–15 killed, 10 captured...
# Side 1 deaths: 80
# Side 2 deaths: 15
# Side 1 result: loser
# Side 2 result: winner
# Found 4 participants for Battle of Yarmouk Camp
# Progress: 950/962 battles processed (98.8%)
# Scraping battle page: Battle of York (ID: 951)
# Result: • United States victory
# • Public buildings, including the parliament building were razed....
# Side 1 raw content: United Kingdom
#   Upper Canada
#  Ojibwe...
# Side 2 raw content: United States...
# Side 1 countries: ['United Kingdom', 'Upper Canada', 'Ojibwe']
# Side 2 countries: ['United States']
# Side 1 strength raw: 300 regulars
#  300 militia
#  40–50 Natives...
# Side 2 strength raw: 1,700 regulars
#  14 armed vessels...
# Side 1 troops: 45
# Side 2 troops: 1700
# Side 1 casualties raw: 82 killed
#  112 wounded (including 69 wounded prisoners)
#  274 captured
#  7 missing...
# Side 2 casualties raw: 55 killed
#  265 wounded...
# Side 1 deaths: 82
# Side 2 deaths: 55
# Side 1 result: loser
# Side 2 result: winner
# Found 4 participants for Battle of York
# Scraping battle page: Battle of Yorktown (1781) (ID: 952)
# Result: Franco-American victory...
# Side 1 raw content: United States
#  France...
# Side 2 raw content: Great Britain
# • Loyalists  Hesse-Kassel
#  Ansbach - Bayreuth...
# Side 1 countries: ['United States', 'France']
# Side 2 countries: ['Great Britain', 'Loyalists Hesse-Kassel Ansbach - Bayreuth']
# Side 1 strength raw: Americans : 8,000–9,000 men
# • 5,900 regular troops
# • 3,100 militia (not engaged) French : 10,800 m...
# Side 2 strength raw: British : 5,000 German : Fewer than 3,000
#
#  Total : 8-9,000...
# Side 1 troops: 9000
# Side 2 troops: 4504
# Side 1 casualties raw: 88 killed
#  301 wounded...
# Side 2 casualties raw: 142–309 killed
#  326–595 wounded prisoners
#  7,416–7,685 captured...
# Side 1 deaths: 88
# Side 2 deaths: 309
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of Yorktown (1781)
# Scraping battle page: First Battle of Ypres (ID: 953)
# Result: Indecisive...
# Side 1 raw content: • France
# • Belgium
# • United Kingdom...
# Side 2 raw content: Germany...
# Side 1 countries: ['France', 'Belgium', 'United Kingdom']
# Side 2 countries: ['Germany']
# Side 1 strength raw: ...
# Side 2 strength raw: 5,400,000...
# Side 1 troops: None
# Side 2 troops: 5400
# Side 1 casualties raw: ...
# Side 2 casualties raw: ...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: tied
# Side 2 result: tied
# Found 4 participants for First Battle of Ypres
# Scraping battle page: Second Battle of Ypres (ID: 954)
# Result: See Analysis section...
# Side 1 raw content: British Empire
# • Canada
# • India
# • United Kingdom France
# • Algeria
# • Morocco  Belgium...
# Side 2 raw content: German Empire...
# Side 1 countries: ['British Empire', 'Canada', 'India', 'United Kingdom France', 'Algeria', 'Morocco Belgium']
# Side 2 countries: ['German Empire']
# Side 1 strength raw: ...
# Side 2 strength raw: 7 divisions...
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: ...
# Side 2 casualties raw: 35,000+...
# Side 1 deaths: None
# Side 2 deaths: 35000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 7 participants for Second Battle of Ypres
# Scraping battle page: Third Battle of Ypres (ID: 955)
# Result: See Analysis section...
# Side 1 raw content: British Empire
# • United Kingdom
# • Canada
# • Australia
# • New Zealand
# • South Africa
# • India
# • N...
# Side 2 raw content: Germany...
# Side 1 countries: ['British Empire', 'United Kingdom', 'Canada', 'Australia', 'New Zealand', 'South Africa', 'India', 'Newfoundland', 'Rhodesia France Belgium']
# Side 2 countries: ['Germany']
# Side 1 strength raw: 50 divisions
#   6 divisions...
# Side 2 strength raw: 77–83 divisions...
# Side 1 troops: None
# Side 2 troops: 80
# Side 1 casualties raw: 240,000–448,614
#  (disputed, see Casualties section)...
# Side 2 casualties raw: 217,000–400,000
#  including 24,065 prisoners (disputed, see Casualties section)...
# Side 1 deaths: 344307
# Side 2 deaths: 308500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 10 participants for Third Battle of Ypres
# Scraping battle page: Battle of Zama (ID: 956)
# Result: Roman victory...
# Side 1 raw content: Rome...
# Side 2 raw content: Carthage...
# Side 1 countries: ['Rome']
# Side 2 countries: ['Carthage']
# Side 1 strength raw: 30,000
# • 24,000 infantry
# • 6,000 cavalry...
# Side 2 strength raw: 40,000 or 50,000
# • 36,000 or 46,000 infantry
# • 4,000 cavalry
# • 80 war elephants...
# Side 1 troops: 24000
# Side 2 troops: 46000
# Side 1 casualties raw: At least 1,500 killed...
# Side 2 casualties raw: • •  20,000 killed
# • •  20,000 captured...
# Side 1 deaths: 1500
# Side 2 deaths: 20000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Zama
# Scraping battle page: Battle of Zapote Bridge (1897) (ID: 957)
# Result: Filipino victory...
# Side 1 raw content: Katipunan
# • Magdalo...
# Side 2 raw content: Spanish Empire
# • Guardia Civil...
# Side 1 countries: ['Katipunan', 'Magdalo']
# Side 2 countries: ['Spanish Empire', 'Guardia Civil']
# Side 1 strength raw: ~10,000 men...
# Side 2 strength raw: 16,000 men...
# Side 1 troops: 10000
# Side 2 troops: 16000
# Side 1 casualties raw: 450 killed,
#  900+ wounded...
# Side 2 casualties raw: 441 killed,
#  870+ wounded, 313 captured...
# Side 1 deaths: 450
# Side 2 deaths: 441
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Zapote Bridge (1897)
# Scraping battle page: Battle of Zenta (ID: 958)
# Result: • Holy League victory
# • Treaty of Karlowitz
# • End of the Great Turkish War...
# Side 1 raw content: Habsburg Monarchy
# • Kingdom of Hungary
# • Serbian Militia...
# Side 2 raw content: Ottoman Empire
# • Crimean Tatars
# • Kuruc rebels...
# Side 1 countries: ['Habsburg Monarchy', 'Kingdom of Hungary', 'Serbian Militia']
# Side 2 countries: ['Ottoman Empire', 'Crimean Tatars', 'Kuruc rebels']
# Side 1 strength raw: 50,000 men
# • 34,000 infantry
# • 16,000 cavalry
# • 60 guns...
# Side 2 strength raw: 75,000–100,000 men
#  200 guns...
# Side 1 troops: 50000
# Side 2 troops: 100000
# Side 1 casualties raw: 429 killed
#  1,598 wounded...
# Side 2 casualties raw: 30,000 killed, wounded, or drowned...
# Side 1 deaths: 429
# Side 2 deaths: 30000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 6 participants for Battle of Zenta
# Scraping battle page: Battle of Zborov (ID: 959)
# Result: Czechoslovak and Russian victory...
# Side 1 raw content: Czechoslovak Legion
#   Russian Provisional Government...
# Side 2 raw content: Austria-Hungary  German Empire...
# Side 1 countries: ['Czechoslovak Legion', 'Russian Provisional Government']
# Side 2 countries: ['Austria-Hungary German Empire']
# Side 1 strength raw: 3,530...
# Side 2 strength raw: 5,500...
# Side 1 troops: 3530
# Side 2 troops: 5500
# Side 1 casualties raw: 167 killed
#  700 wounded
#
#  11 missing...
# Side 2 casualties raw: 3,300 captured
#
#  20 guns captured...
# Side 1 deaths: 167
# Side 2 deaths: 3300
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Zborov
# Scraping battle page: First Battle of Zurich (ID: 960)
# Result: Austrian victory...
# Side 1 raw content: France...
# Side 2 raw content: Austria...
# Side 1 countries: ['France']
# Side 2 countries: ['Austria']
# Side 1 strength raw: 59,000...
# Side 2 strength raw: 72,000...
# Side 1 troops: 59000
# Side 2 troops: 72000
# Side 1 casualties raw: 500 killed
#  800 wounded...
# Side 2 casualties raw: 730 killed
#  1,470 wounded
#  2,200 captured...
# Side 1 deaths: 500
# Side 2 deaths: 730
# Side 1 result: loser
# Side 2 result: winner
# Found 2 participants for First Battle of Zurich
# Progress: 960/962 battles processed (99.8%)
# Scraping battle page: Second Battle of Zurich (ID: 961)
# Result: French victory...
# Side 1 raw content: French Republic...
# Side 2 raw content: Russian Empire
#   Habsburg monarchy...
# Side 1 countries: ['French Republic']
# Side 2 countries: ['Russian Empire', 'Habsburg monarchy']
# Side 1 strength raw: 35,448...
# Side 2 strength raw: 27,116...
# Side 1 troops: 35448
# Side 2 troops: 27116
# Side 1 casualties raw: 4,000 killed or wounded...
# Side 2 casualties raw: at least 8,000 casualties during the battle
#  100 guns 4,000 more during the retreat...
# Side 1 deaths: 4000
# Side 2 deaths: 8000
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Second Battle of Zurich
# Scraping battle page: Battle of Zusmarshausen (ID: 962)
# Result: Franco-Swedish victory...
# Side 1 raw content: Swedish Empire
#  France...
# Side 2 raw content: Bavaria
#   Holy Roman Empire...
# Side 1 countries: ['Swedish Empire', 'France']
# Side 2 countries: ['Bavaria', 'Holy Roman Empire']
# Side 1 strength raw: 22,000
# • 7,500 infantry
# • 14,500 cavalry...
# Side 2 strength raw: 15,370–18,000
# • 8,150 infantry
# • 7,220 cavalry...
# Side 1 troops: 7500
# Side 2 troops: 8150
# Side 1 casualties raw: 500 –2,000...
# Side 2 casualties raw: 1,897 –2,200
#  6 Guns...
# Side 1 deaths: 1250
# Side 2 deaths: 2048
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Zusmarshausen
# Progress: 962/962 battles processed (100.0%)
#
# ✅ Scraped 3184 participant entries for 962 battles.
# Saved to 'battle_participants.csv'
#
# Extraction statistics:
# - Participants with troop numbers: 2438 (76.6%)
# - Participants with death counts: 2287 (71.8%)
# - Participants with known results: 1384 (43.5%)
#
# Sample of participant data:
# 1. Participant ID: 1, Battle ID: 1, Country: United States
#    Troops: 100000.0
#    Deaths: 2000.0
#    Result: winner
# 2. Participant ID: 2, Battle ID: 1, Country: Germany
#    Troops: 13000.0
#    Deaths: 5000.0
#    Result: loser
# 3. Participant ID: 3, Battle ID: 2, Country: First French Empire
#    Troops: 55000.0
#    Deaths: 1000.0
#    Result: winner
# 4. Participant ID: 4, Battle ID: 2, Country: Kingdom of Bavaria
#    Troops: 55000.0
#    Deaths: 1000.0
#    Result: winner
# 5. Participant ID: 5, Battle ID: 2, Country: Württemberg
#    Troops: 55000.0
#    Deaths: 1000.0
#    Result: winner

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import random
import os.path
from urllib.parse import urljoin

# Constants
BASE_URL = "https://en.wikipedia.org"
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    )
}

def load_battles_csv(filename="battles_list.csv"):
    """Load the battles CSV file and return as DataFrame."""
    if not os.path.isfile(filename):
        raise FileNotFoundError(f"Battles CSV file not found: {filename}")
    
    battles_df = pd.read_csv(filename)
    print(f"Loaded {len(battles_df)} battles from {filename}")
    return battles_df

def extract_number(text, keywords=None):
    """
    Extract number from text, with optional keyword context.
    If keywords provided, looks for numbers near the keywords.
    """
    if not isinstance(text, str):
        return None
    
    text = text.replace('\xa0', ' ')  # Handle non-breaking spaces
    
    # Default keywords if none provided
    if keywords is None:
        keywords = ['men', 'troops', 'soldiers', 'personnel']
    elif isinstance(keywords, str):
        keywords = [keywords]
    
    # Try each keyword
    for keyword in keywords:
        if keyword in text.lower():
            # Find position of keyword
            pos = text.lower().find(keyword)
            
            # Look for numbers before the keyword (within 50 characters)
            before_text = text[max(0, pos-50):pos]
            number_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+(?:\.\d+)?|\d+)', before_text)
            
            # If found numbers before keyword, use the closest one (last one)
            if number_matches:
                num_str = number_matches[-1].replace(',', '')
                try:
                    return int(float(num_str))
                except ValueError:
                    pass
            
            # Look for numbers after keyword (within 20 characters)
            after_text = text[pos + len(keyword):min(len(text), pos + len(keyword) + 20)]
            number_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+(?:\.\d+)?|\d+)', after_text)
            
            # If found numbers after keyword, use the closest one (first one)
            if number_matches:
                num_str = number_matches[0].replace(',', '')
                try:
                    return int(float(num_str))
                except ValueError:
                    pass
    
    # If no numbers found near keywords, look for number ranges (e.g., "10,000-15,000")
    range_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+)(?:\s*[-–]\s*)(\d{1,3}(?:,\d{3})+|\d+)', text)
    if range_matches:
        try:
            # Use average of the range
            first_num = int(range_matches[0][0].replace(',', ''))
            second_num = int(range_matches[0][1].replace(',', ''))
            return (first_num + second_num) // 2
        except ValueError:
            pass
    
    # Look for any number with specific formats (prioritize larger numbers which are more likely troop counts)
    # Focus on numbers that appear to be formatted as thousands (e.g., "10,000")
    formatted_thousands = re.findall(r'(\d{1,3},\d{3})', text)
    if formatted_thousands:
        try:
            return int(formatted_thousands[0].replace(',', ''))
        except ValueError:
            pass
    
    # Look for any large numbers (3+ digits)
    large_numbers = re.findall(r'(\d{3,})', text)
    if large_numbers:
        try:
            return int(large_numbers[0])
        except ValueError:
            pass
    
    # Last resort: any number
    number_matches = re.findall(r'(\d+)', text)
    if number_matches:
        for match in number_matches:
            try:
                num = int(match)
                # Only consider if it's a reasonably sized number for troop counts
                if num > 50:  # Avoid small numbers that might be dates or footnotes
                    return num
            except ValueError:
                continue
    
    return None

def clean_country_name(text):
    """Clean country name text."""
    if not isinstance(text, str):
        return None
    
    # Remove text in brackets, parentheses
    cleaned = re.sub(r'\([^)]*\)', '', text)
    cleaned = re.sub(r'\[[^\]]*\]', '', cleaned)
    
    # Remove footnote references and citation needed
    cleaned = re.sub(r'\[\d+\]', '', cleaned)
    cleaned = re.sub(r'\[citation needed\]', '', cleaned)
    
    # Remove excess whitespace
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    
    # Skip phrases that are clearly results, not countries
    result_phrases = [
        'victory', 'defeat', 'decisive', 'inconclusive', 'stalemate', 
        'draw', 'tactical', 'strategic', 'pyrrhic', 'truce', 'ceasefire'
    ]
    if any(phrase in cleaned.lower() for phrase in result_phrases) and len(cleaned.split()) <= 3:
        return None
    
    # Remove very short strings or just numbers or dates
    if len(cleaned) < 3 or cleaned.isdigit() or re.match(r'^\d+\s+\w+$', cleaned):
        return None
    
    # Replace some common abbreviations
    replacements = {
        'US': 'United States',
        'U.S.': 'United States',
        'U.S.A.': 'United States',
        'USA': 'United States',
        'UK': 'United Kingdom',
        'U.K.': 'United Kingdom',
        'Soviet Union': 'Russia',
        'USSR': 'Russia',
        'U.S.S.R.': 'Russia'
    }
    
    for abbr, full in replacements.items():
        if cleaned == abbr:
            cleaned = full
    
    return cleaned

def extract_html_content(element):
    """Extract a clean text representation of HTML content including flags and formatting."""
    if element is None:
        return ""
    
    # For simple text elements, just return the text
    if isinstance(element, str):
        return element.strip()
    
    # Create a list to store the content parts
    content_parts = []
    
    # Process all child elements
    for child in element.children:
        if child.name is None:  # Text node
            text = child.strip()
            if text:
                content_parts.append(text)
        elif child.name == 'br':
            content_parts.append('\n')
        elif child.name == 'li':
            content_parts.append('\n• ' + extract_html_content(child))
        elif child.name in ['b', 'strong', 'i', 'em', 'span', 'div', 'p']:
            content_parts.append(extract_html_content(child))
        elif child.name == 'a':
            content_parts.append(child.get_text().strip())
        elif child.name == 'ul' or child.name == 'ol':
            for li in child.find_all('li', recursive=False):
                content_parts.append('\n• ' + extract_html_content(li))
    
    # Join all the parts together
    return ' '.join(content_parts).strip()

def extract_countries_from_text(content):
    """Extract country names from text content with better handling of separators."""
    countries = []
    
    # Split by common separators
    parts = re.split(r'[,\n•]|\band\b', content)
    
    for part in parts:
        country = clean_country_name(part)
        if country and country not in countries and len(country) > 3:
            countries.append(country)
    
    return countries

def split_content_by_flags(content):
    """
    Split HTML content that may contain flags and country references.
    This improves extraction when countries are arranged with flag icons.
    """
    if not content:
        return []
    
    # Check for list items
    if '•' in content:
        parts = [p.strip() for p in content.split('•') if p.strip()]
        return parts
    
    # Split by commas and newlines
    parts = re.split(r'[,\n]+', content)
    return [p.strip() for p in parts if p.strip()]

def determine_battle_result(result_text, side1_countries, side2_countries):
    """Determine the battle result with improved pattern matching."""
    if not result_text:
        return "unknown", "unknown"
    
    result_lower = result_text.lower()
    
    # Check for ties
    if any(term in result_lower for term in ["stalemate", "draw", "inconclusive", "indecisive", "truce", "ceasefire"]):
        return "tied", "tied"
    
    # Check for side 1 victory
    side1_victory = any(term in result_lower for term in ["allied victory", "american victory", "british victory", "french victory"])
    for country in side1_countries:
        if country.lower() in result_lower and "victory" in result_lower:
            side1_victory = True
            break
    
    # Check for side 2 victory
    side2_victory = any(term in result_lower for term in ["german victory", "axis victory", "japanese victory", "confederate victory"])
    for country in side2_countries:
        if country.lower() in result_lower and "victory" in result_lower:
            side2_victory = True
            break
    
    # Determine results based on the checks
    if side1_victory and not side2_victory:
        return "winner", "loser"
    elif side2_victory and not side1_victory:
        return "loser", "winner"
    
    # Check for specific defeat mentions
    if "defeat" in result_lower:
        for country in side1_countries:
            if country.lower() in result_lower and "defeat" in result_lower:
                return "loser", "winner"
        for country in side2_countries:
            if country.lower() in result_lower and "defeat" in result_lower:
                return "winner", "loser"
    
    # Default to unknown if we can't determine
    return "unknown", "unknown"

def extract_infobox_data(infobox, key):
    """
    Extract data from infobox based on a key (header text)
    with improved handling of infobox structures.
    """
    if not infobox:
        return []
    
    data = []
    found_header = False
    
    # First try to find a row with the key in the header
    for row in infobox.find_all("tr"):
        if not found_header:
            # Check if this is a header row with our key
            th = row.find("th")
            if th and key.lower() in th.get_text().strip().lower():
                found_header = True
                # Some infoboxes include data in the same row as the header
                td = row.find("td")
                if td:
                    data.append(td)
        else:
            # After finding the header, collect subsequent data rows until we hit another header
            th = row.find("th")
            if th:
                # If the new header doesn't contain our key, we've moved to a new section
                if key.lower() not in th.get_text().strip().lower():
                    break
            
            # Add any data cells
            for td in row.find_all("td"):
                data.append(td)
    
    # If standard approach failed, try to find rows with specific structure
    if not data:
        # Look for row format: belligerent1, belligerent2
        for row in infobox.find_all("tr"):
            ths = row.find_all("th")
            tds = row.find_all("td")
            
            # Check if this is a row with key in any header and multiple data cells
            if any(key.lower() in th.get_text().strip().lower() for th in ths) and len(tds) >= 2:
                data = tds
                break
    
    return data

def clean_location_text(text):
    """Clean location text by removing unnecessary parts."""
    if not isinstance(text, str):
        return ""
    
    # Remove text in brackets, parentheses
    cleaned = re.sub(r'\([^)]*\)', '', text)
    
    # Remove footnote references
    cleaned = re.sub(r'\[\d+\]', '', cleaned)
    cleaned = re.sub(r'\[citation needed\]', '', cleaned)
    
    # Remove phrases like "near", "present-day", etc.
    cleaned = re.sub(r'\bnear\b|\bpresent-day\b|\bmodern-day\b|\bvicinity of\b', '', cleaned, flags=re.IGNORECASE)
    
    # Remove excess whitespace
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    
    # If there's a comma at the beginning after cleaning, remove it
    cleaned = re.sub(r'^,\s*', '', cleaned)
    
    return cleaned

def parse_location(text):
    """
    Parse location text to extract city and country.
    Uses several strategies to handle different formats.
    """
    if not text:
        return None, None
    
    # Common countries for reference
    common_countries = [
        "Afghanistan", "Albania", "Algeria", "Argentina", "Australia", "Austria", "Bangladesh", 
        "Belgium", "Brazil", "Bulgaria", "Canada", "China", "Croatia", "Czech Republic", 
        "Denmark", "Egypt", "Finland", "France", "Germany", "Greece", "Hungary", "India", 
        "Indonesia", "Iran", "Iraq", "Ireland", "Israel", "Italy", "Japan", "Korea", 
        "Malaysia", "Mexico", "Morocco", "Netherlands", "New Zealand", "Norway", "Pakistan", 
        "Philippines", "Poland", "Portugal", "Romania", "Russia", "Saudi Arabia", "Serbia", 
        "Singapore", "South Africa", "Spain", "Sweden", "Switzerland", "Syria", "Thailand", 
        "Turkey", "Ukraine", "United Arab Emirates", "United Kingdom", "United States", 
        "Vietnam", "Yemen", "Zimbabwe", "Soviet Union", "Ottoman Empire", "Prussia", 
        "Holy Roman Empire", "Byzantine Empire", "Roman Empire"
    ]
    
    # Strategy 1: Look for common format "City, Country"
    parts = [p.strip() for p in text.split(',')]
    
    # If we have exactly two parts, it might be "City, Country"
    if len(parts) == 2:
        # Check if the second part is a known country
        if parts[1] in common_countries or any(country in parts[1] for country in common_countries):
            return parts[0], parts[1]
    
    # Strategy 2: If we have more than 2 parts, the last part is often the country
    if len(parts) > 2:
        # Check if the last part is a known country
        if parts[-1] in common_countries or any(country in parts[-1] for country in common_countries):
            # The country is the last part
            country = parts[-1]
            
            # For the city, we need to be careful:
            # In cases like "Garibpur, Dhaka, Bangladesh", Dhaka might be the city
            # Check if the second-to-last part is a major city
            common_major_cities = ["Dhaka", "Cairo", "Tokyo", "Moscow", "Berlin", "Paris", "London", 
                                  "Beijing", "Delhi", "Rome", "Madrid", "Athens", "Istanbul", "Tehran"]
            
            if parts[-2] in common_major_cities:
                city = parts[-2]
            else:
                # Otherwise use the first part as the city
                city = parts[0]
            
            return city, country
    
    # Strategy 3: Check if any part contains a known country
    country = None
    for part in reversed(parts):  # Check from the end as country usually comes last
        if any(country_name in part for country_name in common_countries):
            country = part
            break
    
    if country:
        # If we found a country, assume the first part is the city
        city = parts[0]
        return city, country
    
    # Strategy 4: If only one part and no country identified, it might be just a region or landmark
    if len(parts) == 1:
        return parts[0], None
    
    # Strategy 5: If we have multiple parts but couldn't identify a country, use first as city, last as potential region
    if len(parts) > 1:
        return parts[0], parts[-1]
    
    # Default fallback: return None for both
    return None, None

def extract_location_data(infobox):
    """
    Extract location data from infobox with handling for various formats.
    Returns tuple of (city, country)
    """
    if not infobox:
        return None, None
    
    # Find location data in the infobox
    location_data = extract_infobox_data(infobox, "place") or extract_infobox_data(infobox, "location")
    
    if not location_data:
        return None, None
    
    # Get the text content of the first location element
    location_text = extract_html_content(location_data[0])
    if not location_text:
        return None, None
    
    print(f"Raw location text: {location_text}")
    
    # Clean the location text
    location_text = clean_location_text(location_text)
    
    # Extract city and country
    city, country = parse_location(location_text)
    
    return city, country

def scrape_battle_page(battle_id, battle_name, wiki_link):
    """Scrape an individual battle page for country participant information."""
    print(f"Scraping battle page: {battle_name} (ID: {battle_id})")
    
    # Check if the wiki_link is already a full URL
    if not wiki_link.startswith("http"):
        url = urljoin(BASE_URL, wiki_link)
    else:
        url = wiki_link
    
    participants = []
    
    try:
        # Fetch the page
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Failed to fetch page: {url} (Status: {response.status_code})")
            return participants
        
        # Parse the HTML
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Find the infobox (try multiple classes)
        infobox = soup.find("table", {"class": ["infobox", "vevent", "vcard"]})
        if not infobox:
            print(f"No infobox found for {battle_name} at {url}")
            return participants
        
        # Extract location information
        city, country = extract_location_data(infobox)
        print(f"Battle location - City: {city}, Country: {country}")
        
        # Extract result first to determine overall battle outcome
        result_text = ""
        result_data = extract_infobox_data(infobox, "result")
        if result_data:
            result_text = extract_html_content(result_data[0])
            print(f"Result: {result_text[:100]}...")
        
        # Extract belligerents
        belligerent_data = extract_infobox_data(infobox, "belligerent") or extract_infobox_data(infobox, "combatant")
        
        side1_countries = []
        side2_countries = []
        
        if len(belligerent_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(belligerent_data[0])
            print(f"Side 1 raw content: {side1_content[:100]}...")
            
            # Extract countries with improved extraction
            if side1_content:
                # First try to extract from list items if present
                parts = split_content_by_flags(side1_content)
                if parts:
                    for part in parts:
                        country_name = clean_country_name(part)
                        if country_name and country_name not in side1_countries:
                            side1_countries.append(country_name)
                else:
                    # Try extracting from the full content
                    extracted = extract_countries_from_text(side1_content)
                    side1_countries.extend([c for c in extracted if c not in side1_countries])
            
            # Process Side 2
            side2_content = extract_html_content(belligerent_data[1])
            print(f"Side 2 raw content: {side2_content[:100]}...")
            
            # Extract countries with improved extraction
            if side2_content:
                # First try to extract from list items if present
                parts = split_content_by_flags(side2_content)
                if parts:
                    for part in parts:
                        country_name = clean_country_name(part)
                        if country_name and country_name not in side2_countries:
                            side2_countries.append(country_name)
                else:
                    # Try extracting from the full content
                    extracted = extract_countries_from_text(side2_content)
                    side2_countries.extend([c for c in extracted if c not in side2_countries])
        
        # If no countries found, try harder with alternative approaches
        if not side1_countries and not side2_countries:
            # Get all text from the infobox
            infobox_text = infobox.get_text()
            
            # Try to identify common country names in the text
            common_countries = [
                "United States", "Germany", "France", "United Kingdom", "Great Britain",
                "Soviet Union", "Russia", "Japan", "Italy", "China", "Spain", "Austria",
                "Confederate States", "Union", "Prussia", "Ottoman Empire", "Turkey"
            ]
            
            found_countries = []
            for country in common_countries:
                if country in infobox_text:
                    found_countries.append(country)
            
            # If we found some countries, try to split them into sides
            if len(found_countries) >= 2:
                # Common historical pairings to guess sides
                opposing_pairs = [
                    (["United States", "United Kingdom", "France", "Russia", "Soviet Union"], 
                     ["Germany", "Japan", "Italy"]),
                    (["Union"], ["Confederate States"]),
                    (["United Kingdom", "Prussia", "Russia"], ["France"]),
                    (["United Kingdom", "France"], ["Spain"]),
                    (["Austria", "Prussia", "Russia"], ["Ottoman Empire", "Turkey"])
                ]
                
                for side1_candidates, side2_candidates in opposing_pairs:
                    side1_matches = [c for c in found_countries if c in side1_candidates]
                    side2_matches = [c for c in found_countries if c in side2_candidates]
                    
                    if side1_matches and side2_matches:
                        side1_countries = side1_matches
                        side2_countries = side2_matches
                        break
                
                # If we couldn't assign sides with pairs, just split the found countries
                if not side1_countries and not side2_countries and len(found_countries) >= 2:
                    middle = len(found_countries) // 2
                    side1_countries = found_countries[:middle]
                    side2_countries = found_countries[middle:]
        
        print(f"Side 1 countries: {side1_countries}")
        print(f"Side 2 countries: {side2_countries}")
        
        # Extract strength information
        strength_data = extract_infobox_data(infobox, "strength")
        
        side1_troops = None
        side2_troops = None
        
        if len(strength_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(strength_data[0])
            print(f"Side 1 strength raw: {side1_content[:100]}...")
            
            # Extract troop numbers with improved extraction
            if side1_content:
                # Try multiple keywords for troop counts
                keywords = ['men', 'troops', 'soldiers', 'personnel', 'combatants', 'infantry', 'army']
                side1_troops = extract_number(side1_content, keywords)
            
            # Process Side 2
            side2_content = extract_html_content(strength_data[1])
            print(f"Side 2 strength raw: {side2_content[:100]}...")
            
            # Extract troop numbers with improved extraction
            if side2_content:
                # Try multiple keywords for troop counts
                keywords = ['men', 'troops', 'soldiers', 'personnel', 'combatants', 'infantry', 'army']
                side2_troops = extract_number(side2_content, keywords)
        
        print(f"Side 1 troops: {side1_troops}")
        print(f"Side 2 troops: {side2_troops}")
        
        # Extract casualty information
        casualty_data = extract_infobox_data(infobox, "casualt") or extract_infobox_data(infobox, "loss")
        
        side1_deaths = None
        side2_deaths = None
        
        if len(casualty_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(casualty_data[0])
            print(f"Side 1 casualties raw: {side1_content[:100]}...")
            
            # Extract death numbers with improved extraction
            if side1_content:
                # Try multiple keywords for death counts
                keywords = ['killed', 'dead', 'deaths', 'fatalities', 'kia', 'killed in action']
                side1_deaths = extract_number(side1_content, keywords)
                
                # If no deaths found with keywords, try extracting other casualty numbers
                if side1_deaths is None:
                    side1_deaths = extract_number(side1_content, ['casualties', 'wounded', 'injured'])
            
            # Process Side 2
            side2_content = extract_html_content(casualty_data[1])
            print(f"Side 2 casualties raw: {side2_content[:100]}...")
            
            # Extract death numbers with improved extraction
            if side2_content:
                # Try multiple keywords for death counts
                keywords = ['killed', 'dead', 'deaths', 'fatalities', 'kia', 'killed in action']
                side2_deaths = extract_number(side2_content, keywords)
                
                # If no deaths found with keywords, try extracting other casualty numbers
                if side2_deaths is None:
                    side2_deaths = extract_number(side2_content, ['casualties', 'wounded', 'injured'])
        
        print(f"Side 1 deaths: {side1_deaths}")
        print(f"Side 2 deaths: {side2_deaths}")
        
        # Determine the result for each side based on the overall result
        side1_result, side2_result = determine_battle_result(result_text, side1_countries, side2_countries)
        
        print(f"Side 1 result: {side1_result}")
        print(f"Side 2 result: {side2_result}")
        
        # Add the participants with the new location columns
        for country_name in side1_countries:
            participants.append({
                "battle_id": battle_id,
                "country": country_name,
                "troops": side1_troops,
                "deaths": side1_deaths,
                "result": side1_result,
                "city_battle_location": city,
                "country_battle_location": country
            })
        
        for country_name in side2_countries:
            participants.append({
                "battle_id": battle_id,
                "country": country_name,
                "troops": side2_troops,
                "deaths": side2_deaths,
                "result": side2_result,
                "city_battle_location": city,
                "country_battle_location": country
            })
        
        print(f"Found {len(participants)} participants for {battle_name}")
        
        return participants
    
    except Exception as e:
        print(f"Error scraping {battle_name}: {e}")
        import traceback
        traceback.print_exc()
        return participants

def main():
    try:
        # Load the battles from the CSV file
        battles_df = load_battles_csv()
        
        # Create a list to store all participants
        all_participants = []
        
        # Process all battles or limit for testing
        max_battles = len(battles_df)  # Change this to limit the number of battles processed
        num_battles = min(len(battles_df), max_battles)
        
        print(f"Processing {num_battles} battles...")
        
        # Process each battle
        for index, battle in battles_df.head(num_battles).iterrows():
            battle_id = battle["battle_id"]
            battle_name = battle["battle_name"]
            wiki_link = battle["wiki_link"]
            
            # Skip if missing wiki link
            if pd.isna(wiki_link) or not wiki_link:
                print(f"Skipping battle {battle_name} (ID: {battle_id}) - Missing wiki link")
                continue
            
            # Scrape the battle page for country information
            participants = scrape_battle_page(battle_id, battle_name, wiki_link)
            
            # Add participants to the overall list
            all_participants.extend(participants)
            
            # Add a random delay to avoid rate limiting
            time.sleep(random.uniform(1.0, 3.0))
            
            # Print progress every 10 battles
            if (index + 1) % 10 == 0 or (index + 1) == num_battles:
                print(f"Progress: {index + 1}/{num_battles} battles processed ({((index + 1)/num_battles)*100:.1f}%)")
        
        # Create a DataFrame from the participants data
        if not all_participants:
            print("No participants found. Check the scraping logic.")
            return
        
        participants_df = pd.DataFrame(all_participants)
        
        # Add a unique participant_id as the primary key
        participants_df.reset_index(drop=True, inplace=True)
        participants_df['participant_id'] = participants_df.index + 1  # Start IDs from 1
        
        # Reorder columns to put participant_id first
        cols = ['participant_id', 'battle_id', 'country', 'troops', 'deaths', 'result', 
                'city_battle_location', 'country_battle_location']
        participants_df = participants_df[cols]
        
        # Save to CSV
        participants_df

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import random
import os.path
from urllib.parse import urljoin

# Constants
BASE_URL = "https://en.wikipedia.org"
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    )
}

def load_battles_csv(filename='/Users/louis/Desktop/Coding/Github/WarCast/Data/Pre_clean/battles_list.csv'):
    """Load the battles CSV file and return as DataFrame."""
    if not os.path.isfile(filename):
        raise FileNotFoundError(f"Battles CSV file not found: {filename}")
    
    battles_df = pd.read_csv(filename)
    print(f"Loaded {len(battles_df)} battles from {filename}")
    return battles_df

def extract_number(text, keywords=None):
    """
    Extract number from text, with optional keyword context.
    If keywords provided, looks for numbers near the keywords.
    """
    if not isinstance(text, str):
        return None
    
    text = text.replace('\xa0', ' ')  # Handle non-breaking spaces
    
    # Default keywords if none provided
    if keywords is None:
        keywords = ['men', 'troops', 'soldiers', 'personnel']
    elif isinstance(keywords, str):
        keywords = [keywords]
    
    # Try each keyword
    for keyword in keywords:
        if keyword in text.lower():
            # Find position of keyword
            pos = text.lower().find(keyword)
            
            # Look for numbers before the keyword (within 50 characters)
            before_text = text[max(0, pos-50):pos]
            number_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+(?:\.\d+)?|\d+)', before_text)
            
            # If found numbers before keyword, use the closest one (last one)
            if number_matches:
                num_str = number_matches[-1].replace(',', '')
                try:
                    return int(float(num_str))
                except ValueError:
                    pass
            
            # Look for numbers after keyword (within 20 characters)
            after_text = text[pos + len(keyword):min(len(text), pos + len(keyword) + 20)]
            number_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+(?:\.\d+)?|\d+)', after_text)
            
            # If found numbers after keyword, use the closest one (first one)
            if number_matches:
                num_str = number_matches[0].replace(',', '')
                try:
                    return int(float(num_str))
                except ValueError:
                    pass
    
    # If no numbers found near keywords, look for number ranges (e.g., "10,000-15,000")
    range_matches = re.findall(r'(\d{1,3}(?:,\d{3})+|\d+)(?:\s*[-–]\s*)(\d{1,3}(?:,\d{3})+|\d+)', text)
    if range_matches:
        try:
            # Use average of the range
            first_num = int(range_matches[0][0].replace(',', ''))
            second_num = int(range_matches[0][1].replace(',', ''))
            return (first_num + second_num) // 2
        except ValueError:
            pass
    
    # Look for any number with specific formats (prioritize larger numbers which are more likely troop counts)
    # Focus on numbers that appear to be formatted as thousands (e.g., "10,000")
    formatted_thousands = re.findall(r'(\d{1,3},\d{3})', text)
    if formatted_thousands:
        try:
            return int(formatted_thousands[0].replace(',', ''))
        except ValueError:
            pass
    
    # Look for any large numbers (3+ digits)
    large_numbers = re.findall(r'(\d{3,})', text)
    if large_numbers:
        try:
            return int(large_numbers[0])
        except ValueError:
            pass
    
    # Last resort: any number
    number_matches = re.findall(r'(\d+)', text)
    if number_matches:
        for match in number_matches:
            try:
                num = int(match)
                # Only consider if it's a reasonably sized number for troop counts
                if num > 50:  # Avoid small numbers that might be dates or footnotes
                    return num
            except ValueError:
                continue
    
    return None

def clean_country_name(text):
    """Clean country name text."""
    if not isinstance(text, str):
        return None
    
    # Remove text in brackets, parentheses
    cleaned = re.sub(r'\([^)]*\)', '', text)
    cleaned = re.sub(r'\[[^\]]*\]', '', cleaned)
    
    # Remove footnote references and citation needed
    cleaned = re.sub(r'\[\d+\]', '', cleaned)
    cleaned = re.sub(r'\[citation needed\]', '', cleaned)
    
    # Remove excess whitespace
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    
    # Skip phrases that are clearly results, not countries
    result_phrases = [
        'victory', 'defeat', 'decisive', 'inconclusive', 'stalemate', 
        'draw', 'tactical', 'strategic', 'pyrrhic', 'truce', 'ceasefire'
    ]
    if any(phrase in cleaned.lower() for phrase in result_phrases) and len(cleaned.split()) <= 3:
        return None
    
    # Remove very short strings or just numbers or dates
    if len(cleaned) < 3 or cleaned.isdigit() or re.match(r'^\d+\s+\w+$', cleaned):
        return None
    
    # Replace some common abbreviations
    replacements = {
        'US': 'United States',
        'U.S.': 'United States',
        'U.S.A.': 'United States',
        'USA': 'United States',
        'UK': 'United Kingdom',
        'U.K.': 'United Kingdom',
        'Soviet Union': 'Russia',
        'USSR': 'Russia',
        'U.S.S.R.': 'Russia'
    }
    
    for abbr, full in replacements.items():
        if cleaned == abbr:
            cleaned = full
    
    return cleaned

def extract_html_content(element):
    """Extract a clean text representation of HTML content including flags and formatting."""
    if element is None:
        return ""
    
    # For simple text elements, just return the text
    if isinstance(element, str):
        return element.strip()
    
    # Create a list to store the content parts
    content_parts = []
    
    # Process all child elements
    for child in element.children:
        if child.name is None:  # Text node
            text = child.strip()
            if text:
                content_parts.append(text)
        elif child.name == 'br':
            content_parts.append('\n')
        elif child.name == 'li':
            content_parts.append('\n• ' + extract_html_content(child))
        elif child.name in ['b', 'strong', 'i', 'em', 'span', 'div', 'p']:
            content_parts.append(extract_html_content(child))
        elif child.name == 'a':
            content_parts.append(child.get_text().strip())
        elif child.name == 'ul' or child.name == 'ol':
            for li in child.find_all('li', recursive=False):
                content_parts.append('\n• ' + extract_html_content(li))
    
    # Join all the parts together
    return ' '.join(content_parts).strip()

def extract_countries_from_text(content):
    """Extract country names from text content with better handling of separators."""
    countries = []
    
    # Split by common separators
    parts = re.split(r'[,\n•]|\band\b', content)
    
    for part in parts:
        country = clean_country_name(part)
        if country and country not in countries and len(country) > 3:
            countries.append(country)
    
    return countries

def split_content_by_flags(content):
    """
    Split HTML content that may contain flags and country references.
    This improves extraction when countries are arranged with flag icons.
    """
    if not content:
        return []
    
    # Check for list items
    if '•' in content:
        parts = [p.strip() for p in content.split('•') if p.strip()]
        return parts
    
    # Split by commas and newlines
    parts = re.split(r'[,\n]+', content)
    return [p.strip() for p in parts if p.strip()]

def determine_battle_result(result_text, side1_countries, side2_countries):
    """Determine the battle result with improved pattern matching."""
    if not result_text:
        return "unknown", "unknown"
    
    result_lower = result_text.lower()
    
    # Check for ties
    if any(term in result_lower for term in ["stalemate", "draw", "inconclusive", "indecisive", "truce", "ceasefire"]):
        return "tied", "tied"
    
    # Check for side 1 victory
    side1_victory = any(term in result_lower for term in ["allied victory", "american victory", "british victory", "french victory"])
    for country in side1_countries:
        if country.lower() in result_lower and "victory" in result_lower:
            side1_victory = True
            break
    
    # Check for side 2 victory
    side2_victory = any(term in result_lower for term in ["german victory", "axis victory", "japanese victory", "confederate victory"])
    for country in side2_countries:
        if country.lower() in result_lower and "victory" in result_lower:
            side2_victory = True
            break
    
    # Determine results based on the checks
    if side1_victory and not side2_victory:
        return "winner", "loser"
    elif side2_victory and not side1_victory:
        return "loser", "winner"
    
    # Check for specific defeat mentions
    if "defeat" in result_lower:
        for country in side1_countries:
            if country.lower() in result_lower and "defeat" in result_lower:
                return "loser", "winner"
        for country in side2_countries:
            if country.lower() in result_lower and "defeat" in result_lower:
                return "winner", "loser"
    
    # Default to unknown if we can't determine
    return "unknown", "unknown"

def extract_infobox_data(infobox, key):
    """
    Extract data from infobox based on a key (header text)
    with improved handling of infobox structures.
    """
    if not infobox:
        return []
    
    data = []
    found_header = False
    
    # First try to find a row with the key in the header
    for row in infobox.find_all("tr"):
        if not found_header:
            # Check if this is a header row with our key
            th = row.find("th")
            if th and key.lower() in th.get_text().strip().lower():
                found_header = True
                # Some infoboxes include data in the same row as the header
                td = row.find("td")
                if td:
                    data.append(td)
        else:
            # After finding the header, collect subsequent data rows until we hit another header
            th = row.find("th")
            if th:
                # If the new header doesn't contain our key, we've moved to a new section
                if key.lower() not in th.get_text().strip().lower():
                    break
            
            # Add any data cells
            for td in row.find_all("td"):
                data.append(td)
    
    # If standard approach failed, try to find rows with specific structure
    if not data:
        # Look for row format: belligerent1, belligerent2
        for row in infobox.find_all("tr"):
            ths = row.find_all("th")
            tds = row.find_all("td")
            
            # Check if this is a row with key in any header and multiple data cells
            if any(key.lower() in th.get_text().strip().lower() for th in ths) and len(tds) >= 2:
                data = tds
                break
    
    return data

def clean_location_text(text):
    """Clean location text by removing unnecessary parts."""
    if not isinstance(text, str):
        return ""
    
    # Remove text in brackets, parentheses
    cleaned = re.sub(r'\([^)]*\)', '', text)
    
    # Remove footnote references
    cleaned = re.sub(r'\[\d+\]', '', cleaned)
    cleaned = re.sub(r'\[citation needed\]', '', cleaned)
    
    # Remove phrases like "near", "present-day", etc.
    cleaned = re.sub(r'\bnear\b|\bpresent-day\b|\bmodern-day\b|\bvicinity of\b', '', cleaned, flags=re.IGNORECASE)
    
    # Remove excess whitespace
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    
    # If there's a comma at the beginning after cleaning, remove it
    cleaned = re.sub(r'^,\s*', '', cleaned)
    
    return cleaned

def parse_location(text):
    """
    Parse location text to extract city and country.
    Uses several strategies to handle different formats.
    """
    if not text:
        return None, None
    
    # Common countries for reference
    common_countries = [
        "Afghanistan", "Albania", "Algeria", "Argentina", "Australia", "Austria", "Bangladesh", 
        "Belgium", "Brazil", "Bulgaria", "Canada", "China", "Croatia", "Czech Republic", 
        "Denmark", "Egypt", "Finland", "France", "Germany", "Greece", "Hungary", "India", 
        "Indonesia", "Iran", "Iraq", "Ireland", "Israel", "Italy", "Japan", "Korea", 
        "Malaysia", "Mexico", "Morocco", "Netherlands", "New Zealand", "Norway", "Pakistan", 
        "Philippines", "Poland", "Portugal", "Romania", "Russia", "Saudi Arabia", "Serbia", 
        "Singapore", "South Africa", "Spain", "Sweden", "Switzerland", "Syria", "Thailand", 
        "Turkey", "Ukraine", "United Arab Emirates", "United Kingdom", "United States", 
        "Vietnam", "Yemen", "Zimbabwe", "Soviet Union", "Ottoman Empire", "Prussia", 
        "Holy Roman Empire", "Byzantine Empire", "Roman Empire"
    ]
    
    # Strategy 1: Look for common format "City, Country"
    parts = [p.strip() for p in text.split(',')]
    
    # If we have exactly two parts, it might be "City, Country"
    if len(parts) == 2:
        # Check if the second part is a known country
        if parts[1] in common_countries or any(country in parts[1] for country in common_countries):
            return parts[0], parts[1]
    
    # Strategy 2: If we have more than 2 parts, the last part is often the country
    if len(parts) > 2:
        # Check if the last part is a known country
        if parts[-1] in common_countries or any(country in parts[-1] for country in common_countries):
            # The country is the last part
            country = parts[-1]
            
            # For the city, we need to be careful:
            # In cases like "Garibpur, Dhaka, Bangladesh", Dhaka might be the city
            # Check if the second-to-last part is a major city
            common_major_cities = ["Dhaka", "Cairo", "Tokyo", "Moscow", "Berlin", "Paris", "London", 
                                  "Beijing", "Delhi", "Rome", "Madrid", "Athens", "Istanbul", "Tehran"]
            
            if parts[-2] in common_major_cities:
                city = parts[-2]
            else:
                # Otherwise use the first part as the city
                city = parts[0]
            
            return city, country
    
    # Strategy 3: Check if any part contains a known country
    country = None
    for part in reversed(parts):  # Check from the end as country usually comes last
        if any(country_name in part for country_name in common_countries):
            country = part
            break
    
    if country:
        # If we found a country, assume the first part is the city
        city = parts[0]
        return city, country
    
    # Strategy 4: If only one part and no country identified, it might be just a region or landmark
    if len(parts) == 1:
        return parts[0], None
    
    # Strategy 5: If we have multiple parts but couldn't identify a country, use first as city, last as potential region
    if len(parts) > 1:
        return parts[0], parts[-1]
    
    # Default fallback: return None for both
    return None, None

def extract_location_data(infobox):
    """
    Extract location data from infobox with handling for various formats.
    Returns tuple of (city, country)
    """
    if not infobox:
        return None, None
    
    # Find location data in the infobox
    location_data = extract_infobox_data(infobox, "place") or extract_infobox_data(infobox, "location")
    
    if not location_data:
        return None, None
    
    # Get the text content of the first location element
    location_text = extract_html_content(location_data[0])
    if not location_text:
        return None, None
    
    print(f"Raw location text: {location_text}")
    
    # Clean the location text
    location_text = clean_location_text(location_text)
    
    # Extract city and country
    city, country = parse_location(location_text)
    
    return city, country

def scrape_battle_page(battle_id, battle_name, wiki_link):
    """Scrape an individual battle page for country participant information."""
    print(f"Scraping battle page: {battle_name} (ID: {battle_id})")
    
    # Check if the wiki_link is already a full URL
    if not wiki_link.startswith("http"):
        url = urljoin(BASE_URL, wiki_link)
    else:
        url = wiki_link
    
    participants = []
    
    try:
        # Fetch the page
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Failed to fetch page: {url} (Status: {response.status_code})")
            return participants
        
        # Parse the HTML
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Find the infobox (try multiple classes)
        infobox = soup.find("table", {"class": ["infobox", "vevent", "vcard"]})
        if not infobox:
            print(f"No infobox found for {battle_name} at {url}")
            return participants
        
        # Extract location information
        city, country = extract_location_data(infobox)
        print(f"Battle location - City: {city}, Country: {country}")
        
        # Extract result first to determine overall battle outcome
        result_text = ""
        result_data = extract_infobox_data(infobox, "result")
        if result_data:
            result_text = extract_html_content(result_data[0])
            print(f"Result: {result_text[:100]}...")
        
        # Extract belligerents
        belligerent_data = extract_infobox_data(infobox, "belligerent") or extract_infobox_data(infobox, "combatant")
        
        side1_countries = []
        side2_countries = []
        
        if len(belligerent_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(belligerent_data[0])
            print(f"Side 1 raw content: {side1_content[:100]}...")
            
            # Extract countries with improved extraction
            if side1_content:
                # First try to extract from list items if present
                parts = split_content_by_flags(side1_content)
                if parts:
                    for part in parts:
                        country_name = clean_country_name(part)
                        if country_name and country_name not in side1_countries:
                            side1_countries.append(country_name)
                else:
                    # Try extracting from the full content
                    extracted = extract_countries_from_text(side1_content)
                    side1_countries.extend([c for c in extracted if c not in side1_countries])
            
            # Process Side 2
            side2_content = extract_html_content(belligerent_data[1])
            print(f"Side 2 raw content: {side2_content[:100]}...")
            
            # Extract countries with improved extraction
            if side2_content:
                # First try to extract from list items if present
                parts = split_content_by_flags(side2_content)
                if parts:
                    for part in parts:
                        country_name = clean_country_name(part)
                        if country_name and country_name not in side2_countries:
                            side2_countries.append(country_name)
                else:
                    # Try extracting from the full content
                    extracted = extract_countries_from_text(side2_content)
                    side2_countries.extend([c for c in extracted if c not in side2_countries])
        
        # If no countries found, try harder with alternative approaches
        if not side1_countries and not side2_countries:
            # Get all text from the infobox
            infobox_text = infobox.get_text()
            
            # Try to identify common country names in the text
            common_countries = [
                "United States", "Germany", "France", "United Kingdom", "Great Britain",
                "Soviet Union", "Russia", "Japan", "Italy", "China", "Spain", "Austria",
                "Confederate States", "Union", "Prussia", "Ottoman Empire", "Turkey"
            ]
            
            found_countries = []
            for country in common_countries:
                if country in infobox_text:
                    found_countries.append(country)
            
            # If we found some countries, try to split them into sides
            if len(found_countries) >= 2:
                # Common historical pairings to guess sides
                opposing_pairs = [
                    (["United States", "United Kingdom", "France", "Russia", "Soviet Union"], 
                     ["Germany", "Japan", "Italy"]),
                    (["Union"], ["Confederate States"]),
                    (["United Kingdom", "Prussia", "Russia"], ["France"]),
                    (["United Kingdom", "France"], ["Spain"]),
                    (["Austria", "Prussia", "Russia"], ["Ottoman Empire", "Turkey"])
                ]
                
                for side1_candidates, side2_candidates in opposing_pairs:
                    side1_matches = [c for c in found_countries if c in side1_candidates]
                    side2_matches = [c for c in found_countries if c in side2_candidates]
                    
                    if side1_matches and side2_matches:
                        side1_countries = side1_matches
                        side2_countries = side2_matches
                        break
                
                # If we couldn't assign sides with pairs, just split the found countries
                if not side1_countries and not side2_countries and len(found_countries) >= 2:
                    middle = len(found_countries) // 2
                    side1_countries = found_countries[:middle]
                    side2_countries = found_countries[middle:]
        
        print(f"Side 1 countries: {side1_countries}")
        print(f"Side 2 countries: {side2_countries}")
        
        # Extract strength information
        strength_data = extract_infobox_data(infobox, "strength")
        
        side1_troops = None
        side2_troops = None
        
        if len(strength_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(strength_data[0])
            print(f"Side 1 strength raw: {side1_content[:100]}...")
            
            # Extract troop numbers with improved extraction
            if side1_content:
                # Try multiple keywords for troop counts
                keywords = ['men', 'troops', 'soldiers', 'personnel', 'combatants', 'infantry', 'army']
                side1_troops = extract_number(side1_content, keywords)
            
            # Process Side 2
            side2_content = extract_html_content(strength_data[1])
            print(f"Side 2 strength raw: {side2_content[:100]}...")
            
            # Extract troop numbers with improved extraction
            if side2_content:
                # Try multiple keywords for troop counts
                keywords = ['men', 'troops', 'soldiers', 'personnel', 'combatants', 'infantry', 'army']
                side2_troops = extract_number(side2_content, keywords)
        
        print(f"Side 1 troops: {side1_troops}")
        print(f"Side 2 troops: {side2_troops}")
        
        # Extract casualty information
        casualty_data = extract_infobox_data(infobox, "casualt") or extract_infobox_data(infobox, "loss")
        
        side1_deaths = None
        side2_deaths = None
        
        if len(casualty_data) >= 2:
            # Most common case: side-by-side layout with two columns
            
            # Process Side 1
            side1_content = extract_html_content(casualty_data[0])
            print(f"Side 1 casualties raw: {side1_content[:100]}...")
            
            # Extract death numbers with improved extraction
            if side1_content:
                # Try multiple keywords for death counts
                keywords = ['killed', 'dead', 'deaths', 'fatalities', 'kia', 'killed in action']
                side1_deaths = extract_number(side1_content, keywords)
                
                # If no deaths found with keywords, try extracting other casualty numbers
                if side1_deaths is None:
                    side1_deaths = extract_number(side1_content, ['casualties', 'wounded', 'injured'])
            
            # Process Side 2
            side2_content = extract_html_content(casualty_data[1])
            print(f"Side 2 casualties raw: {side2_content[:100]}...")
            
            # Extract death numbers with improved extraction
            if side2_content:
                # Try multiple keywords for death counts
                keywords = ['killed', 'dead', 'deaths', 'fatalities', 'kia', 'killed in action']
                side2_deaths = extract_number(side2_content, keywords)
                
                # If no deaths found with keywords, try extracting other casualty numbers
                if side2_deaths is None:
                    side2_deaths = extract_number(side2_content, ['casualties', 'wounded', 'injured'])
        
        print(f"Side 1 deaths: {side1_deaths}")
        print(f"Side 2 deaths: {side2_deaths}")
        
        # Determine the result for each side based on the overall result
        side1_result, side2_result = determine_battle_result(result_text, side1_countries, side2_countries)
        
        print(f"Side 1 result: {side1_result}")
        print(f"Side 2 result: {side2_result}")
        
        # Add the participants with the new location columns
        for country_name in side1_countries:
            participants.append({
                "battle_id": battle_id,
                "country": country_name,
                "troops": side1_troops,
                "deaths": side1_deaths,
                "result": side1_result,
                "city_battle_location": city,
                "country_battle_location": country
            })
        
        for country_name in side2_countries:
            participants.append({
                "battle_id": battle_id,
                "country": country_name,
                "troops": side2_troops,
                "deaths": side2_deaths,
                "result": side2_result,
                "city_battle_location": city,
                "country_battle_location": country
            })
        
        print(f"Found {len(participants)} participants for {battle_name}")
        
        return participants
    
    except Exception as e:
        print(f"Error scraping {battle_name}: {e}")
        import traceback
        traceback.print_exc()
        return participants

def main():
    try:
        # Load the battles from the CSV file
        battles_df = load_battles_csv()
        
        # Create a list to store all participants
        all_participants = []
        
        # Process all battles or limit for testing
        max_battles = len(battles_df)  # Change this to limit the number of battles processed
        num_battles = min(len(battles_df), max_battles)
        
        print(f"Processing {num_battles} battles...")
        
        # Process each battle
        for index, battle in battles_df.head(num_battles).iterrows():
            battle_id = battle["battle_id"]
            battle_name = battle["battle_name"]
            wiki_link = battle["wiki_link"]
            
            # Skip if missing wiki link
            if pd.isna(wiki_link) or not wiki_link:
                print(f"Skipping battle {battle_name} (ID: {battle_id}) - Missing wiki link")
                continue
            
            # Scrape the battle page for country information
            participants = scrape_battle_page(battle_id, battle_name, wiki_link)
            
            # Add participants to the overall list
            all_participants.extend(participants)
            
            # Add a random delay to avoid rate limiting
            time.sleep(random.uniform(1.0, 3.0))
            
            # Print progress every 10 battles
            if (index + 1) % 10 == 0 or (index + 1) == num_battles:
                print(f"Progress: {index + 1}/{num_battles} battles processed ({((index + 1)/num_battles)*100:.1f}%)")
        
        # Create a DataFrame from the participants data
        if not all_participants:
            print("No participants found. Check the scraping logic.")
            return
        
        participants_df = pd.DataFrame(all_participants)
        
        # Add a unique participant_id as the primary key
        participants_df.reset_index(drop=True, inplace=True)
        participants_df['participant_id'] = participants_df.index + 1  # Start IDs from 1
        
        # Reorder columns to put participant_id first
        cols = ['participant_id', 'battle_id', 'country', 'troops', 'deaths', 'result', 
                'city_battle_location', 'country_battle_location']
        participants_df = participants_df[cols]
        
        # Save to CSV
        participants_df.to_csv("battle_info.csv", index=False)
        
        print(f"\n✅ Scraped {len(participants_df)} participant entries for {num_battles} battles.")
        print("Saved to 'battle_info.csv'")
        
        # Print stats about data extraction
        troops_count = participants_df['troops'].notna().sum()
        deaths_count = participants_df['deaths'].notna().sum()
        result_count = participants_df[participants_df['result'] != "unknown"].shape[0]
        city_count = participants_df['city_battle_location'].notna().sum()
        country_count = participants_df['country_battle_location'].notna().sum()
        
        print(f"\nExtraction statistics:")
        print(f"- Participants with troop numbers: {troops_count} ({troops_count/len(participants_df)*100:.1f}%)")
        print(f"- Participants with death counts: {deaths_count} ({deaths_count/len(participants_df)*100:.1f}%)")
        print(f"- Participants with known results: {result_count} ({result_count/len(participants_df)*100:.1f}%)")
        print(f"- Battles with city location: {city_count} ({city_count/len(participants_df)*100:.1f}%)")
        print(f"- Battles with country location: {country_count} ({country_count/len(participants_df)*100:.1f}%)")
        
        # Show some sample data
        print("\nSample of participant data:")
        for i, row in participants_df.head(5).iterrows():
            print(f"{i+1}. Participant ID: {row['participant_id']}, Battle ID: {row['battle_id']}, Country: {row['country']}")
            print(f"   Troops: {row['troops'] if pd.notna(row['troops']) else 'Unknown'}")
            print(f"   Deaths: {row['deaths'] if pd.notna(row['deaths']) else 'Unknown'}")
            print(f"   Result: {row['result'] if pd.notna(row['result']) else 'Unknown'}")
            print(f"   Battle Location: {row['city_battle_location'] if pd.notna(row['city_battle_location']) else 'Unknown'}, "
                  f"{row['country_battle_location'] if pd.notna(row['country_battle_location']) else 'Unknown'}")
    
    except Exception as e:
        print(f"\n❌ Error: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# Loaded 962 battles from /Users/louis/Desktop/Coding/Github/WarCast/Data/Pre_clean/battles_list.csv
# Processing 962 battles...
# Scraping battle page: Battle of Aachen (ID: 1)
# Raw location text: Aachen , Germany 50°46′35″N 06°05′00″E﻿ / ﻿50.77639°N 6.08333°E﻿ / 50.77639; 6.08333
# Battle location - City: Aachen, Country: Germany 50°46′35″N 06°05′00″E﻿ / ﻿50.77639°N 6.08333°E﻿ / 50.77639; 6.08333
# Result: American victory...
# Side 1 raw content: United States...
# Side 2 raw content: Germany...
# Side 1 countries: ['United States']
# Side 2 countries: ['Germany']
# Side 1 strength raw: 100,000 soldiers...
# Side 2 strength raw: 13,000 soldiers
#  5,000 Volkssturm...
# Side 1 troops: 100000
# Side 2 troops: 13000
# Side 1 casualties raw: 7,000+ casualties
#  including 2,000 killed...
# Side 2 casualties raw: 5,000 killed (estimate),
#  5,600 captured...
# Side 1 deaths: 2000
# Side 2 deaths: 5000
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Aachen
# Scraping battle page: Battle of Abensberg (ID: 2)
# Raw location text: Abensberg , Bavaria , Germany 48°48′N 11°51′E﻿ / ﻿48.800°N 11.850°E﻿ / 48.800; 11.850
# Battle location - City: Abensberg, Country: Germany 48°48′N 11°51′E﻿ / ﻿48.800°N 11.850°E﻿ / 48.800; 11.850
# Result: French victory...
# Side 1 raw content: First French Empire
#   Kingdom of Bavaria
#   Württemberg...
# Side 2 raw content: Austrian Empire...
# Side 1 countries: ['First French Empire', 'Kingdom of Bavaria', 'Württemberg']
# Side 2 countries: ['Austrian Empire']
# Side 1 strength raw: 55,000...
# Side 2 strength raw: 42,000...
# Side 1 troops: 55000
# Side 2 troops: 42000
# Side 1 casualties raw: 1,000...
# Side 2 casualties raw: 7,200, 12 guns...
# Side 1 deaths: 1000
# Side 2 deaths: 7200
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of Abensberg
# Scraping battle page: Battle of Abbeville (ID: 3)
# Raw location text: Abbeville 50°06′21″N 01°50′09″E﻿ / ﻿50.10583°N 1.83583°E﻿ / 50.10583; 1.83583
# Battle location - City: Abbeville 50°06′21″N 01°50′09″E﻿ / ﻿50.10583°N 1.83583°E﻿ / 50.10583; 1.83583, Country: None
# Result: German victory...
# Side 1 raw content: France
#   United Kingdom...
# Side 2 raw content: Germany...
# Side 1 countries: ['France', 'United Kingdom']
# Side 2 countries: ['Germany']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: 2,000 killed or captured
#  210 AFVs destroyed or captured...
# Side 2 casualties raw: 57th Infantry Division: 1,000 casualties including about 300 POW...
# Side 1 deaths: 2000
# Side 2 deaths: 1000
# Side 1 result: loser
# Side 2 result: winner
# Found 3 participants for Battle of Abbeville
# Scraping battle page: Battle of Abukir (ID: 4)
# Raw location text: Abu Qir , Egypt 31°19′N 30°04′E﻿ / ﻿31.317°N 30.067°E﻿ / 31.317; 30.067
# Battle location - City: Abu Qir, Country: Egypt 31°19′N 30°04′E﻿ / ﻿31.317°N 30.067°E﻿ / 31.317; 30.067
# Result: French victory...
# Side 1 raw content: France...
# Side 2 raw content: Ottoman Empire
#  Great Britain...
# Side 1 countries: ['France']
# Side 2 countries: ['Ottoman Empire', 'Great Britain']
# Side 1 strength raw: 9,000 infantry
#  1,000 cavalry
#  17 guns...
# Side 2 strength raw: 5,000 under Mustapha Pasha, 2,000 under Hassan Bey
#  7,000 in a state fit to fight according to the ...
# Side 1 troops: 9000
# Side 2 troops: 20000
# Side 1 casualties raw: 220 killed in action
#  600 wounded...
# Side 2 casualties raw: 2,000 killed in action
#  11,000 drowned
#  5,000 captured
#  2,000 missing and unaccounted for...
# Side 1 deaths: 220
# Side 2 deaths: 2000
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Battle of Abukir
# Scraping battle page: Battle of Abu Klea (ID: 5)
# Raw location text: Khartoum 16°59′00″N 33°18′00″E﻿ / ﻿16.9833333°N 33.3°E﻿ / 16.9833333; 33.3
# Battle location - City: Khartoum 16°59′00″N 33°18′00″E﻿ / ﻿16.9833333°N 33.3°E﻿ / 16.9833333; 33.3, Country: None
# Result: British victory...
# Side 1 raw content: United Kingdom
# • India...
# Side 2 raw content: Mahdist State...
# Side 1 countries: ['United Kingdom', 'India']
# Side 2 countries: ['Mahdist State']
# Side 1 strength raw: 1,400...
# Side 2 strength raw: 14,000 (3,000 engaged in the battle)...
# Side 1 troops: 1400
# Side 2 troops: 14000
# Side 1 casualties raw: 76 killed
#  82 wounded...
# Side 2 casualties raw: 1,100 killed, unknown wounded (British claim)...
# Side 1 deaths: 76
# Side 2 deaths: 1100
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Battle of Abu Klea
# Scraping battle page: Battle of Aclea (ID: 6)
# Raw location text: Unknown location, possibly Ockley , England
# Battle location - City: Unknown location, Country: England
# Result: West Saxon victory...
# Side 1 raw content: Kingdom of Wessex...
# Side 2 raw content: Kingdom of Denmark...
# Side 1 countries: ['Kingdom of Wessex']
# Side 2 countries: ['Kingdom of Denmark']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Aclea
# Scraping battle page: Battle of Acragas (ID: 7)
# Raw location text: Akragas
# Battle location - City: Akragas, Country: None
# Result: Carthaginian victory...
# Side 1 raw content: Carthage...
# Side 2 raw content: Akragas
#  Syracuse...
# Side 1 countries: ['Carthage']
# Side 2 countries: ['Akragas', 'Syracuse']
# Side 1 strength raw: 60,000
#  120 triremes
#  1,000 transport ships...
# Side 2 strength raw: 35,000
#  40 triremes
#  Supply convoy...
# Side 1 troops: 60000
# Side 2 troops: 35000
# Side 1 casualties raw: 6,000 killed
#  15 triremes lost...
# Side 2 casualties raw: 8 triremes sunk
#  Supply convoy captured
#  Population massacred...
# Side 1 deaths: 6000
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Acragas
# Scraping battle page: Siege of Acre (1189–1191) (ID: 8)
# Raw location text: Acre 32°55′39″N 35°04′54″E﻿ / ﻿32.9275°N 35.0817°E﻿ / 32.9275; 35.0817
# Battle location - City: Acre 32°55′39″N 35°04′54″E﻿ / ﻿32.9275°N 35.0817°E﻿ / 32.9275; 35.0817, Country: None
# Result: Crusader victory...
# Side 1 raw content: • Kingdom of England
# • Kingdom of France
# • Kingdom of Jerusalem • Knights Templar
# • Order Of St L...
# Side 2 raw content: Ayyubids...
# Side 1 countries: ['Kingdom of England', 'Kingdom of France', 'Kingdom of Jerusalem', 'Knights Templar', 'Order Of St Lazarus', 'Knights Hospitaller', 'Republic of Pisa', 'Kingdom of Sicily', 'Papal States', 'Holy Roman Empire', 'Duchy of Bohemia', 'Armenian Kingdom of Cilicia', 'Kingdom of Denmark', 'Republic of Genoa']
# Side 2 countries: ['Ayyubids']
# Side 1 strength raw: ...
# Side 2 strength raw: 45,000–50,000 men
# • Garrison: 5,000–10,000 men
# • Relief force:
# • 40,000 men
# • 50 galleys...
# Side 1 troops: None
# Side 2 troops: 50000
# Side 1 casualties raw: 19,000 dead...
# Side 2 casualties raw: ...
# Side 1 deaths: 19000
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 15 participants for Siege of Acre (1189–1191)
# Scraping battle page: Siege of Acre (1291) (ID: 9)
# Raw location text: Acre , Kingdom of Jerusalem 32°56′N 35°05′E﻿ / ﻿32.933°N 35.083°E﻿ / 32.933; 35.083
# Battle location - City: Acre, Country: Kingdom of Jerusalem 32°56′N 35°05′E﻿ / ﻿32.933°N 35.083°E﻿ / 32.933; 35.083
# Result: Mamluk victory • Collapse of the Crusader states...
# Side 1 raw content: Mamluk Sultanate
# • Ayyubid remnant emirate of Hama...
# Side 2 raw content: • Kingdom of Jerusalem (in union with Cyprus )
# • Knights Templar
# • Knights Hospitaller
# • Teutonic...
# Side 1 countries: ['Mamluk Sultanate', 'Ayyubid remnant emirate of Hama']
# Side 2 countries: ['Kingdom of Jerusalem', 'Knights Templar', 'Knights Hospitaller', 'Teutonic Order', 'Order of St. Thomas', 'Order of St. Lazarus']
# Side 1 strength raw: Unknown...
# Side 2 strength raw: Acre: 15,000 Cyprus: 700...
# Side 1 troops: None
# Side 2 troops: 15000
# Side 1 casualties raw: Unknown...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 8 participants for Siege of Acre (1291)
# Scraping battle page: Siege of Acre (1799) (ID: 10)
# Raw location text: Acre , Sidon Eyalet , Ottoman Empire 32°55′19″N 35°04′12″E﻿ / ﻿32.922°N 35.070°E﻿ / 32.922; 35.070
# Battle location - City: Acre, Country: Ottoman Empire 32°55′19″N 35°04′12″E﻿ / ﻿32.922°N 35.070°E﻿ / 32.922; 35.070
# Result: Anglo–Ottoman victory...
# Side 1 raw content: Ottoman Empire
#   Great Britain...
# Side 2 raw content: French Republic...
# Side 1 countries: ['Ottoman Empire', 'Great Britain']
# Side 2 countries: ['French Republic']
# Side 1 strength raw: Garrison : 5,000 men
#  Relief army ( Mt. Tabor ): 35,000 –40,000
#  Support : 2 British ships of the ...
# Side 2 strength raw: 12,000 –13,000...
# Side 1 troops: 5000
# Side 2 troops: 12500
# Side 1 casualties raw: 2,000 (for the siege)...
# Side 2 casualties raw: 4,000
#  or 4,500
# • 2,300 killed
# • 2,200 wounded or ill...
# Side 1 deaths: 2000
# Side 2 deaths: 2300
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Siege of Acre (1799)
# Progress: 10/962 battles processed (1.0%)
# Scraping battle page: Battle of the Admin Box (ID: 11)
# Raw location text: Arakan , Burma 20°55′55″N 92°26′58″E﻿ / ﻿20.932080°N 92.449349°E﻿ / 20.932080; 92.449349
# Battle location - City: Arakan, Country: Burma 20°55′55″N 92°26′58″E﻿ / ﻿20.932080°N 92.449349°E﻿ / 20.932080; 92.449349
# Result: Allied victory...
# Side 1 raw content: United Kingdom
# • British Raj...
# Side 2 raw content: Japan
# • Azad Hind...
# Side 1 countries: ['United Kingdom', 'British Raj']
# Side 2 countries: ['Japan', 'Azad Hind']
# Side 1 strength raw: At start:
#  2 infantry divisions
#  1 armoured regiment
#  Reinforcements:
#  2 infantry divisions...
# Side 2 strength raw: 1 infantry division...
# Side 1 troops: 1
# Side 2 troops: 1
# Side 1 casualties raw: 3,506 total
#  Several fighter aircraft...
# Side 2 casualties raw: 3,106 killed
#  2,229 wounded
#  Several fighter aircraft...
# Side 1 deaths: 3506
# Side 2 deaths: 3106
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of the Admin Box
# Scraping battle page: Battle of Akroinon (ID: 12)
# Raw location text: Akroinon, Byzantine Empire (present-day Afyon , Turkey ) 38°45′N 30°32′E﻿ / ﻿38.750°N 30.533°E﻿ / 38.750; 30.533
# Battle location - City: Akroinon, Country: Byzantine Empire 38°45′N 30°32′E﻿ / ﻿38.750°N 30.533°E﻿ / 38.750; 30.533
# Result: Byzantine victory...
# Side 1 raw content: Umayyad Caliphate...
# Side 2 raw content: Byzantine Empire...
# Side 1 countries: ['Umayyad Caliphate']
# Side 2 countries: ['Byzantine Empire']
# Side 1 strength raw: 20,000...
# Side 2 strength raw: Unknown...
# Side 1 troops: 20000
# Side 2 troops: None
# Side 1 casualties raw: 13,200...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: 13200
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Akroinon
# Scraping battle page: Battle of Actium (ID: 13)
# Raw location text: Ionian Sea , near the promontory of Actium in Greece 38°55′30″N 20°43′30″E﻿ / ﻿38.92500°N 20.72500°E﻿ / 38.92500; 20.72500
# Battle location - City: Ionian Sea, Country: the promontory of Actium in Greece 38°55′30″N 20°43′30″E﻿ / ﻿38.92500°N 20.72500°E﻿ / 38.92500; 20.72500
# Result: Octavian victory...
# Side 1 raw content: Octavian 's forces...
# Side 2 raw content: Antony 's forces
#  Ptolemaic Egypt...
# Side 1 countries: ["Octavian 's forces"]
# Side 2 countries: ["Antony 's forces", 'Ptolemaic Egypt']
# Side 1 strength raw: 250–400 galleys
#  3,000 archers
#  16,000 infantry on ships...
# Side 2 strength raw: 250–500 larger galleys
#  30–50 transports
#  20,000–70,000 infantry on ships
#  2,000 archers...
# Side 1 troops: 16000
# Side 2 troops: 70000
# Side 1 casualties raw: About 2,500 killed...
# Side 2 casualties raw: Over 5,000 killed
#  250 ships sunk or captured...
# Side 1 deaths: 2500
# Side 2 deaths: 5000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Actium
# Scraping battle page: Battle of Ad Decimum (ID: 14)
# Raw location text: Near Carthage and modern-day Tunis.
# Battle location - City: Carthage and Tunis., Country: None
# Result: Byzantine victory...
# Side 1 raw content: Byzantine Empire...
# Side 2 raw content: Vandal Kingdom...
# Side 1 countries: ['Byzantine Empire']
# Side 2 countries: ['Vandal Kingdom']
# Side 1 strength raw: 18,000 men or 15,000 men...
# Side 2 strength raw: Greater than the Romans, 20,000 men at maximum. Most likely 10,000–12,000 men or 11,000 men....
# Side 1 troops: 18000
# Side 2 troops: 20000
# Side 1 casualties raw: 1,000? Still unknown modern estimate...
# Side 2 casualties raw: 3,000–4,000? Still unknown modern estimate...
# Side 1 deaths: 1000
# Side 2 deaths: 3500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Ad Decimum
# Scraping battle page: Battle of Adwa (ID: 15)
# Raw location text: Adwa , Tigray Province , Ethiopia 14°1′8″N 38°58′24″E﻿ / ﻿14.01889°N 38.97333°E﻿ / 14.01889; 38.97333﻿ (Battle of Adwa)
# Battle location - City: Adwa, Country: Ethiopia 14°1′8″N 38°58′24″E﻿ / ﻿14.01889°N 38.97333°E﻿ / 14.01889; 38.97333﻿
# Result: Ethiopian victory...
# Side 1 raw content: Ethiopia...
# Side 2 raw content: Italy...
# Side 1 countries: ['Ethiopia']
# Side 2 countries: ['Italy']
# Side 1 strength raw: 73,000–100,000...
# Side 2 strength raw: 14,519–17,770...
# Side 1 troops: 86500
# Side 2 troops: 16144
# Side 1 casualties raw: 3,886–7,000 killed...
# Side 2 casualties raw: ~6,000 killed
#  3,865 captured...
# Side 1 deaths: 7000
# Side 2 deaths: 6000
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Adwa
# Scraping battle page: Battle of Adwalton Moor (ID: 16)
# Raw location text: Adwalton , Yorkshire 53°45′04″N 1°39′50″W﻿ / ﻿53.751°N 1.664°W﻿ / 53.751; -1.664
# Battle location - City: Adwalton, Country: Yorkshire 53°45′04″N 1°39′50″W﻿ / ﻿53.751°N 1.664°W﻿ / 53.751; -1.664
# Result: Royalist Victory...
# Side 1 raw content: Royalists...
# Side 2 raw content: Parliamentarians...
# Side 1 countries: ['Royalists']
# Side 2 countries: ['Parliamentarians']
# Side 1 strength raw: 4,000 foot soldiers
#  3,000 horse...
# Side 2 strength raw: 6,000 foot soldiers
#  1,500 horse
#  Local countrymen...
# Side 1 troops: 4000
# Side 2 troops: 1500
# Side 1 casualties raw: 200 killed
#  300 wounded...
# Side 2 casualties raw: 500 killed
#  1,500 captured...
# Side 1 deaths: 200
# Side 2 deaths: 500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Adwalton Moor
# Scraping battle page: Battle of Aegina (ID: 17)
# Raw location text: Mainland Greece
# Battle location - City: Mainland Greece, Country: Mainland Greece
# Result: Arrangement between Sparta and Athens ratified by the " Thirty Years' Peace "...
# Side 1 raw content: Delian League led by Athens ,
#  Argos...
# Side 2 raw content: Peloponnesian League led by Sparta ,
#  Thebes...
# Side 1 countries: ['Delian League led by Athens', 'Argos']
# Side 2 countries: ['Peloponnesian League led by Sparta', 'Thebes']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Aegina
# Scraping battle page: Battle of Aegospotami (ID: 18)
# Raw location text: Aegospotami , Hellespont
#  (present-day Çanakkale Province , Turkey ) 40°15′N 26°33′E﻿ / ﻿40.250°N 26.550°E﻿ / 40.250; 26.550
# Battle location - City: Aegospotami, Country: Hellespont 40°15′N 26°33′E﻿ / ﻿40.250°N 26.550°E﻿ / 40.250; 26.550
# Result: • Decisive Spartan victory • Athens is besieged and surrenders
# • End of the Peloponnesian War...
# Side 1 raw content: ...
# Side 2 raw content: ...
# Side 1 countries: []
# Side 2 countries: []
# Side 1 strength raw: 170 ships...
# Side 2 strength raw: 180 ships 36,000 men...
# Side 1 troops: 170
# Side 2 troops: 36000
# Side 1 casualties raw: Minimal...
# Side 2 casualties raw: 160 ships,
#  3,000 sailors executed...
# Side 1 deaths: None
# Side 2 deaths: 3000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 0 participants for Battle of Aegospotami
# Scraping battle page: Battle of Agincourt (ID: 19)
# Raw location text: Azincourt , County of Saint-Pol (now Pas-de-Calais ) 50°27′49″N 2°8′30″E﻿ / ﻿50.46361°N 2.14167°E﻿ / 50.46361; 2.14167
# Battle location - City: Azincourt, Country: County of Saint-Pol 50°27′49″N 2°8′30″E﻿ / ﻿50.46361°N 2.14167°E﻿ / 50.46361; 2.14167
# Result: English victory...
# Side 1 raw content: Kingdom of England...
# Side 2 raw content: Kingdom of France...
# Side 1 countries: ['Kingdom of England']
# Side 2 countries: ['Kingdom of France']
# Side 1 strength raw: 6,000 –8,100 men
#  (modern estimates; see Numbers at Agincourt )
#  • About 5 ⁄ 6 archers
#  •...
# Side 2 strength raw: 14,000–15,000 men or up to 25,000 if counting armed servants
#  • 10,000 men-at-arms
#  • 4,000–5,000 ...
# Side 1 troops: 8100
# Side 2 troops: 15000
# Side 1 casualties raw: Up to 600 killed (112 identified)...
# Side 2 casualties raw: • 6,000 killed (most of whom were of the French nobility)
#  • 700–2,200 captured...
# Side 1 deaths: 600
# Side 2 deaths: 6000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Agincourt
# Scraping battle page: Battle of Agnadello (ID: 20)
# Raw location text: Near Agnadello, between Milan and Bergamo , present-day Italy
# Battle location - City: Agnadello, Country: Italy
# Result: French victory...
# Side 1 raw content: Kingdom of France...
# Side 2 raw content: Republic of Venice...
# Side 1 countries: ['Kingdom of France']
# Side 2 countries: ['Republic of Venice']
# Side 1 strength raw: 30,000...
# Side 2 strength raw: 15,000...
# Side 1 troops: 30000
# Side 2 troops: 15000
# Side 1 casualties raw: 500...
# Side 2 casualties raw: 10,000+...
# Side 1 deaths: 500
# Side 2 deaths: 10000
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Agnadello
# Progress: 20/962 battles processed (2.1%)
# Scraping battle page: Battle of Agusan Hill (ID: 21)
# Raw location text: Cagayan de Oro , Mindanao
# Battle location - City: Cagayan de Oro, Country: Mindanao
# Result: American victory...
# Side 1 raw content: First Philippine Republic...
# Side 2 raw content: United States...
# Side 1 countries: ['First Philippine Republic']
# Side 2 countries: ['United States']
# Side 1 strength raw: 500...
# Side 2 strength raw: 80...
# Side 1 troops: 500
# Side 2 troops: 80
# Side 1 casualties raw: 38 killed...
# Side 2 casualties raw: 2 killed; 3 wounded...
# Side 1 deaths: 38
# Side 2 deaths: 2
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Agusan Hill
# Scraping battle page: Battle of Ahvenanmaa (ID: 22)
# Raw location text: Hanko Peninsula , southern Finland
# Battle location - City: Hanko Peninsula, Country: southern Finland
# Result: Russian victory...
# Side 1 raw content: Swedish Empire...
# Side 2 raw content: • Tsardom of Russia
# • Navy...
# Side 1 countries: ['Swedish Empire']
# Side 2 countries: ['Tsardom of Russia', 'Navy']
# Side 1 strength raw: 1 pram
#  6 galleys
#  2 skerry boats
#  941–2,400 men...
# Side 2 strength raw: 98 galleys , of which 23 engaged, with about 3,900 men aboard...
# Side 1 troops: 2400
# Side 2 troops: 3900
# Side 1 casualties raw: All ships captured or sunk
#  361 killed
#  580 captured –2,400 killed or captured...
# Side 2 casualties raw: Russian accounts :
#  125 killed, 341 wounded
#  Swedish accounts :
#  3,000 men, 50+ galleys...
# Side 1 deaths: 361
# Side 2 deaths: 125
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Ahvenanmaa
# Scraping battle page: Battle of Ain Jalut (ID: 23)
# Raw location text: Near Ma'ayan Harod ( Hebrew ) or Ayn Jalut ( Arabic ), Jezreel Valley , Israel
# Battle location - City: Ma'ayan Harod or Ayn Jalut, Country: Israel
# Result: Mamluk victory...
# Side 1 raw content: • Mamluk Sultanate
# • Ayyubid emirs of Kerak and Hamah...
# Side 2 raw content: • Ilkhanate
# • Cilician Armenia
# • Kingdom of Georgia...
# Side 1 countries: ['Mamluk Sultanate', 'Ayyubid emirs of Kerak and Hamah']
# Side 2 countries: ['Ilkhanate', 'Cilician Armenia', 'Kingdom of Georgia']
# Side 1 strength raw: 15,000–20,000...
# Side 2 strength raw: 10,000–20,000...
# Side 1 troops: 17500
# Side 2 troops: 15000
# Side 1 casualties raw: Unknown...
# Side 2 casualties raw: High...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 5 participants for Battle of Ain Jalut
# Scraping battle page: First Battle of the Aisne (ID: 24)
# Raw location text: Aisne River , France 49°26′N 3°40′E﻿ / ﻿49.433°N 3.667°E﻿ / 49.433; 3.667
# Battle location - City: Aisne River, Country: France 49°26′N 3°40′E﻿ / ﻿49.433°N 3.667°E﻿ / 49.433; 3.667
# Result: Indecisive...
# Side 1 raw content: France
#   United Kingdom...
# Side 2 raw content: German Empire...
# Side 1 countries: ['France', 'United Kingdom']
# Side 2 countries: ['German Empire']
# Side 1 strength raw: Fifth Army
#   Sixth Army
#   BEF...
# Side 2 strength raw: First Army
#   Second Army
#   Seventh Army...
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: Unknown
#   13,541 killed or wounded...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: 13541
# Side 2 deaths: None
# Side 1 result: tied
# Side 2 result: tied
# Found 3 participants for First Battle of the Aisne
# Scraping battle page: Second Battle of the Aisne (ID: 25)
# Raw location text: Between Soissons and Reims , France 49°24′N 3°36′E﻿ / ﻿49.400°N 3.600°E﻿ / 49.400; 3.600
# Battle location - City: Between Soissons and Reims, Country: France 49°24′N 3°36′E﻿ / ﻿49.400°N 3.600°E﻿ / 49.400; 3.600
# Result: Inconclusive...
# Side 1 raw content: France
#  Russia...
# Side 2 raw content: Germany...
# Side 1 countries: ['France', 'Russia']
# Side 2 countries: ['Germany']
# Side 1 strength raw: 53 French divisions
#  4 Russian divisions...
# Side 2 strength raw: 38 divisions...
# Side 1 troops: 53
# Side 2 troops: None
# Side 1 casualties raw: 187,000...
# Side 2 casualties raw: 163,000...
# Side 1 deaths: 187000
# Side 2 deaths: 163000
# Side 1 result: tied
# Side 2 result: tied
# Found 3 participants for Second Battle of the Aisne
# Scraping battle page: Third Battle of the Aisne (ID: 26)
# Raw location text: Aisne River near Paris , France 49°23′N 3°44′E﻿ / ﻿49.383°N 3.733°E﻿ / 49.383; 3.733
# Battle location - City: Aisne River Paris, Country: France 49°23′N 3°44′E﻿ / ﻿49.383°N 3.733°E﻿ / 49.383; 3.733
# Result: See Aftermath section...
# Side 1 raw content: France
#  United Kingdom
#  United States
#   Italy...
# Side 2 raw content: German Empire...
# Side 1 countries: ['France', 'United Kingdom', 'United States', 'Italy']
# Side 2 countries: ['German Empire']
# Side 1 strength raw: ...
# Side 2 strength raw: (over 20 divisions and 4,000 artillery guns)...
# Side 1 troops: None
# Side 2 troops: 4000
# Side 1 casualties raw: 127,000...
# Side 2 casualties raw: 130,000...
# Side 1 deaths: 127000
# Side 2 deaths: 130000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 5 participants for Third Battle of the Aisne
# Scraping battle page: Battle of Ajnadayn (ID: 27)
# Raw location text: Ajnadayn, Palaestina Prima (Palestine)
# Battle location - City: Ajnadayn, Country: Palaestina Prima
# Result: Muslim victory...
# Side 1 raw content: Byzantine Empire...
# Side 2 raw content: Rashidun Caliphate...
# Side 1 countries: ['Byzantine Empire']
# Side 2 countries: ['Rashidun Caliphate']
# Side 1 strength raw: Max. 40,000 – 100...
# Side 2 strength raw: Max. 500 – 20,000...
# Side 1 troops: 20050
# Side 2 troops: 10250
# Side 1 casualties raw: 50,000 killed
#  ( Al-Waqidi ),
#  Modern estimates unknown....
# Side 2 casualties raw: 5,000 ( Al-Waqidi )
#  Modern estimates unknown....
# Side 1 deaths: 50000
# Side 2 deaths: 5000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Ajnadayn
# Scraping battle page: Battle of Akraba (632) (ID: 28)
# Raw location text: Plain of Aqraba, al-Yamama , Arabia
# Battle location - City: Plain of Aqraba, Country: Arabia
# Result: Muslim victory...
# Side 1 raw content: Rashidun Caliphate...
# Side 2 raw content: Banu Hanifa and Musaylima's followers...
# Side 1 countries: ['Rashidun Caliphate']
# Side 2 countries: ["Banu Hanifa and Musaylima's followers"]
# Side 1 strength raw: 10,000-13,000...
# Side 2 strength raw: 50,000-100,000...
# Side 1 troops: 11500
# Side 2 troops: 75000
# Side 1 casualties raw: 1,200...
# Side 2 casualties raw: 10,000-21,000...
# Side 1 deaths: 1200
# Side 2 deaths: 15500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Akraba (632)
# Scraping battle page: Battle of Alalia (ID: 29)
# Raw location text: Alalia , Corsica
# Battle location - City: Alalia, Country: Corsica
# Result: Greek victory...
# Side 1 raw content: Phocaeans...
# Side 2 raw content: Carthage
#  Etruscans...
# Side 1 countries: ['Phocaeans']
# Side 2 countries: ['Carthage', 'Etruscans']
# Side 1 strength raw: 60 Pentekonters...
# Side 2 strength raw: Around 120 Ships...
# Side 1 troops: 60
# Side 2 troops: 120
# Side 1 casualties raw: Almost 40 Pentekonters...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Alalia
# Scraping battle page: Battle of Alamance (ID: 30)
# Raw location text: Great Alamance Creek , North Carolina 36°00′30″N 079°31′14″W﻿ / ﻿36.00833°N 79.52056°W﻿ / 36.00833; -79.52056
# Battle location - City: Great Alamance Creek, Country: North Carolina 36°00′30″N 079°31′14″W﻿ / ﻿36.00833°N 79.52056°W﻿ / 36.00833; -79.52056
# Result: Government victory...
# Side 1 raw content: North Carolina...
# Side 2 raw content: Regulators...
# Side 1 countries: ['North Carolina']
# Side 2 countries: ['Regulators']
# Side 1 strength raw: ~1,000...
# Side 2 strength raw: ~2,000...
# Side 1 troops: 1000
# Side 2 troops: 2000
# Side 1 casualties raw: 9-27 killed
#  61 wounded...
# Side 2 casualties raw: 100 killed
#  ~200 wounded...
# Side 1 deaths: 27
# Side 2 deaths: 100
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Alamance
# Progress: 30/962 battles processed (3.1%)
# Scraping battle page: Battle of al-Bab (ID: 31)
# Raw location text: Al-Bab District , Aleppo Governorate , Syria
# Battle location - City: Al-Bab District, Country: Syria
# Result: Turkish and SNA victory
# • Turkish Armed Forces and Syrian National Army /allied Syrian rebels captu...
# Side 1 raw content: Turkey
#   Syrian National Army
#  Support:
#   Russia
#   United States (against ISIL only, since 17 Ja...
# Side 2 raw content: Islamic State...
# Side 1 countries: ['Turkey', 'Syrian National Army', 'Support:', 'Russia', 'United States (against ISIL only', 'since 17 Jan. 2017)']
# Side 2 countries: ['Islamic State']
# Side 1 strength raw: 1,300–4,000 soldiers
#  40 tanks originally, 10 reinforcements
#  15+ APCs
#   2,000–3,000 rebel fighte...
# Side 2 strength raw: 3,000–5,000 militants...
# Side 1 troops: 10
# Side 2 troops: 4000
# Side 1 casualties raw: 59 killed
#  8-10 Leopard 2 tanks destroyed, at least 2 captured
#   500+ killed...
# Side 2 casualties raw: 1,348+ killed...
# Side 1 deaths: 59
# Side 2 deaths: 1348
# Side 1 result: winner
# Side 2 result: loser
# Found 7 participants for Battle of al-Bab
# Scraping battle page: Battle of Alam el Halfa (ID: 32)
# Raw location text: Near El Alamein , Egypt 30°40′N 29°10′E﻿ / ﻿30.667°N 29.167°E﻿ / 30.667; 29.167
# Battle location - City: El Alamein, Country: Egypt 30°40′N 29°10′E﻿ / ﻿30.667°N 29.167°E﻿ / 30.667; 29.167
# Result: British victory...
# Side 1 raw content: United Kingdom
#  New Zealand...
# Side 2 raw content: Germany
#   Italy...
# Side 1 countries: ['United Kingdom', 'New Zealand']
# Side 2 countries: ['Germany', 'Italy']
# Side 1 strength raw: XIII Corps ( Eighth Army ):
#  4 divisions...
# Side 2 strength raw: Panzer Army Africa :
#  6 divisions...
# Side 1 troops: 4
# Side 2 troops: 6
# Side 1 casualties raw: 1,750 killed, wounded or captured
#  68 tanks
#  67 aircraft...
# Side 2 casualties raw: 2,900 killed, wounded or captured
#  49 tanks
#  36 aircraft
#  60 guns
#  400 transport vehicles...
# Side 1 deaths: 1750
# Side 2 deaths: 2900
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of Alam el Halfa
# Scraping battle page: Battle of the Alamo (ID: 33)
# Raw location text: Alamo Mission , San Antonio , Mexican Texas 29°25′32″N 98°29′10″W﻿ / ﻿29.42556°N 98.48611°W﻿ / 29.42556; -98.48611
# Battle location - City: Alamo Mission, Country: Mexican Texas 29°25′32″N 98°29′10″W﻿ / ﻿29.42556°N 98.48611°W﻿ / 29.42556; -98.48611
# Result: Mexican victory...
# Side 1 raw content: Mexico...
# Side 2 raw content: Republic of Texas...
# Side 1 countries: ['Mexico']
# Side 2 countries: ['Republic of Texas']
# Side 1 strength raw: ~2,000–2,100...
# Side 2 strength raw: 185–260...
# Side 1 troops: 2050
# Side 2 troops: 222
# Side 1 casualties raw: Mexican official version
#  60 killed and 250 wounded
#  Texan estimation
#  400–600 killed and wounded...
# Side 2 casualties raw: 182–257 killed...
# Side 1 deaths: 60
# Side 2 deaths: 257
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of the Alamo
# Scraping battle page: Battle of Aldenhoven (1794) (ID: 34)
# Raw location text: Aldenhoven , Germany 50°53′45″N 6°16′59″E﻿ / ﻿50.89583°N 6.28306°E﻿ / 50.89583; 6.28306
# Battle location - City: Aldenhoven, Country: Germany 50°53′45″N 6°16′59″E﻿ / ﻿50.89583°N 6.28306°E﻿ / 50.89583; 6.28306
# Result: French victory...
# Side 1 raw content: French Republic...
# Side 2 raw content: Habsburg monarchy...
# Side 1 countries: ['French Republic']
# Side 2 countries: ['Habsburg monarchy']
# Side 1 strength raw: 88,000...
# Side 2 strength raw: 77,000...
# Side 1 troops: 88000
# Side 2 troops: 77000
# Side 1 casualties raw: 1,500 killed or wounded...
# Side 2 casualties raw: 3,000 killed or wounded
#  800 captured...
# Side 1 deaths: 1500
# Side 2 deaths: 3000
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Aldenhoven (1794)
# Scraping battle page: El Alamein (ID: 35)
# Battle location - City: None, Country: None
# Side 1 countries: []
# Side 2 countries: []
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 0 participants for El Alamein
# Scraping battle page: Battle of Albarracin (ID: 36)
# Raw location text: Albarracín area and Montes Universales , Spain
# Battle location - City: Albarracín area and Montes Universales, Country: Spain
# Result: Nationalist victory...
# Side 1 raw content: Spanish Republic...
# Side 2 raw content: Nationalist Spain...
# Side 1 countries: ['Spanish Republic']
# Side 2 countries: ['Nationalist Spain']
# Side 1 strength raw: 42nd Division
#  8,000–9,500...
# Side 2 strength raw: ?...
# Side 1 troops: 8750
# Side 2 troops: None
# Side 1 casualties raw: High...
# Side 2 casualties raw: Unknown...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Albarracin
# Scraping battle page: Battle of Alesia (ID: 37)
# Raw location text: Alise-Sainte-Reine , France 47°32′13″N 4°30′00″E﻿ / ﻿47.537°N 4.500°E﻿ / 47.537; 4.500
# Battle location - City: Alise-Sainte-Reine, Country: France 47°32′13″N 4°30′00″E﻿ / ﻿47.537°N 4.500°E﻿ / 47.537; 4.500
# Result: • Roman victory
# • Rome completes its conquest of Gaul...
# Side 1 raw content: Roman Republic...
# Side 2 raw content: Gallic confederation...
# Side 1 countries: ['Roman Republic']
# Side 2 countries: ['Gallic confederation']
# Side 1 strength raw: 10–11 legions (30–50,000 legionaries)
#  10,000 auxiliaries 60,000–75,000 approx. total Romans and al...
# Side 2 strength raw: 328,000–470,000 total (ancient sources) • 80,000–170,000 besieged
# • 248,000–300,000 relief forces <...
# Side 1 troops: 10
# Side 2 troops: 399000
# Side 1 casualties raw: 12,800 killed and wounded...
# Side 2 casualties raw: 290,000 (Caesar, exaggerated) • 250,000 killed
# • 40,000 captured...
# Side 1 deaths: 12800
# Side 2 deaths: 250000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Alesia
# Scraping battle page: Battle of Alexandria (ID: 38)
# Raw location text: Alexandria , Egypt , Ottoman Empire 31°13′N 29°57′E﻿ / ﻿31.22°N 29.95°E﻿ / 31.22; 29.95
# Battle location - City: Alexandria, Country: Ottoman Empire 31°13′N 29°57′E﻿ / ﻿31.22°N 29.95°E﻿ / 31.22; 29.95
# Result: British victory...
# Side 1 raw content: United Kingdom...
# Side 2 raw content: France...
# Side 1 countries: ['United Kingdom']
# Side 2 countries: ['France']
# Side 1 strength raw: 12,000 –14,200...
# Side 2 strength raw: 10,000 –16,000...
# Side 1 troops: 13100
# Side 2 troops: 13000
# Side 1 casualties raw: 243 killed
#  1,253 wounded
#  32 missing...
# Side 2 casualties raw: 1,700 –5,000...
# Side 1 deaths: 243
# Side 2 deaths: 3350
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Alexandria
# Scraping battle page: First Battle of El Alamein (ID: 39)
# Raw location text: El Alamein , British-occupied Egypt 30°50′29″N 28°56′34″E﻿ / ﻿30.84139°N 28.94278°E﻿ / 30.84139; 28.94278
# Battle location - City: El Alamein, Country: British-occupied Egypt 30°50′29″N 28°56′34″E﻿ / ﻿30.84139°N 28.94278°E﻿ / 30.84139; 28.94278
# Result: Inconclusive...
# Side 1 raw content: Italy
#   Germany...
# Side 2 raw content: United Kingdom
#   India
#  New Zealand
#   Australia
#   South Africa...
# Side 1 countries: ['Italy', 'Germany']
# Side 2 countries: ['United Kingdom', 'India', 'New Zealand', 'Australia', 'South Africa']
# Side 1 strength raw: 96,000 troops (56,000 Italian, 40,000 German)
#  70 tanks initially (585 tanks later)
#  ~500 planes...
# Side 2 strength raw: 150,000 troops
#  179 tanks initially (1,114 tanks later)
#  1,000+ artillery pieces
#  1,500+ planes...
# Side 1 troops: 96000
# Side 2 troops: 150000
# Side 1 casualties raw: 10,000 killed or wounded
#  7,000 prisoners...
# Side 2 casualties raw: 13,250 killed or wounded...
# Side 1 deaths: 10000
# Side 2 deaths: 13250
# Side 1 result: tied
# Side 2 result: tied
# Found 7 participants for First Battle of El Alamein
# Scraping battle page: Second Battle of El Alamein (ID: 40)
# Raw location text: El Alamein , Egypt 30°50′30″N 28°56′33″E﻿ / ﻿30.84167°N 28.94250°E﻿ / 30.84167; 28.94250
# Battle location - City: El Alamein, Country: Egypt 30°50′30″N 28°56′33″E﻿ / ﻿30.84167°N 28.94250°E﻿ / 30.84167; 28.94250
# Result: Allied victory...
# Side 1 raw content: British Empire
# • United Kingdom
# • India
# • Australia
# • New Zealand
# • South Africa
# • Libyan Arab...
# Side 2 raw content: Italy
#  Germany...
# Side 1 countries: ['British Empire', 'United Kingdom', 'India', 'Australia', 'New Zealand', 'South Africa', 'Libyan Arab Force Free France Greece Air support: United States']
# Side 2 countries: ['Italy', 'Germany']
# Side 1 strength raw: 195,000
#  1,029 tanks
#  435 armoured cars
#  730 – 750 aircraft
#  892 – 908 artillery guns
#  1,451 an...
# Side 2 strength raw: 116,000
#  547 tanks
#  192 armoured cars
#  770 – 900 aircraft
#  552 artillery pieces
#  496 – 1,063 an...
# Side 1 troops: 740
# Side 2 troops: 835
# Side 1 casualties raw: 13,560 killed, wounded, captured, and missing
#  332–500 tanks destroyed
#  111 guns destroyed
#  97 ai...
# Side 2 casualties raw: 2,000–9,000 dead or missing, 4,800–15,000 wounded, 35,000–49,000 captured
#  500 tanks destroyed
#  25...
# Side 1 deaths: 13560
# Side 2 deaths: 9000
# Side 1 result: winner
# Side 2 result: loser
# Found 9 participants for Second Battle of El Alamein
# Progress: 40/962 battles processed (4.2%)
# Scraping battle page: Battle of Alessandria (ID: 41)
# Raw location text: Alessandria, Piedmont, Italy 44°55′N 08°37′E﻿ / ﻿44.917°N 8.617°E﻿ / 44.917; 8.617
# Battle location - City: Alessandria, Country: Italy 44°55′N 08°37′E﻿ / ﻿44.917°N 8.617°E﻿ / 44.917; 8.617
# Result: Milanese victory...
# Side 1 raw content: Lordship of Milan...
# Side 2 raw content: Republic of Florence...
# Side 1 countries: ['Lordship of Milan']
# Side 2 countries: ['Republic of Florence']
# Side 1 strength raw: 10,000 (incl. 6,000 knights)...
# Side 2 strength raw: 10,500 (incl. 7,500 knights)...
# Side 1 troops: 10000
# Side 2 troops: 10500
# Side 1 casualties raw: Unknown...
# Side 2 casualties raw: Thousands killed 6,000 captured...
# Side 1 deaths: None
# Side 2 deaths: 6000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Alessandria
# Scraping battle page: Battle of Alfambra (ID: 42)
# Raw location text: Teruel , Aragon , Spain
# Battle location - City: Teruel, Country: Spain
# Result: Nationalist victory...
# Side 1 raw content: Spanish Republic...
# Side 2 raw content: Nationalist Spain
#  Italy
#   Germany...
# Side 1 countries: ['Spanish Republic']
# Side 2 countries: ['Nationalist Spain', 'Italy', 'Germany']
# Side 1 strength raw: Fewer than 50,000
#  120 fighters
#  80 bombers...
# Side 2 strength raw: 100,000
#  500 guns
#  150 fighters
#  100 bombers...
# Side 1 troops: 50000
# Side 2 troops: 100000
# Side 1 casualties raw: 20,000 –22,000...
# Side 2 casualties raw: ?...
# Side 1 deaths: 21000
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Alfambra
# Scraping battle page: Battle of Alfarrobeira (ID: 43)
# Raw location text: Vialonga , near Lisbon, Portugal
# Battle location - City: Vialonga, Country: Portugal
# Result: Rebellion suppressed;
#  Supremacy of the main line of the House of Aviz preserved...
# Side 1 raw content: Kingdom of Portugal House of Braganza...
# Side 2 raw content: Coimbra Rebels...
# Side 1 countries: ['Kingdom of Portugal House of Braganza']
# Side 2 countries: ['Coimbra Rebels']
# Side 1 strength raw: 30,000 men...
# Side 2 strength raw: 6,000 men:
#  • 5,000 infantry
#  • 1,000 cavalry...
# Side 1 troops: 30000
# Side 2 troops: 6000
# Side 1 casualties raw: 500 dead or wounded...
# Side 2 casualties raw: 4,000 dead, wounded, or captured...
# Side 1 deaths: 500
# Side 2 deaths: 4000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Alfarrobeira
# Scraping battle page: Battle of Algeciras (ID: 44)
# Raw location text: Algeciras 36°07′39″N 05°27′14″W﻿ / ﻿36.12750°N 5.45389°W﻿ / 36.12750; -5.45389
# Battle location - City: Algeciras 36°07′39″N 05°27′14″W﻿ / ﻿36.12750°N 5.45389°W﻿ / 36.12750; -5.45389, Country: None
# Result: Castillian victory...
# Side 1 raw content: Marinid Dynasty
#   Emirate of Granada...
# Side 2 raw content: Crown of Castile
#   Republic of Genoa
#   Kingdom of Aragon
#   Kingdom of Portugal
#   Kingdom of Nava...
# Side 1 countries: ['Marinid Dynasty', 'Emirate of Granada']
# Side 2 countries: ['Crown of Castile', 'Republic of Genoa', 'Kingdom of Aragon', 'Kingdom of Portugal', 'Kingdom of Navarre', 'European crusaders']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: unknown
# Side 2 result: unknown
# Found 8 participants for Battle of Algeciras
# Scraping battle page: Battle of Aljubarrota (ID: 45)
# Raw location text: Near Aljubarrota , central Portugal
# Battle location - City: Aljubarrota, Country: central Portugal
# Result: Portuguese victory...
# Side 1 raw content: Kingdom of Portugal
#  Supported by:
#  Kingdom of England...
# Side 2 raw content: Crown of Castile
#  Supported by:
#  Kingdom of France
#  Crown of Aragon
#  Genoese mercenaries...
# Side 1 countries: ['Kingdom of Portugal', 'Supported by:', 'Kingdom of England']
# Side 2 countries: ['Crown of Castile', 'Supported by:', 'Kingdom of France', 'Crown of Aragon', 'Genoese mercenaries']
# Side 1 strength raw: About 6,600 men:
# • 4,000 foot soldiers
# • 1,700 lances
# • 800 crossbowmen
# • 200 English longbowmen...
# Side 2 strength raw: About 31,000 men:
# • 15,000 foot soldiers
# • 6,000 lances
# • 8,000 crossbowmen
# • More than 2,000 Fr...
# Side 1 troops: 6600
# Side 2 troops: 31000
# Side 1 casualties raw: Fewer than 1,000...
# Side 2 casualties raw: 4,000–5,000
#  5,000 in the aftermath...
# Side 1 deaths: 1000
# Side 2 deaths: 4500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 8 participants for Battle of Aljubarrota
# Scraping battle page: Battle of Alma (ID: 46)
# Raw location text: Alma River , Russian Empire 44°49′52″N 33°40′08″E﻿ / ﻿44.831036°N 33.668879°E﻿ / 44.831036; 33.668879
# Battle location - City: Alma River, Country: Russian Empire 44°49′52″N 33°40′08″E﻿ / ﻿44.831036°N 33.668879°E﻿ / 44.831036; 33.668879
# Result: Allied victory...
# Side 1 raw content: Britain
#   France
#   Ottoman Empire...
# Side 2 raw content: Russia...
# Side 1 countries: ['Britain', 'France', 'Ottoman Empire']
# Side 2 countries: ['Russia']
# Side 1 strength raw: 56,500 –58,000...
# Side 2 strength raw: 37,500...
# Side 1 troops: 57250
# Side 2 troops: 37500
# Side 1 casualties raw: 4,103 killed and wounded...
# Side 2 casualties raw: ~5,000 killed and wounded...
# Side 1 deaths: 4103
# Side 2 deaths: 5000
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of Alma
# Scraping battle page: Battle of Almansa (ID: 47)
# Raw location text: Almansa , Albacete , Spain
# Battle location - City: Almansa, Country: Spain
# Result: Franco-Spanish victory...
# Side 1 raw content: Spain
#   France...
# Side 2 raw content: England
#  Portugal
#  Dutch Republic...
# Side 1 countries: ['Spain', 'France']
# Side 2 countries: ['England', 'Portugal', 'Dutch Republic']
# Side 1 strength raw: 21,000 to 25,000...
# Side 2 strength raw: 16,000 to 16,500...
# Side 1 troops: 21000
# Side 2 troops: 16000
# Side 1 casualties raw: 1,500 to 2,000 killed or wounded...
# Side 2 casualties raw: 7,000 killed, wounded or captured...
# Side 1 deaths: 2000
# Side 2 deaths: 7000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 5 participants for Battle of Almansa
# Scraping battle page: Battle of Almendralejo (ID: 48)
# No infobox found for Battle of Almendralejo at https://en.wikipedia.org/wiki/Battle_of_Almendralejo
# Scraping battle page: Battle of Almonacid (ID: 49)
# Raw location text: Almonacid , near Toledo , Spain 39°44′N 3°52′W﻿ / ﻿39.733°N 3.867°W﻿ / 39.733; -3.867
# Battle location - City: Almonacid, Country: Spain 39°44′N 3°52′W﻿ / ﻿39.733°N 3.867°W﻿ / 39.733; -3.867
# Result: French victory...
# Side 1 raw content: France
#   Duchy of Warsaw...
# Side 2 raw content: Spain...
# Side 1 countries: ['France', 'Duchy of Warsaw']
# Side 2 countries: ['Spain']
# Side 1 strength raw: 28,797...
# Side 2 strength raw: 28,107...
# Side 1 troops: 28797
# Side 2 troops: 28107
# Side 1 casualties raw: 2,400...
# Side 2 casualties raw: 3,300–3,500 killed & wounded
#  2,000 captured
#  20–21 guns lost
#  Total :
#  5,500...
# Side 1 deaths: 2400
# Side 2 deaths: 3500
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Battle of Almonacid
# Scraping battle page: Battle of Al-Safra (ID: 50)
# Raw location text: Wadi Al-Safra , near Medina
# Battle location - City: Wadi Al-Safra, Country: Medina
# Result: Saudi victory...
# Side 1 raw content: Ottoman Empire...
# Side 2 raw content: Emirate of Diriyah...
# Side 1 countries: ['Ottoman Empire']
# Side 2 countries: ['Emirate of Diriyah']
# Side 1 strength raw: 8,000–14,000 men...
# Side 2 strength raw: 18,000 men
#  800 Cavalry...
# Side 1 troops: 14000
# Side 2 troops: 18000
# Side 1 casualties raw: 4,000–5,000 killed
#  7 Cannons captured...
# Side 2 casualties raw: 600 killed...
# Side 1 deaths: 5000
# Side 2 deaths: 600
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Al-Safra
# Progress: 50/962 battles processed (5.2%)
# Scraping battle page: Battle of Ambarawa (ID: 51)
# Raw location text: Semarang and Magelang , Indonesia
# Battle location - City: Semarang and Magelang, Country: Indonesia
# Result: • Indonesian victory
# • Withdrawal of all British troops from Magelang , and Ambarawa ....
# Side 1 raw content: Indonesia...
# Side 2 raw content: • United Kingdom
# • British Raj Supported by:
#   Netherlands...
# Side 1 countries: ['Indonesia']
# Side 2 countries: ['United Kingdom', 'British Raj Supported by: Netherlands']
# Side 1 strength raw: 10,000+ (Ambarawa)...
# Side 2 strength raw: Unknown...
# Side 1 troops: 10000
# Side 2 troops: None
# Side 1 casualties raw: 2,000 killed...
# Side 2 casualties raw: 100 killed (Ambarawa)...
# Side 1 deaths: 2000
# Side 2 deaths: 100
# Side 1 result: tied
# Side 2 result: tied
# Found 3 participants for Battle of Ambarawa
# Scraping battle page: Battle of Amberg (ID: 52)
# Raw location text: Amberg 49°28′16″N 11°49′45″E﻿ / ﻿49.4712°N 11.8291°E﻿ / 49.4712; 11.8291
# Battle location - City: Amberg 49°28′16″N 11°49′45″E﻿ / ﻿49.4712°N 11.8291°E﻿ / 49.4712; 11.8291, Country: None
# Result: Austrian victory, turning point in the campaign...
# Side 1 raw content: Republican France...
# Side 2 raw content: Habsburg monarchy...
# Side 1 countries: ['Republican France']
# Side 2 countries: ['Habsburg monarchy']
# Side 1 strength raw: 34,000...
# Side 2 strength raw: 40,000...
# Side 1 troops: 34000
# Side 2 troops: 40000
# Side 1 casualties raw: 2,000...
# Side 2 casualties raw: 400...
# Side 1 deaths: 2000
# Side 2 deaths: 400
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Amberg
# Scraping battle page: Battle of Amiens (ID: 53)
# Raw location text: Amiens , France
# Battle location - City: Amiens, Country: France
# Result: German victory...
# Side 1 raw content: North German Confederation
# • Prussia...
# Side 2 raw content: French Republic...
# Side 1 countries: ['North German Confederation', 'Prussia']
# Side 2 countries: ['French Republic']
# Side 1 strength raw: 43,000...
# Side 2 strength raw: 25,000...
# Side 1 troops: 43000
# Side 2 troops: 25000
# Side 1 casualties raw: 1,292 killed or wounded
#  300 missing...
# Side 2 casualties raw: 1,383 killed or wounded
#  1,000 soldiers missing...
# Side 1 deaths: 1292
# Side 2 deaths: 1383
# Side 1 result: loser
# Side 2 result: winner
# Found 3 participants for Battle of Amiens
# Scraping battle page: Battle of Amiens (ID: 54)
# Raw location text: East of Amiens , Picardy , France 49°53′38″N 2°17′39″E﻿ / ﻿49.89389°N 2.29417°E﻿ / 49.89389; 2.29417
# Battle location - City: East of Amiens, Country: France 49°53′38″N 2°17′39″E﻿ / ﻿49.89389°N 2.29417°E﻿ / 49.89389; 2.29417
# Result: Allied victory
# • Start of Hundred Days Offensive...
# Side 1 raw content: British Empire
# • United Kingdom
# • Australia
# • Canada France
#  United States...
# Side 2 raw content: German Empire...
# Side 1 countries: ['British Empire', 'United Kingdom', 'Australia', 'Canada France United States']
# Side 2 countries: ['German Empire']
# Side 1 strength raw: ...
# Side 2 strength raw: ...
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: ...
# Side 2 casualties raw: 45,000 killed or wounded
#  29,873 captured...
# Side 1 deaths: None
# Side 2 deaths: 45000
# Side 1 result: winner
# Side 2 result: loser
# Found 5 participants for Battle of Amiens
# Scraping battle page: Battle of Amphipolis (ID: 55)
# Raw location text: Amphipolis 40°49′25″N 23°50′49″E﻿ / ﻿40.823681°N 23.84705°E﻿ / 40.823681; 23.84705
# Battle location - City: Amphipolis 40°49′25″N 23°50′49″E﻿ / ﻿40.823681°N 23.84705°E﻿ / 40.823681; 23.84705, Country: None
# Result: Spartan victory...
# Side 1 raw content: Athens...
# Side 2 raw content: Sparta...
# Side 1 countries: ['Athens']
# Side 2 countries: ['Sparta']
# Side 1 strength raw: About 2,000...
# Side 2 strength raw: About 2,500...
# Side 1 troops: 2000
# Side 2 troops: 2500
# Side 1 casualties raw: About 600...
# Side 2 casualties raw: 7...
# Side 1 deaths: 600
# Side 2 deaths: None
# Side 1 result: loser
# Side 2 result: winner
# Found 2 participants for Battle of Amphipolis
# Scraping battle page: Battle of Amstetten (ID: 56)
# Raw location text: Amstetten , Lower Austria 48°07′00″N 14°52′00″E﻿ / ﻿48.1167°N 14.8667°E﻿ / 48.1167; 14.8667
# Battle location - City: Amstetten, Country: Lower Austria 48°07′00″N 14°52′00″E﻿ / ﻿48.1167°N 14.8667°E﻿ / 48.1167; 14.8667
# Result: Inconclusive...
# Side 1 raw content: France...
# Side 2 raw content: Habsburg Empire
#   Russia...
# Side 1 countries: ['France']
# Side 2 countries: ['Habsburg Empire', 'Russia']
# Side 1 strength raw: Around 10,000 soldiers...
# Side 2 strength raw: 6,700–7,900 soldiers...
# Side 1 troops: 10000
# Side 2 troops: 7900
# Side 1 casualties raw: 1,000...
# Side 2 casualties raw: Russian Empire:
#  300 killed or wounded
#  <700 prisoners
#  Austrian Empire:
#  1,000 killed, wounded,...
# Side 1 deaths: 1000
# Side 2 deaths: 300
# Side 1 result: tied
# Side 2 result: tied
# Found 3 participants for Battle of Amstetten
# Scraping battle page: Battle of Angaur (ID: 57)
# Raw location text: Angaur , Palau Islands
# Battle location - City: Angaur, Country: Palau Islands
# Result: American victory...
# Side 1 raw content: United States...
# Side 2 raw content: Japan...
# Side 1 countries: ['United States']
# Side 2 countries: ['Japan']
# Side 1 strength raw: 10,000...
# Side 2 strength raw: 1,400...
# Side 1 troops: 10000
# Side 2 troops: 1400
# Side 1 casualties raw: 264 killed
#  1,354 wounded...
# Side 2 casualties raw: 1,350 killed
#  50 captured...
# Side 1 deaths: 264
# Side 2 deaths: 1350
# Side 1 result: winner
# Side 2 result: loser
# Found 2 participants for Battle of Angaur
# Scraping battle page: Battle of Ankara (ID: 58)
# Raw location text: Çubuk plain near Ankara 40°09′N 32°57′E﻿ / ﻿40.150°N 32.950°E﻿ / 40.150; 32.950
# ...
#  1 ironclad damaged...
# Side 2 casualties raw: 1,350 killed and wounded
#  1 protected cruiser sunk
#  1 armoured cruiser sunk
#  2 light cruisers sun...
# Side 1 deaths: 380
# Side 2 deaths: 1350
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Yalu River (1894)
# Scraping battle page: Battle of Yalu River (1904) (ID: 948)
# Raw location text: Near Wiju , border of Korea and China 40°11′29.400″N 124°31′32.988″E﻿ / ﻿40.19150000°N 124.52583000°E﻿ / 40.19150000; 124.52583000
# Battle location - City: Wiju, Country: border of Korea and China 40°11′29.400″N 124°31′32.988″E﻿ / ﻿40.19150000°N 124.52583000°E﻿ / 40.19150000; 124.52583000
# Result: Japanese victory...
# Side 1 raw content: Empire of Japan...
# Side 2 raw content: Russian Empire...
# Side 1 countries: ['Empire of Japan']
# Side 2 countries: ['Russian Empire']
# Side 1 strength raw: 42,000...
# Side 2 strength raw: About 25,000...
# Side 1 troops: 42000
# Side 2 troops: 25000
# Side 1 casualties raw: 1,036 killed, wounded or missing...
# Side 2 casualties raw: 2,172 casualties
# • 593 killed
# • 1,101 wounded
# • 478 missing...
# Side 1 deaths: 1036
# Side 2 deaths: 593
# Side 1 result: loser
# Side 2 result: winner
# Found 2 participants for Battle of Yalu River (1904)
# Scraping battle page: Battle of Yarmuk (ID: 949)
# Raw location text: Near the Yarmuk River , along the tripoint border of Syria, Jordan, and the Israeli-occupied Golan Heights 32°48′51″N 35°57′17″E﻿ / ﻿32.8141°N 35.9548°E﻿ / 32.8141; 35.9548
# Battle location - City: the Yarmuk River, Country: and the Israeli-occupied Golan Heights 32°48′51″N 35°57′17″E﻿ / ﻿32.8141°N 35.9548°E﻿ / 32.8141; 35.9548
# Result: Rashidun victory...
# Side 1 raw content: Rashidun Caliphate...
# Side 2 raw content: Byzantine Empire
#  Ghassanid Kingdom
#  Tanukhids...
# Side 1 countries: ['Rashidun Caliphate']
# Side 2 countries: ['Byzantine Empire', 'Ghassanid Kingdom', 'Tanukhids']
# Side 1 strength raw: 15,000–40,000
#  (modern estimates)
#  24,000–40,000
#  (primary Arab sources)...
# Side 2 strength raw: 20,000–40,000
#  (modern estimates)
#  100,000–200,000
#  (primary Arab sources)
#  140,000
#  (primary R...
# Side 1 troops: 27500
# Side 2 troops: 30000
# Side 1 casualties raw: 4,000 killed...
# Side 2 casualties raw: 70,000–120,000 killed
#  (primary Arab sources)...
# Side 1 deaths: 4000
# Side 2 deaths: 120000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Yarmuk
# Scraping battle page: Battle of Yarmouk Camp (ID: 950)
# Raw location text: Yarmouk Camp , Southern Damascus , Syria
# Battle location - City: Yarmouk Camp, Country: Syria
# Result: Partial ISIL victory
# • 2,000 people were evacuated from the district
# • Rebels repel ISIL attack on...
# Side 1 raw content: Islamic State of Iraq and the Levant  al-Nusra Front...
# Side 2 raw content: Jaysh al-Islam
#   Free Syrian Army
#   Aknaf Bait al-Maqdis...
# Side 1 countries: ['Islamic State of Iraq and the Levant al-Nusra Front']
# Side 2 countries: ['Jaysh al-Islam', 'Free Syrian Army', 'Aknaf Bait al-Maqdis']
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: 80 killed
#
#  36 killed...
# Side 2 casualties raw: 9–15 killed, 10 captured...
# Side 1 deaths: 80
# Side 2 deaths: 15
# Side 1 result: loser
# Side 2 result: winner
# Found 4 participants for Battle of Yarmouk Camp
# Progress: 950/962 battles processed (98.8%)
# Scraping battle page: Battle of York (ID: 951)
# Raw location text: York, Upper Canada
#  (present day Toronto , Ontario)
# Battle location - City: York, Country: Upper Canada
# Result: • United States victory
# • Public buildings, including the parliament building were razed....
# Side 1 raw content: United Kingdom
#   Upper Canada
#  Ojibwe...
# Side 2 raw content: United States...
# Side 1 countries: ['United Kingdom', 'Upper Canada', 'Ojibwe']
# Side 2 countries: ['United States']
# Side 1 strength raw: 300 regulars
#  300 militia
#  40–50 Natives...
# Side 2 strength raw: 1,700 regulars
#  14 armed vessels...
# Side 1 troops: 45
# Side 2 troops: 1700
# Side 1 casualties raw: 82 killed
#  112 wounded (including 69 wounded prisoners)
#  274 captured
#  7 missing...
# Side 2 casualties raw: 55 killed
#  265 wounded...
# Side 1 deaths: 82
# Side 2 deaths: 55
# Side 1 result: loser
# Side 2 result: winner
# Found 4 participants for Battle of York
# Scraping battle page: Battle of Yorktown (1781) (ID: 952)
# Raw location text: Gloucester and Yorktown, Virginia 37°13′51″N 76°30′09″W﻿ / ﻿37.23083°N 76.50250°W﻿ / 37.23083; -76.50250
# Battle location - City: Gloucester and Yorktown, Country: Virginia 37°13′51″N 76°30′09″W﻿ / ﻿37.23083°N 76.50250°W﻿ / 37.23083; -76.50250
# Result: Franco-American victory...
# Side 1 raw content: United States
#  France...
# Side 2 raw content: Great Britain
# • Loyalists  Hesse-Kassel
#  Ansbach - Bayreuth...
# Side 1 countries: ['United States', 'France']
# Side 2 countries: ['Great Britain', 'Loyalists Hesse-Kassel Ansbach - Bayreuth']
# Side 1 strength raw: Americans : 8,000–9,000 men
# • 5,900 regular troops
# • 3,100 militia (not engaged) French : 10,800 m...
# Side 2 strength raw: British : 5,000 German : Fewer than 3,000
#
#  Total : 8-9,000...
# Side 1 troops: 9000
# Side 2 troops: 4504
# Side 1 casualties raw: 88 killed
#  301 wounded...
# Side 2 casualties raw: 142–309 killed
#  326–595 wounded prisoners
#  7,416–7,685 captured...
# Side 1 deaths: 88
# Side 2 deaths: 309
# Side 1 result: winner
# Side 2 result: loser
# Found 4 participants for Battle of Yorktown (1781)
# Scraping battle page: First Battle of Ypres (ID: 953)
# Raw location text: Ypres , Belgium 50°51′7″N 2°53′28″E﻿ / ﻿50.85194°N 2.89111°E﻿ / 50.85194; 2.89111
# Battle location - City: Ypres, Country: Belgium 50°51′7″N 2°53′28″E﻿ / ﻿50.85194°N 2.89111°E﻿ / 50.85194; 2.89111
# Result: Indecisive...
# Side 1 raw content: • France
# • Belgium
# • United Kingdom...
# Side 2 raw content: Germany...
# Side 1 countries: ['France', 'Belgium', 'United Kingdom']
# Side 2 countries: ['Germany']
# Side 1 strength raw: ...
# Side 2 strength raw: 5,400,000...
# Side 1 troops: None
# Side 2 troops: 5400
# Side 1 casualties raw: ...
# Side 2 casualties raw: ...
# Side 1 deaths: None
# Side 2 deaths: None
# Side 1 result: tied
# Side 2 result: tied
# Found 4 participants for First Battle of Ypres
# Scraping battle page: Second Battle of Ypres (ID: 954)
# Raw location text: Ypres , Belgium 50°53′58″N 02°56′26″E﻿ / ﻿50.89944°N 2.94056°E﻿ / 50.89944; 2.94056
# Battle location - City: Ypres, Country: Belgium 50°53′58″N 02°56′26″E﻿ / ﻿50.89944°N 2.94056°E﻿ / 50.89944; 2.94056
# Result: See Analysis section...
# Side 1 raw content: British Empire
# • Canada
# • India
# • United Kingdom France
# • Algeria
# • Morocco  Belgium...
# Side 2 raw content: German Empire...
# Side 1 countries: ['British Empire', 'Canada', 'India', 'United Kingdom France', 'Algeria', 'Morocco Belgium']
# Side 2 countries: ['German Empire']
# Side 1 strength raw: ...
# Side 2 strength raw: 7 divisions...
# Side 1 troops: None
# Side 2 troops: None
# Side 1 casualties raw: ...
# Side 2 casualties raw: 35,000+...
# Side 1 deaths: None
# Side 2 deaths: 35000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 7 participants for Second Battle of Ypres
# Scraping battle page: Third Battle of Ypres (ID: 955)
# Raw location text: Passchendaele , Ypres Salient , Belgium 50°54′1″N 3°1′16″E﻿ / ﻿50.90028°N 3.02111°E﻿ / 50.90028; 3.02111﻿ (Passendale)
# Battle location - City: Passchendaele, Country: Belgium 50°54′1″N 3°1′16″E﻿ / ﻿50.90028°N 3.02111°E﻿ / 50.90028; 3.02111﻿
# Result: See Analysis section...
# Side 1 raw content: British Empire
# • United Kingdom
# • Canada
# • Australia
# • New Zealand
# • South Africa
# • India
# • N...
# Side 2 raw content: Germany...
# Side 1 countries: ['British Empire', 'United Kingdom', 'Canada', 'Australia', 'New Zealand', 'South Africa', 'India', 'Newfoundland', 'Rhodesia France Belgium']
# Side 2 countries: ['Germany']
# Side 1 strength raw: 50 divisions
#   6 divisions...
# Side 2 strength raw: 77–83 divisions...
# Side 1 troops: None
# Side 2 troops: 80
# Side 1 casualties raw: 240,000–448,614
#  (disputed, see Casualties section)...
# Side 2 casualties raw: 217,000–400,000
#  including 24,065 prisoners (disputed, see Casualties section)...
# Side 1 deaths: 344307
# Side 2 deaths: 308500
# Side 1 result: unknown
# Side 2 result: unknown
# Found 10 participants for Third Battle of Ypres
# Scraping battle page: Battle of Zama (ID: 956)
# Raw location text: Zama , North Africa (near modern Siliana, Tunisia ) 36°17′56″N 9°26′57″E﻿ / ﻿36.29889°N 9.44917°E﻿ / 36.29889; 9.44917
# Battle location - City: Zama, Country: North Africa 36°17′56″N 9°26′57″E﻿ / ﻿36.29889°N 9.44917°E﻿ / 36.29889; 9.44917
# Result: Roman victory...
# Side 1 raw content: Rome...
# Side 2 raw content: Carthage...
# Side 1 countries: ['Rome']
# Side 2 countries: ['Carthage']
# Side 1 strength raw: 30,000
# • 24,000 infantry
# • 6,000 cavalry...
# Side 2 strength raw: 40,000 or 50,000
# • 36,000 or 46,000 infantry
# • 4,000 cavalry
# • 80 war elephants...
# Side 1 troops: 24000
# Side 2 troops: 46000
# Side 1 casualties raw: At least 1,500 killed...
# Side 2 casualties raw: • •  20,000 killed
# • •  20,000 captured...
# Side 1 deaths: 1500
# Side 2 deaths: 20000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 2 participants for Battle of Zama
# Scraping battle page: Battle of Zapote Bridge (1897) (ID: 957)
# Raw location text: Zapote Bridge , Bacoor and Las Piñas ( Manila – Cavite provincial boundary), Captaincy General of the Philippines
# Battle location - City: Zapote Bridge, Country: Captaincy General of the Philippines
# Result: Filipino victory...
# Side 1 raw content: Katipunan
# • Magdalo...
# Side 2 raw content: Spanish Empire
# • Guardia Civil...
# Side 1 countries: ['Katipunan', 'Magdalo']
# Side 2 countries: ['Spanish Empire', 'Guardia Civil']
# Side 1 strength raw: ~10,000 men...
# Side 2 strength raw: 16,000 men...
# Side 1 troops: 10000
# Side 2 troops: 16000
# Side 1 casualties raw: 450 killed,
#  900+ wounded...
# Side 2 casualties raw: 441 killed,
#  870+ wounded, 313 captured...
# Side 1 deaths: 450
# Side 2 deaths: 441
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Zapote Bridge (1897)
# Scraping battle page: Battle of Zenta (ID: 958)
# Raw location text: Near Zenta , Kingdom of Hungary , occupied by the Ottoman Empire
#  Present-day Senta , Vojvodina , Serbia
#  45°55′34″N 20°05′53″E﻿ / ﻿45.92611°N 20.09806°E﻿ / 45.92611; 20.09806
# Battle location - City: Zenta, Country: Serbia 45°55′34″N 20°05′53″E﻿ / ﻿45.92611°N 20.09806°E﻿ / 45.92611; 20.09806
# Result: • Holy League victory
# • Treaty of Karlowitz
# • End of the Great Turkish War...
# Side 1 raw content: Habsburg Monarchy
# • Kingdom of Hungary
# • Serbian Militia...
# Side 2 raw content: Ottoman Empire
# • Crimean Tatars
# • Kuruc rebels...
# Side 1 countries: ['Habsburg Monarchy', 'Kingdom of Hungary', 'Serbian Militia']
# Side 2 countries: ['Ottoman Empire', 'Crimean Tatars', 'Kuruc rebels']
# Side 1 strength raw: 50,000 men
# • 34,000 infantry
# • 16,000 cavalry
# • 60 guns...
# Side 2 strength raw: 75,000–100,000 men
#  200 guns...
# Side 1 troops: 50000
# Side 2 troops: 100000
# Side 1 casualties raw: 429 killed
#  1,598 wounded...
# Side 2 casualties raw: 30,000 killed, wounded, or drowned...
# Side 1 deaths: 429
# Side 2 deaths: 30000
# Side 1 result: unknown
# Side 2 result: unknown
# Found 6 participants for Battle of Zenta
# Scraping battle page: Battle of Zborov (ID: 959)
# Raw location text: Zborov , Galicia , Austria-Hungary (now Ukraine )
# Battle location - City: Zborov, Country: Austria-Hungary
# Result: Czechoslovak and Russian victory...
# Side 1 raw content: Czechoslovak Legion
#   Russian Provisional Government...
# Side 2 raw content: Austria-Hungary  German Empire...
# Side 1 countries: ['Czechoslovak Legion', 'Russian Provisional Government']
# Side 2 countries: ['Austria-Hungary German Empire']
# Side 1 strength raw: 3,530...
# Side 2 strength raw: 5,500...
# Side 1 troops: 3530
# Side 2 troops: 5500
# Side 1 casualties raw: 167 killed
#  700 wounded
#
#  11 missing...
# Side 2 casualties raw: 3,300 captured
#
#  20 guns captured...
# Side 1 deaths: 167
# Side 2 deaths: 3300
# Side 1 result: unknown
# Side 2 result: unknown
# Found 3 participants for Battle of Zborov
# Scraping battle page: First Battle of Zurich (ID: 960)
# Raw location text: Zürich , Switzerland 47°22′0″N 8°33′0″E﻿ / ﻿47.36667°N 8.55000°E﻿ / 47.36667; 8.55000
# Battle location - City: Zürich, Country: Switzerland 47°22′0″N 8°33′0″E﻿ / ﻿47.36667°N 8.55000°E﻿ / 47.36667; 8.55000
# Result: Austrian victory...
# Side 1 raw content: France...
# Side 2 raw content: Austria...
# Side 1 countries: ['France']
# Side 2 countries: ['Austria']
# Side 1 strength raw: 59,000...
# Side 2 strength raw: 72,000...
# Side 1 troops: 59000
# Side 2 troops: 72000
# Side 1 casualties raw: 500 killed
#  800 wounded...
# Side 2 casualties raw: 730 killed
#  1,470 wounded
#  2,200 captured...
# Side 1 deaths: 500
# Side 2 deaths: 730
# Side 1 result: loser
# Side 2 result: winner
# Found 2 participants for First Battle of Zurich
# Progress: 960/962 battles processed (99.8%)
# Scraping battle page: Second Battle of Zurich (ID: 961)
# Raw location text: Zürich , Helvetic Republic 47°22′N 8°33′E﻿ / ﻿47.367°N 8.550°E﻿ / 47.367; 8.550
# Battle location - City: Zürich, Country: Helvetic Republic 47°22′N 8°33′E﻿ / ﻿47.367°N 8.550°E﻿ / 47.367; 8.550
# Result: French victory...
# Side 1 raw content: French Republic...
# Side 2 raw content: Russian Empire
#   Habsburg monarchy...
# Side 1 countries: ['French Republic']
# Side 2 countries: ['Russian Empire', 'Habsburg monarchy']
# Side 1 strength raw: 35,448...
# Side 2 strength raw: 27,116...
# Side 1 troops: 35448
# Side 2 troops: 27116
# Side 1 casualties raw: 4,000 killed or wounded...
# Side 2 casualties raw: at least 8,000 casualties during the battle
#  100 guns 4,000 more during the retreat...
# Side 1 deaths: 4000
# Side 2 deaths: 8000
# Side 1 result: winner
# Side 2 result: loser
# Found 3 participants for Second Battle of Zurich
# Scraping battle page: Battle of Zusmarshausen (ID: 962)
# Raw location text: Zusmarshausen , near Augsburg (present-day Germany )
# Battle location - City: Zusmarshausen, Country: Augsburg
# Result: Franco-Swedish victory...
# Side 1 raw content: Swedish Empire
#  France...
# Side 2 raw content: Bavaria
#   Holy Roman Empire...
# Side 1 countries: ['Swedish Empire', 'France']
# Side 2 countries: ['Bavaria', 'Holy Roman Empire']
# Side 1 strength raw: 22,000
# • 7,500 infantry
# • 14,500 cavalry...
# Side 2 strength raw: 15,370–18,000
# • 8,150 infantry
# • 7,220 cavalry...
# Side 1 troops: 7500
# Side 2 troops: 8150
# Side 1 casualties raw: 500 –2,000...
# Side 2 casualties raw: 1,897 –2,200
#  6 Guns...
# Side 1 deaths: 1250
# Side 2 deaths: 2048
# Side 1 result: unknown
# Side 2 result: unknown
# Found 4 participants for Battle of Zusmarshausen
# Progress: 962/962 battles processed (100.0%)
#
# ✅ Scraped 3184 participant entries for 962 battles.
# Saved to 'battle_info.csv'
#
# Extraction statistics:
# - Participants with troop numbers: 2438 (76.6%)
# - Participants with death counts: 2287 (71.8%)
# - Participants with known results: 1384 (43.5%)
# - Battles with city location: 3184 (100.0%)
# - Battles with country location: 2801 (88.0%)
#
# Sample of participant data:
# 1. Participant ID: 1, Battle ID: 1, Country: United States
#    Troops: 100000.0
#    Deaths: 2000.0
#    Result: winner
#    Battle Location: Aachen, Germany 50°46′35″N 06°05′00″E﻿ / ﻿50.77639°N 6.08333°E﻿ / 50.77639; 6.08333
# 2. Participant ID: 2, Battle ID: 1, Country: Germany
#    Troops: 13000.0
#    Deaths: 5000.0
#    Result: loser
#    Battle Location: Aachen, Germany 50°46′35″N 06°05′00″E﻿ / ﻿50.77639°N 6.08333°E﻿ / 50.77639; 6.08333
# 3. Participant ID: 3, Battle ID: 2, Country: First French Empire
#    Troops: 55000.0
#    Deaths: 1000.0
#    Result: winner
#    Battle Location: Abensberg, Germany 48°48′N 11°51′E﻿ / ﻿48.800°N 11.850°E﻿ / 48.800; 11.850
# 4. Participant ID: 4, Battle ID: 2, Country: Kingdom of Bavaria
#    Troops: 55000.0
#    Deaths: 1000.0
#    Result: winner
#    Battle Location: Abensberg, Germany 48°48′N 11°51′E﻿ / ﻿48.800°N 11.850°E﻿ / 48.800; 11.850
# 5. Participant ID: 5, Battle ID: 2, Country: Württemberg
#    Troops: 55000.0
#    Deaths: 1000.0
#    Result: winner
#    Battle Location: Abensberg, Germany 48°48′N 11°51′E﻿ / ﻿48.800°N 11.850°E﻿ / 48.800; 11.850
